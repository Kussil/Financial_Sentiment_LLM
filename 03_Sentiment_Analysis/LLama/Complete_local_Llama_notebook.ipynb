# %% [markdown]
# # Sentiment Analysis for Oil & Gas Articles using Local LLama
#
# ## Overview
#
# This Notebook contains a Python script for performing sentiment analysis on a dataset of oil and gas industry articles. The script categorizes each article into predefined categories and assigns a sentiment (Positive, Neutral, Negative, or N/A) to each category.
#
# *Key Components*
#
# 1. Data Preparation
#
# - The script loads a pre-cleaned dataset of articles.
# - It removes specific rows that are known to be unprocessable.
#
# 2. File Management
#
# - The script checks for an existing results file.
# - If the file doesn't exist, it creates an empty DataFrame to store results.
#
# 3. Sentiment Analysis Process
#
# - The script uses a pre-defined template for sentiment analysis.
# - It processes articles one by one, assigning sentiments to each category.
# - Results are saved to a CSV file after each successful analysis.
#
# 4. Error Handling and Retries
#
# - The script includes a retry mechanism for failed analyses.
# - After a maximum number of retries, it marks the entry as "No JSON found".
#
# 5. Progress Tracking
#
# - The script prints progress updates every 10 iterations.
# - It displays the number of articles processed and the elapsed time.

# %%
# Import Libraries
import os
import sys
import time
import pandas as pd

# %%
# Setup paths
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
source_code_dir = os.path.join(project_dir, '10_Source_Code')
sys.path.append(source_code_dir)

# import local .py helper functions
import llama_setup as ls
import data_setup as ds

# %%
# Global Variables
CATEGORIES = [
        "Finance",
        "Production",
        "Reserves / Exploration / Acquisitions / Mergers / Divestments",
        "Environment / Regulatory / Geopolitics",
        "Alternative Energy / Lower Carbon",
        "Oil Price / Natural Gas Price / Gasoline Price"
        ]

SENTIMENT_RESULTS_FILE_PATH = 'Full_data_LLama_model_sentiment_analysis_results.csv'
ROWS_TO_DROP = ['PQ-2840736837']
MAX_TRIES = 5

# %%
# Load and prepare data
text_df = ds.load_cleaned_data()
text_df = ds.drop_unprocessable_rows(text_df, ROWS_TO_DROP)

# %%
# Check if sentiment analysis results file exists and create if it doesn't
if not ds.check_file_exists(SENTIMENT_RESULTS_FILE_PATH):
    empty_sentiment_df = ds.create_empty_sentiment_df(text_df, CATEGORIES)
    ds.save_dataframe_to_csv(empty_sentiment_df, SENTIMENT_RESULTS_FILE_PATH)
    print(f"Created and saved an empty sentiment analysis DataFrame to {SENTIMENT_RESULTS_FILE_PATH}")
else:
    print(f"The file exists in the current directory.")
# Out:
# The file exists in the current directory.

# %%
# Define the template
TEMPLATE = """<s>Classify the following article into categories with sentiment (Positive, Neutral, Negative, N/A if not applicable or not mentioned) and provide the output in the specified dictionary format.
Example:
Article: ExxonMobil announced a significant increase in quarterly profits due to rising oil prices and increased production levels.
Output: {{"Finance": "Positive", 'Production': "Positive", "Reserves / Exploration / Acquisitions / Mergers / Divestments": 'Neutral', "Environment / Regulatory / Geopolitics": 'Neutral', "Alternative Energy / Lower Carbon": 'Neutral', "Oil Price / Natural Gas Price / Gasoline Price": "Positive"}}

Example:
Article: Chevron plans to invest heavily in renewable energy projects, aiming to reduce its carbon footprint over the next decade.
Output: {{'Finance': 'Neutral', 'Production': 'Neutral', "Reserves / Exploration / Acquisitions / Mergers / Divestments": 'Neutral', "Environment / Regulatory / Geopolitics": "Positive", "Alternative Energy / Lower Carbon": "Positive", "Oil Price / Natural Gas Price / Gasoline Price": 'Neutral'}}

Example:
Article: BP faced regulatory challenges in its latest drilling project, delaying operations and increasing costs.
Output: {{'Finance': 'Negative', "Production": 'Negative', "Reserves / Exploration / Acquisitions / Mergers / Divestments": 'Negative', "Environment / Regulatory / Geopolitics": 'Negative', "Alternative Energy / Lower Carbon": 'Neutral', "Oil Price / Natural Gas Price / Gasoline Price": 'Neutral'}}

Article: {article}

Output only the EXACT dictionary format:
{{"Finance": '[Sentiment]', "Production": '[Sentiment]', "Reserves / Exploration / Acquisitions / Mergers / Divestments": '[Sentiment]', "Environment / Regulatory / Geopolitics":: '[Sentiment]', "Alternative Energy / Lower Carbon": '[Sentiment]', "Oil Price / Natural Gas Price / Gasoline Price": '[Sentiment]'}}

Do not use any other format or additional information. Please provide the output in the specified format only.</s>"""

# %%
# Function to process a single unique ID
def process_unique_id(unique_id):
    """Process a single article for sentiment analysis.

    Args:
        unique_id (str): The unique identifier for the article.

    Returns:
        bool: True if analysis was successful, False otherwise.

    Tries to perform sentiment analysis on an article, updating results in a CSV file.
    If unsuccessful after MAX_TRIES attempts, saves "No JSON found" for each category.
    """
    
    for _ in range(MAX_TRIES):
        try:
            company, source, headline, text = ds.get_model_inputs(text_df, unique_id)
            response = ls.get_ollama_response(text, TEMPLATE)
            sentiment_dict = ds.extract_and_convert_to_dict(response)

            if isinstance(sentiment_dict, dict):
                ds.update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict, CATEGORIES)
                return True
            print("Error: Sentiment dictionary not found. Retrying...")
        except Exception as e:
            print(f"Error: {e}. Retrying...")
    
    print(f"Max retries reached for Unique_ID '{unique_id}'. Inserting 'No JSON found' for each category.")
    sentiment_dict = {category: "No JSON found" for category in CATEGORIES}
    ds.update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict, CATEGORIES)
    return False

# %%
unique_id = ds.find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
    if not unique_id:
        break
    
    process_unique_id(unique_id)
    count += 1
    if count % 10 == 0:
        elapsed_time = time.time() - start_time
        minutes, seconds = divmod(elapsed_time, 60)
        print(f"Iteration: {count}, Elapsed Time: {int(minutes)} minutes and {seconds:.2f} seconds")

print("Processing complete.")
# Out:
# Row with Unique_ID 'PQ-2324792481' has been updated.
# Row with Unique_ID 'PQ-2323314971' has been updated.
# Row with Unique_ID 'PQ-2323189609' has been updated.
# Row with Unique_ID 'PQ-2300871043' has been updated.
# Row with Unique_ID 'PQ-2300871006' has been updated.
# Row with Unique_ID 'PQ-2293021546' has been updated.
# Row with Unique_ID 'PQ-2268136378' has been updated.
# Row with Unique_ID 'PQ-2244937767' has been updated.
# Row with Unique_ID 'PQ-2244906592' has been updated.
# Row with Unique_ID 'PQ-2244478210' has been updated.
# Iteration: 60, Elapsed Time: 5 minutes and 49.43 seconds
# Row with Unique_ID 'PQ-2771856894' has been updated.
# Row with Unique_ID 'PQ-2771237417' has been updated.
# Row with Unique_ID 'PQ-2771152183' has been updated.
# Row with Unique_ID 'PQ-2769962559' has been updated.
# Row with Unique_ID 'PQ-2760492003' has been updated.
# Row with Unique_ID 'PQ-2760070699' has been updated.
# Row with Unique_ID 'PQ-2759651523' has been updated.
# Row with Unique_ID 'PQ-2748143336' has been updated.
# Row with Unique_ID 'PQ-2745193656' has been updated.
# Row with Unique_ID 'PQ-2742617595' has been updated.
# Iteration: 70, Elapsed Time: 6 minutes and 40.84 seconds
# Row with Unique_ID 'PQ-2740634042' has been updated.
# Row with Unique_ID 'PQ-2740324084' has been updated.
# Row with Unique_ID 'PQ-2740193502' has been updated.
# Row with Unique_ID 'PQ-2739630314' has been updated.
# Row with Unique_ID 'PQ-2739520395' has been updated.
# Row with Unique_ID 'PQ-2739209148' has been updated.
# Row with Unique_ID 'PQ-2729783296' has been updated.
# Row with Unique_ID 'PQ-2722122777' has been updated.
# Row with Unique_ID 'PQ-2722643285' has been updated.
# Row with Unique_ID 'PQ-2721802552' has been updated.
# Iteration: 80, Elapsed Time: 7 minutes and 40.42 seconds
# Row with Unique_ID 'PQ-2721508150' has been updated.
# Row with Unique_ID 'PQ-2721460199' has been updated.
# Row with Unique_ID 'PQ-2721420498' has been updated.
# Row with Unique_ID 'PQ-2718784313' has been updated.
# Row with Unique_ID 'PQ-2718711441' has been updated.
# Row with Unique_ID 'PQ-2710406566' has been updated.
# Row with Unique_ID 'PQ-2703460640' has been updated.
# Row with Unique_ID 'PQ-2327801858' has been updated.
# Row with Unique_ID 'PQ-2327620821' has been updated.
# Row with Unique_ID 'PQ-2327697799' has been updated.
# Iteration: 90, Elapsed Time: 8 minutes and 38.52 seconds
# Row with Unique_ID 'PQ-2395334486' has been updated.
# Row with Unique_ID 'PQ-2335373659' has been updated.
# Row with Unique_ID 'PQ-2324684049' has been updated.
# Row with Unique_ID 'PQ-2323364655' has been updated.
# Row with Unique_ID 'PQ-2323315275' has been updated.
# Row with Unique_ID 'PQ-2323314949' has been updated.
# Row with Unique_ID 'PQ-2323229714' has been updated.
# Row with Unique_ID 'PQ-2323221766' has been updated.
# Row with Unique_ID 'PQ-2326721500' has been updated.
# Row with Unique_ID 'PQ-2323244712' has been updated.
# Iteration: 100, Elapsed Time: 9 minutes and 23.96 seconds
# Row with Unique_ID 'PQ-2323211159' has been updated.
# Row with Unique_ID 'PQ-2323175805' has been updated.
# Row with Unique_ID 'PQ-2323117073' has been updated.
# Row with Unique_ID 'PQ-2322866856' has been updated.
# Row with Unique_ID 'PQ-2322859114' has been updated.
# Row with Unique_ID 'PQ-2322855827' has been updated.
# Row with Unique_ID 'PQ-2320722172' has been updated.
# Row with Unique_ID 'PQ-2321819316' has been updated.
# Row with Unique_ID 'PQ-2320603664' has been updated.
# Row with Unique_ID 'PQ-2331003355' has been updated.
# Iteration: 210, Elapsed Time: 18 minutes and 37.48 seconds
# Row with Unique_ID 'PQ-2256171063' has been updated.
# Row with Unique_ID 'PQ-2250928384' has been updated.
# Row with Unique_ID 'PQ-2247734402' has been updated.
# Row with Unique_ID 'PQ-2247355270' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Row with Unique_ID 'PQ-2245639024' has been updated.
# Iteration: 220, Elapsed Time: 19 minutes and 17.82 seconds
# Row with Unique_ID 'PQ-2244906120' has been updated.
# Row with Unique_ID 'PQ-2243775793' has been updated.
# Row with Unique_ID 'PQ-2243346678' has been updated.
# Row with Unique_ID 'PQ-2243086864' has been updated.
# Row with Unique_ID 'PQ-2242835045' has been updated.
# Row with Unique_ID 'PQ-2242820797' has been updated.
# Row with Unique_ID 'PQ-2239979451' has been updated.
# Row with Unique_ID 'PQ-2239863317' has been updated.
# Row with Unique_ID 'PQ-2239510473' has been updated.
# Row with Unique_ID 'PQ-2239283546' has been updated.
# Iteration: 230, Elapsed Time: 20 minutes and 11.55 seconds
# Row with Unique_ID 'PQ-2239089892' has been updated.
# Row with Unique_ID 'PQ-2402030268' has been updated.
# Row with Unique_ID 'PQ-2235486926' has been updated.
# Row with Unique_ID 'PQ-2235443163' has been updated.
# Row with Unique_ID 'PQ-2233557520' has been updated.
# Row with Unique_ID 'PQ-2231710988' has been updated.
# Row with Unique_ID 'PQ-2231735045' has been updated.
# Row with Unique_ID 'PQ-2231690024' has been updated.
# Row with Unique_ID 'PQ-2230361536' has been updated.
# Row with Unique_ID 'PQ-2227455983' has been updated.
# Iteration: 240, Elapsed Time: 20 minutes and 56.26 seconds
# Row with Unique_ID 'PQ-2227232356' has been updated.
# Row with Unique_ID 'PQ-2227225821' has been updated.
# Row with Unique_ID 'PQ-2227141839' has been updated.
# Row with Unique_ID 'PQ-3056009640' has been updated.
# Row with Unique_ID 'PQ-3052970753' has been updated.
# Row with Unique_ID 'PQ-3052970730' has been updated.
# Row with Unique_ID 'PQ-3052496953' has been updated.
# Row with Unique_ID 'PQ-3051275772' has been updated.
# Row with Unique_ID 'PQ-3050407291' has been updated.
# Row with Unique_ID 'PQ-3050228204' has been updated.
# Iteration: 250, Elapsed Time: 21 minutes and 48.35 seconds
# Row with Unique_ID 'PQ-3050112389' has been updated.
# Row with Unique_ID 'PQ-3050015203' has been updated.
# Row with Unique_ID 'PQ-3049739707' has been updated.
# Row with Unique_ID 'PQ-3049593095' has been updated.
# Row with Unique_ID 'PQ-3047773500' has been updated.
# Row with Unique_ID 'PQ-3046483001' has been updated.
# Row with Unique_ID 'PQ-3046429653' has been updated.
# Row with Unique_ID 'PQ-3042542195' has been updated.
# Row with Unique_ID 'PQ-3040303610' has been updated.
# Row with Unique_ID 'PQ-2774630976' has been updated.
# Row with Unique_ID 'PQ-2774552858' has been updated.
# Row with Unique_ID 'PQ-2774052488' has been updated.
# Row with Unique_ID 'PQ-2773734099' has been updated.
# Row with Unique_ID 'PQ-2772193026' has been updated.
# Iteration: 460, Elapsed Time: 40 minutes and 41.48 seconds
# Row with Unique_ID 'PQ-2772165273' has been updated.
# Row with Unique_ID 'PQ-2771642663' has been updated.
# Row with Unique_ID 'PQ-2771527492' has been updated.
# Row with Unique_ID 'PQ-2771430953' has been updated.
# Row with Unique_ID 'PQ-2781402434' has been updated.
# Row with Unique_ID 'PQ-2771237400' has been updated.
# Row with Unique_ID 'PQ-2771237365' has been updated.
# Row with Unique_ID 'PQ-2771079076' has been updated.
# Row with Unique_ID 'PQ-2770992722' has been updated.
# Row with Unique_ID 'PQ-2770936261' has been updated.
# Iteration: 470, Elapsed Time: 41 minutes and 33.68 seconds
# Row with Unique_ID 'PQ-2770775585' has been updated.
# Row with Unique_ID 'PQ-2770645068' has been updated.
# Row with Unique_ID 'PQ-2770475524' has been updated.
# Row with Unique_ID 'PQ-2768825153' has been updated.
# Row with Unique_ID 'PQ-2768713957' has been updated.
# Row with Unique_ID 'PQ-2768609000' has been updated.
# Row with Unique_ID 'PQ-2765791749' has been updated.
# Row with Unique_ID 'PQ-2765112507' has been updated.
# Row with Unique_ID 'PQ-2765180132' has been updated.
# Row with Unique_ID 'PQ-2764532627' has been updated.
# Iteration: 480, Elapsed Time: 42 minutes and 28.87 seconds
# Row with Unique_ID 'PQ-2764016600' has been updated.
# Row with Unique_ID 'PQ-2762994721' has been updated.
# Row with Unique_ID 'PQ-2761401021' has been updated.
# Row with Unique_ID 'PQ-2760658015' has been updated.
# Row with Unique_ID 'PQ-2760426793' has been updated.
# Row with Unique_ID 'PQ-2771487742' has been updated.
# Row with Unique_ID 'PQ-2760153151' has been updated.
# Row with Unique_ID 'PQ-2759940391' has been updated.
# Row with Unique_ID 'PQ-2759688645' has been updated.
# Row with Unique_ID 'PQ-2759014958' has been updated.
# Iteration: 490, Elapsed Time: 43 minutes and 16.50 seconds
# Row with Unique_ID 'PQ-2770177139' has been updated.
# Row with Unique_ID 'PQ-2758949216' has been updated.
# Row with Unique_ID 'PQ-2758693578' has been updated.
# Row with Unique_ID 'PQ-2767355732' has been updated.
# Row with Unique_ID 'PQ-2756541137' has been updated.
# Row with Unique_ID 'PQ-2756219044' has been updated.
# Row with Unique_ID 'PQ-2755906144' has been updated.
# Row with Unique_ID 'PQ-2755778203' has been updated.
# Row with Unique_ID 'PQ-2755623669' has been updated.
# Row with Unique_ID 'PQ-2754348506' has been updated.
# Iteration: 500, Elapsed Time: 44 minutes and 1.83 seconds
# Row with Unique_ID 'PQ-2749593707' has been updated.
# Error: setting an array element with a sequence.. Retrying...
# Error: setting an array element with a sequence.. Retrying...
# Row with Unique_ID 'PQ-2748975713' has been updated.
# Row with Unique_ID 'PQ-2748975713' has been updated.
# Row with Unique_ID 'PQ-2403409209' has been updated.
# Row with Unique_ID 'PQ-2403408849' has been updated.
# Row with Unique_ID 'PQ-2390060390' has been updated.
# Row with Unique_ID 'PQ-2390207567' has been updated.
# Row with Unique_ID 'PQ-2389699880' has been updated.
# Row with Unique_ID 'PQ-2386682270' has been updated.
# Row with Unique_ID 'PQ-2386392174' has been updated.
# Iteration: 1500, Elapsed Time: 127 minutes and 51.35 seconds
# Row with Unique_ID 'PQ-2386258973' has been updated.
# Row with Unique_ID 'PQ-2386109619' has been updated.
# Row with Unique_ID 'PQ-2386109619' has been updated.
# Row with Unique_ID 'PQ-2386109619' has been updated.
# Row with Unique_ID 'PQ-2386069708' has been updated.
# Row with Unique_ID 'PQ-2385836977' has been updated.
# Row with Unique_ID 'PQ-2385127261' has been updated.
# Row with Unique_ID 'PQ-2384905013' has been updated.
# Row with Unique_ID 'PQ-2384244356' has been updated.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       7 if not unique_id:
#       8     break
# ---> 10 process_unique_id(unique_id)
#      11 count += 1
#      12 if count % 10 == 0:
#
# Cell In[17], line 18, in process_unique_id(unique_id)
#      16 try:
#      17     company, source, headline, text = ds.get_model_inputs(text_df, unique_id)
# ---> 18     response = ls.get_ollama_response(text, TEMPLATE)
#      19     sentiment_dict = ds.extract_and_convert_to_dict(response)
#      21     if isinstance(sentiment_dict, dict):
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/llama_setup.py:13, in get_ollama_response(article, template)
#      10     return f"Error: Prompt length exceeds maximum context length of {max_context_length} tokens"
#      12 model = "llama3"  # Replace with the appropriate model name if needed
# ---> 13 response = ollama.generate(model=model, prompt=prompt)
#      15 if 'response' in response:
#      16     return response['response'].strip()
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/ollama/_client.py:127, in Client.generate(self, model, prompt, system, template, context, stream, raw, format, images, options, keep_alive)
#     124 if not model:
#     125   raise RequestError('must provide a model')
# --> 127 return self._request_stream(
#     128   'POST',
#     129   '/api/generate',
#     130   json={
#     131     'model': model,
#     132     'prompt': prompt,
#     133     'system': system,
#     134     'template': template,
#     135     'context': context or [],
#     136     'stream': stream,
#     137     'raw': raw,
#     138     'images': [_encode_image(image) for image in images or []],
#     139     'format': format,
#     140     'options': options or {},
#     141     'keep_alive': keep_alive,
#     142   },
#     143   stream=stream,
#     144 )
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/ollama/_client.py:98, in Client._request_stream(self, stream, *args, **kwargs)
#      92 def _request_stream(
#      93   self,
#      94   *args,
#      95   stream: bool = False,
#      96   **kwargs,
#      97 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 98   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/ollama/_client.py:69, in Client._request(self, method, url, **kwargs)
#      68 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 69   response = self._client.request(method, url, **kwargs)
#      71   try:
#      72     response.raise_for_status()
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
