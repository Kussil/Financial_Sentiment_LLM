# %% [markdown]
# # Import Libraries and Clone Github

# %%
# Import Libraries
import os
import re
import time
import pandas as pd
import google.generativeai as genai

# %%
# Global Variables
CATEGORIES = [
        "Finance",
        "Production",
        "Reserves / Exploration / Acquisitions / Mergers / Divestments",
        "Environment / Regulatory / Geopolitics",
        "Alternative Energy / Lower Carbon",
        "Oil Price / Natural Gas Price / Gasoline Price"]
SENTIMENT_RESULTS_FILE_PATH = 'Prompt2_Sentiment_Analysis_Results.csv'

# %% [markdown]
# # Import Data

# %%
# Import all cleaned data files
invest_df1 = pd.read_csv('../02_Cleaned_Data/Investment_Research_Part1.csv')
invest_df2 = pd.read_csv('../02_Cleaned_Data/Investment_Research_Part2.csv')
proquest_df = pd.read_csv('../02_Cleaned_Data/ProQuest_Articles.csv')
earnings_presentations = pd.read_csv('../02_Cleaned_Data/Earnings_Presentations.csv')
earnings_qa = pd.read_csv('../02_Cleaned_Data/Earnings_QA.csv')
sec_df = pd.read_csv('../02_Cleaned_Data/SEC_Filings.csv')

# Merge into single df
text_df = pd.concat([invest_df1, invest_df2, proquest_df, sec_df, earnings_presentations, earnings_qa], ignore_index=True)
display(text_df.shape)
display(text_df.head())
display(text_df.tail())
# Out:
# (10053, 7)
#                 Source Unique_ID Ticker        Date          Article Headline  \
# 0  Investment Research      IR-1    MRO  2024-05-16  Marathon Oil Corporation
# 1  Investment Research      IR-2    EOG  2024-05-14       EOG Resources, Inc.
# 2  Investment Research      IR-3    EOG  2024-05-11       EOG Resources, Inc.
# 3  Investment Research      IR-4    DVN  2024-05-11  Devon Energy Corporation
# 4  Investment Research      IR-5    COP  2024-05-07            ConocoPhillips
#
#                                         Article Text  URL
# 0  Stock Report | May 16, 2024 | NYSESymbol: MRO ...  NaN
# 1  Stock Report | May 14, 2024 | NYSESymbol: EOG ...  NaN
# 2  Stock Report | May 11, 2024 | NYSESymbol: EOG ...  NaN
# 3  Stock Report | May 11, 2024 | NYSESymbol: DVN ...  NaN
# 4  Stock Report | May 07, 2024 | NYSESymbol:\n\nC...  NaN
#                   Source Unique_ID Ticker        Date  \
# 10048  Earnings Call Q&A    EQ-338    XOM  2021-02-02
# 10049  Earnings Call Q&A    EQ-339    COP  2021-02-02
# 10050  Earnings Call Q&A    EQ-340    EOG  2019-05-03
# 10051  Earnings Call Q&A    EQ-341   SHEL  2019-05-02
# 10052  Earnings Call Q&A    EQ-342    COP  2019-04-30
#
#                                         Article Headline  \
# 10048  Exxon Mobil Corporation, Q4 2020 Earnings Call...
# 10049  ConocoPhillips, Q4 2020 Earnings Call, Feb 02,...
# 10050  EOG Resources, Inc., Q1 2019 Earnings Call, Ma...
# 10051  Royal Dutch Shell plc, Q1 2019 Earnings Call, ...
# 10052  ConocoPhillips, Q1 2019 Earnings Call, Apr 30,...
#
#                                             Article Text  URL
# 10048  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10049  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10050  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10051  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10052  Question and Answer\nOperator\n[Operator Instr...  NaN

# %%
# Drop rows google gemini will not process
rows_to_drop = ['PQ-2840736837']
index_to_drops = text_df[text_df['Unique_ID'].isin(rows_to_drop)].index
text_df.drop(index_to_drops, inplace=True)
print(index_to_drops)
# Out:
# Index([5379], dtype='int64')

# %% [markdown]
# # Find or Create Results CSV

# %%
# Determine if the Sentiment Analysis Results file already exists
file_exists = os.path.isfile(SENTIMENT_RESULTS_FILE_PATH)

# Print the result
if file_exists:
    print(f"The file exists in the current directory.")
else:
    print(f"The file does not exist in the current directory.")
# Out:
# The file exists in the current directory.

# %%
# Create an empty file if the file does not exist
if not file_exists:
    # Copy text df and drop the text and headline column due to size
    empty_sentiment_df = text_df.copy()
    empty_sentiment_df = empty_sentiment_df.drop(['Article Text', 'Article Headline'], axis=1)

    for category in CATEGORIES:
        empty_sentiment_df[category] = ""
        empty_sentiment_df[category] = empty_sentiment_df[category].astype('object')

    # Display results
    display(empty_sentiment_df.head())

    # Save as CSV
    empty_sentiment_df.to_csv(SENTIMENT_RESULTS_FILE_PATH, index=False)

# %% [markdown]
# ### NOTE: If you want to re-run the sentiment analysis, delete or archive the csv to create a blank one

# %% [markdown]
# # Sentiment Analysis
# NOTE: Google gemini **currently** has a daily query limit of 1,500 requests per day.  As we have over 10,000 documents, the code will be designed to run over multiple days and pick up where we last left off.  After the code is run, the user will still need to manually download the csv and upload to github.

# %% [markdown]
# **Gemini Free Rate Limits**
# *   15 RPM (requests per minute)
# *   1 million TPM (tokens per minute)
# *   1,500 RPD (requests per day)

# %%
# Set up Gemini. (API key needs to be in your environment variables)
key = 'GOOGLE_API_KEY'
GOOGLE_API_KEY = os.getenv(key)
genai.configure(api_key=GOOGLE_API_KEY)

# So it doesn't block the output
safety_settings = [
    {
        "category": "HARM_CATEGORY_DANGEROUS",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE",},]

model = genai.GenerativeModel('gemini-1.5-flash-latest', safety_settings=safety_settings)

# %%
# Function to find the first empty row of the csv
def find_first_unique_id_with_empty_values(file_path, categories):
    """
    Finds the first unique ID where any of the specified columns have empty values in a CSV file.

    Args:
        file_path (str): The path to the CSV file.
        categories (list of str): List of column names to check for empty values.

    Returns:
        str: The first Unique_ID where any of the specified columns have empty values.
        None: If no such row is found.
    """

    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Iterate over each row to find the first unique ID with any empty values in the specified columns
    for index, row in df.iterrows():
        if row[categories].isnull().any() or (row[categories] == '').any():
            return row['Unique_ID']

    return None  # Return None if no such row is found

# Test function
unique_id = find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
print(unique_id)
# Out:
# PQ-2635684693

# %%
# Helper function to get Gemini query function inputs
def get_gemini_inputs(text_df, unique_id):
    """
    Retrieves information from the DataFrame based on the unique ID and outputs company, source, headline, and text.

    Args:
        text_df (pd.DataFrame): The DataFrame containing the text data.
        unique_id (str): The unique ID to search for.

    Returns:
        tuple: A tuple containing company, source, headline, and text.
    """
    # Find the row with the specified unique ID
    row = text_df[text_df['Unique_ID'] == unique_id]

    # Extract the required information
    company = row['Ticker'].values[0]
    source = row['Source'].values[0]
    headline = row['Article Headline'].values[0]
    text = row['Article Text'].values[0]

    return company, source, headline, text

# Test function
company, source, headline, text = get_gemini_inputs(text_df, unique_id)
print(f"Company: {company}\n")
print(f"Source: {source}\n")
print(f"Headline: {headline}\n")
print(f"Text:\n{text}")
# Out:
# Company: XOM
#
# Source: ProQuest
#
# Headline: Apple Exxon Mobil Rivian Stocks That Defined Week
#
# Text:
# Apple Inc.
# Major Western companies are retreating from Russia . Apple said Tuesday it stopped selling iPhones and other products in Russia, saying it was "deeply concerned about the Russian invasion of Ukraine." Ukraine's vice prime minister on Feb. 25 asked Chief Executive Tim Cook to stop supplying products and services—including access to the App Store—to Russia. Other companies that made similar moves include Ford Motor Co. and Dell Technologies Inc. Apple shares gained 2.1% Wednesday.
# Zoom Video Communications Inc.
# The return of the office may be slowing Zoom's connection. The company's sales growth faltered in the fourth quarter, signaling that demand for its videoconferencing application is no longer as entrenched in daily life as it was earlier in the pandemic. Zoom's performance soared when Covid-19 treatments were largely unavailable and much of the world operated on virtual platforms as people stayed indoors. As Covid-19 conditions improve and competitors such as Microsoft Corp. and Meta Platforms Inc. fight for market share, Zoom has looked for ways to augment its growth. Its nearly $15 billion attempted acquisition of contact-center company Five9 Inc. in September was blocked by the selling shareholders. Zoom shares lost 7.4% Tuesday.
# Exxon Mobil Corp.
# Russia's attack on Ukraine fueled a surge in oil over the past week. U.S. crude prices on Wednesday rose to over $110 a barrel for the first time since 2014 as refiners refused to buy Russian oil, taking a bite out of global energy supplies. Rising oil costs could further boost inflation across the U.S. economy. U.S. oil giants such as Exxon Mobil and Chevron Corp. stand to benefit from higher energy prices, even as they work to disentangle themselves from Russia. Exxon said Tuesday it was halting operations at a multibillion-dollar oil-and-gas project in Russia and would make no further investments in the country, following similar moves by European peers BP PLC and Shell PLC. Exxon shares rose 1.7% Wednesday.
# Kroger Co.
# Shoppers are hungry for more-affordable meals. Kroger said Thursday that its streak of strong sales and profits continued in the latest quarter, thanks to U.S. consumers who ate more at home. Executives said shoppers are cooking more meals at home because it is cheaper to do so than to dine out and that they are shifting to low-cost store brands. Food costs have been rising for months as manufacturers raise prices to offset growing costs and sellers like Kroger pass on these increases to consumers. Price increases in meat and grocery products have been highest, and Kroger executives expect inflation to moderate in the second half of the year. Kroger shares added 12% Thursday.
# Best Buy Co.
# Best Buy is trying to recover from a holiday hangover. The electronics retailer posted lower sales for the holiday quarter compared with the same period a year ago, when homebound consumers splurged on televisions and other electronics. The company expected inventory constraints but shortages were worse than anticipated, particularly in areas that include popular holiday gifts such as mobile phones and computing. While Best Buy expects revenue to fall in its current fiscal year, the company expects sales to rebound to as much as $56.5 billion by 2024, above Wall Street expectations. Best Buy shares increased 9.2% Thursday.
# Rivian Automotive Inc.
# Rivian shifted a hefty price increase into reverse. The electric-vehicle startup's Chief Executive RJ Scaringe apologized in a letter Thursday for applying higher prices to existing orders for its electric trucks and SUVs. The increase was put into effect earlier in the week as the company tried to cope with rising costs of parts and materials, but Mr. Scaringe said Rivian erred by applying them to existing orders. The company will now honor the original prices for customers who ordered a vehicle before the Tuesday increase, which added around 20% to the price of some model configurations. For some customers, the rise translated into a premium of $10,000 to $20,000. Rivian shares slid more than 13% Wednesday and fell 5% further Thursday.
# Sweetgreen Inc.
# Workers are returning to offices, and so are their desk salads. Sweetgreen reported results and an outlook that were better than expected , boosted by higher prices and workers returning to their physical workplaces. The company, which went public in November, said sales are improving in Sweetgreen's urban stores, particularly in Midtown Manhattan. Sweetgreen also raised prices by 6% earlier this year as it seeks to pay for rising wages and other costs and food, including avocados. The company said it hopes to open at least 35 new restaurants this year, while construction delays and supply-chain problems weighed on the chain's new openings. Sweetgreen shares surged 25% Friday.
# Write to Francesca Fontana at francesca.fontana@wsj.com
#  Apple, Exxon Mobil, Rivian: Stocks That Defined the Week

# %%
# Function to query Gemini
def query_gemini(company, source, headline, text, model):
    """
    Query Gemini to perform sentiment analysis on text from various sources about a company.

    Parameters:
    company (str): The name of the company the text is about.
    source (str): The source of the text. Valid values are "Investment Research", "ProQuest", "SEC Filings", "Earnings Call Presentations", "Earnings Call Q&A".
    headline (str): The headline or title of the text.
    text (str): The body of the text to be analyzed.
    model: The model object used to generate content and analyze the text.

    Returns:
    str: The sentiment analysis results for predefined categories in the specified format.

    The function constructs a prompt based on the source of the text and performs sentiment analysis on the given text using the provided model.
    It analyzes the content across multiple predefined categories, determining the sentiment (Positive, Neutral, Negative) for each category.
    If a category is not mentioned or relevant based on the text content, it is marked as 'Neutral'.
    The final output is summarized in a specified format.
    """

    # Source Variables
    if source == "Investment Research":
        text_source = "an analyst report"
        text_source2 = "the analyst report"
    elif source == "ProQuest":
        text_source = "a news article"
        text_source2 = "the news article"
    elif source == "SEC Filings":
        text_source = "an SEC filing"
        text_source2 = "the SEC filing"
    elif source == "Earnings Call Presentations":
        text_source = "an earnings call presentation"
        text_source2 = "the earnings call presentation"
    elif source == "Earnings Call Q&A":
        text_source = "an earnings call Q&A session"
        text_source2 = "the earnings call Q&A session"

    # Prompt
    prompt = f"""
Given the text from {text_source} about {company}, analyze the content and perform sentiment analysis across multiple predefined categories.

Sentiment options:
  - Positive
  - Neutral
  - Negative

Categories:
  - Finance
  - Production
  - Reserves / Exploration / Acquisitions / Mergers / Divestments
  - Environment / Regulatory / Geopolitics
  - Alternative Energy / Lower Carbon
  - Oil Price / Natural Gas Price / Gasoline Price

Each category should be evaluated and given a sentiment output derived from the text.
If a category is not mentioned or relevant based on the text content, mark it as 'Neutral'.

Before giving your answer, explain your reasoning and reference the article.
After going through all the categories, provide a summary in the following format:
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment

Example Output1:
- Finance - Positive
- Production - Neutral
- Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative
- Environment / Regulatory / Geopolitics - Neutral
- Alternative Energy / Lower Carbon - Positive
- Oil Price / Natural Gas Price / Gasoline Price - Neutral

Example Output 2:
 - Finance - Negative
 - Production - Positive
 - Reserves / Exploration / Acquisitions / Mergers / Divestments - Neutral
 - Environment / Regulatory / Geopolitics - Positive
 - Alternative Energy / Lower Carbon - Neutral
 - Oil Price / Natural Gas Price / Gasoline Price - Negative

Example Output 3:
 - Finance - Neutral
 - Production - Negative
 - Reserves / Exploration / Acquisitions / Mergers / Divestments - Positive
 - Environment / Regulatory / Geopolitics - Negative
 - Alternative Energy / Lower Carbon - Positive
 - Oil Price / Natural Gas Price / Gasoline Price - Neutral

Example Output 4:
 - Finance - Positive
 - Production - Neutral
 - Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative
 - Environment / Regulatory / Geopolitics - Neutral
 - Alternative Energy / Lower Carbon - Negative
 - Oil Price / Natural Gas Price / Gasoline Price - Positive

Example Output 5:
 - Finance - Negative
 - Production - Positive
 - Reserves / Exploration / Acquisitions / Mergers / Divestments - Neutral
 - Environment / Regulatory / Geopolitics - Negative
 - Alternative Energy / Lower Carbon - Positive
 - Oil Price / Natural Gas Price / Gasoline Price - Negative

Make sure to use plain text, do not bold or bullet the output summary.

The text from {text_source2} is below:
{headline}
{text}

Remember to summarize your final answers in the following format exactly:
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment

Make sure to use plain text and stick to the given categories and sentiment options.
DO NOT bold or bullet the output summary.
    """

    # print(prompt)
    response = model.generate_content(prompt)
    return response.text

# Test function
response = query_gemini(company, source, headline, text, model)
print(response)
# Out:
# ## Sentiment Analysis of XOM Article:
#
# The article focuses on Exxon Mobil's response to the Russian invasion of Ukraine and its impact on the oil market. Here's a breakdown of the sentiment analysis:
#
# **- Finance - Positive:**  The article mentions that Exxon Mobil shares rose 1.7% on Wednesday, likely due to the surge in oil prices. This indicates a positive sentiment towards the company's financial performance in the context of the rising oil market.
#
# **- Production - Neutral:** While the article mentions Exxon Mobil's decision to halt operations at a multibillion-dollar oil-and-gas project in Russia, there's no direct information on the impact on their overall production. Therefore, the sentiment is neutral.
#
# **- Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative:** The article explicitly states that Exxon Mobil is halting operations and will make no further investments in Russia. This signifies a negative sentiment towards future exploration and development activities in the region.
#
# **- Environment / Regulatory / Geopolitics - Neutral:** The article focuses on the geopolitical impact of the Russian invasion and Exxon Mobil's response. There's no mention of environmental or regulatory implications specific to the company.
#
# **- Alternative Energy / Lower Carbon - Neutral:**  The article doesn't discuss Exxon Mobil's stance on alternative energy or lower-carbon initiatives. The focus is on the company's response to the geopolitical situation and its implications for the oil market.
#
# **- Oil Price / Natural Gas Price / Gasoline Price - Positive:** The article clearly states that Exxon Mobil stands to benefit from higher energy prices. This indicates a positive sentiment towards the company's position in the context of rising oil prices.
#
# **Summary:**
#
# - Finance - Positive
# - Production - Neutral
# - Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative
# - Environment / Regulatory / Geopolitics - Neutral
# - Alternative Energy / Lower Carbon - Neutral
# - Oil Price / Natural Gas Price / Gasoline Price - Positive

# %%
# Function to parse text
def parse_sentiment(text, categories):
    """
    Parses a given text for specified categories and their sentiments.

    Args:
        text (str): The input text containing categories and their sentiments.
        categories (list of str): List of category names to look for in the text.

    Returns:
        dict or str: A dictionary with categories as keys and their corresponding sentiments as values,
                     or "Did not find all categories" if any sentiment is not Positive, Neutral, or Negative.
    """
    results = {}
    valid_sentiments = {"Positive", "Neutral", "Negative"}

    for category in categories:
        # Create a regex pattern to match the format "- Category - Sentiment"
        # The category name is escaped to handle any special characters
        pattern = rf"- {re.escape(category)} - (\w+)"

        # Search for the pattern in the text
        match = re.search(pattern, text)

        # If a match is found, extract the sentiment and add it to the results dictionary
        if match:
            sentiment = match.group(1)
            if sentiment not in valid_sentiments:
                return "Did not find all categories"
            results[category] = sentiment
        else:
            return "Did not find all categories"

    return results

# Test function
fail_text = """
- Finance - Positive
- Production - Neutral
- Reserves / Exploration / Acquisitions / Mergers / Divestments - Bad
- Environment / Regulatory / Geopolitics - Neutral
- Alternative Energy / Lower Carbon - Positive
- Oil Price / Natural Gas Price / Gasoline Price - Neutral
"""

sentiment_dict = parse_sentiment(response, CATEGORIES)
fail_sentiment = parse_sentiment("fail_text", CATEGORIES)
print(sentiment_dict)
print(fail_sentiment)
# Out:
# {'Finance': 'Positive', 'Production': 'Neutral', 'Reserves / Exploration / Acquisitions / Mergers / Divestments': 'Negative', 'Environment / Regulatory / Geopolitics': 'Neutral', 'Alternative Energy / Lower Carbon': 'Neutral', 'Oil Price / Natural Gas Price / Gasoline Price': 'Positive'}
# Did not find all categories

# %%
# Function to update the csv
def update_csv(file_path, unique_id, sentiment_dict):
    """
    Updates the columns of a CSV file based on the unique ID and sentiment dictionary.

    Args:
        file_path (str): The path to the CSV file.
        unique_id (str): The unique ID of the row to be updated.
        sentiment_dict (dict): A dictionary with categories as keys and their corresponding sentiments as values.

    Returns:
        None
    """
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Find the index of the row with the specified unique ID
    row_index = df[df['Unique_ID'] == unique_id].index

    # Update the columns based on the sentiment dictionary
    for category, sentiment in sentiment_dict.items():
        df.loc[row_index, category] = sentiment

    # Save the updated DataFrame back to the CSV file
    df.to_csv(file_path, index=False)
    print(f"Row with Unique_ID '{unique_id}' has been updated.")

# Test function
update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict)
# Out:
# Row with Unique_ID 'PQ-2635684693' has been updated.

# %%
start_time = time.time()
unique_id = find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
count = 0
max_tries = 5

# Iterate through the CSV using the functions
while unique_id:
    retries = 0
    success = False

    # There are multiple errors that can happen, many of them simply need another try
    while retries < max_tries and not success:
        try:
            # Get gemini inputs
            company, source, headline, text = get_gemini_inputs(text_df, unique_id)

            # Query Gemini
            response = query_gemini(company, source, headline, text, model)

            # Parse text
            sentiment_dict = parse_sentiment(response, CATEGORIES)

            # Update the csv
            update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict)

            success = True

        except Exception as e:
            retries += 1
            print(f"Error encountered: {e}. Retry {retries}/{max_tries}")

            if retries >= max_tries:
                print(f"Failed to process unique_id {unique_id} after {max_tries} attempts. Stopping.")
                # Exit both loops
                unique_id = None
                break

    if not success:
        break

    # Get an update every 10 rows
    count += 1
    if count % 10 == 0:
        elapsed_time = time.time() - start_time
        minutes, seconds = divmod(elapsed_time, 60)
        print(f"Iteration: {count}, Elapsed Time: {int(minutes)} minutes and {seconds:.2f} seconds")

    # Find the next empty row
    unique_id = find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)

    # Test print statements
    # print(unique_id)
    # print(f"Company: {company}\n")
    # print(f"Source: {source}\n")
    # print(f"Headline: {headline}\n")
    # print(f"Text:\n{text}")
    # print(response)
    # print(sentiment_dict)
# Out:
# Row with Unique_ID 'PQ-2635256694' has been updated.
# Row with Unique_ID 'PQ-2635314949' has been updated.
# Row with Unique_ID 'PQ-2635161746' has been updated.
# Row with Unique_ID 'PQ-2634870869' has been updated.
# Row with Unique_ID 'PQ-2512376328' has been updated.
# Row with Unique_ID 'PQ-2464144160' has been updated.
# Row with Unique_ID 'PQ-2460769247' has been updated.
# Row with Unique_ID 'PQ-2460088266' has been updated.
# Row with Unique_ID 'PQ-2458488855' has been updated.
# Row with Unique_ID 'PQ-2458407133' has been updated.
# Iteration: 10, Elapsed Time: 1 minutes and 59.63 seconds
# Row with Unique_ID 'PQ-2467512336' has been updated.
# Row with Unique_ID 'PQ-2467512046' has been updated.
# Row with Unique_ID 'PQ-2458216645' has been updated.
# Row with Unique_ID 'PQ-2457706001' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2457420881' has been updated.
# Row with Unique_ID 'PQ-2456396416' has been updated.
# Row with Unique_ID 'PQ-2455950447' has been updated.
# Row with Unique_ID 'PQ-2462670688' has been updated.
# Row with Unique_ID 'PQ-2465586187' has been updated.
# Row with Unique_ID 'PQ-2465586065' has been updated.
# Iteration: 20, Elapsed Time: 4 minutes and 1.59 seconds
# Row with Unique_ID 'PQ-2462488152' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2456191848' has been updated.
# Row with Unique_ID 'PQ-2456156613' has been updated.
# Row with Unique_ID 'PQ-2456134408' has been updated.
# Row with Unique_ID 'PQ-2456109214' has been updated.
# Row with Unique_ID 'PQ-2456040178' has been updated.
# Row with Unique_ID 'PQ-2456039502' has been updated.
# Row with Unique_ID 'PQ-2456028131' has been updated.
# Row with Unique_ID 'PQ-2455949221' has been updated.
# Row with Unique_ID 'PQ-2455822853' has been updated.
# Iteration: 30, Elapsed Time: 6 minutes and 4.77 seconds
# Row with Unique_ID 'PQ-2455784674' has been updated.
# Row with Unique_ID 'PQ-2455687806' has been updated.
# Row with Unique_ID 'PQ-2464945933' has been updated.
# Row with Unique_ID 'PQ-2455645121' has been updated.
# Row with Unique_ID 'PQ-2455552740' has been updated.
# Row with Unique_ID 'PQ-2455201343' has been updated.
# Row with Unique_ID 'PQ-2455201332' has been updated.
# Row with Unique_ID 'PQ-2455169836' has been updated.
# Row with Unique_ID 'PQ-2454328119' has been updated.
# Row with Unique_ID 'PQ-2454091719' has been updated.
# Iteration: 40, Elapsed Time: 7 minutes and 59.86 seconds
# Row with Unique_ID 'PQ-2454056062' has been updated.
# Row with Unique_ID 'PQ-2454036495' has been updated.
# Row with Unique_ID 'PQ-2453915666' has been updated.
# Row with Unique_ID 'PQ-2452248911' has been updated.
# Row with Unique_ID 'PQ-2451442571' has been updated.
# Row with Unique_ID 'PQ-2450647558' has been updated.
# Row with Unique_ID 'PQ-2450305143' has been updated.
# Row with Unique_ID 'PQ-2450196544' has been updated.
# Row with Unique_ID 'PQ-2450194061' has been updated.
# Row with Unique_ID 'PQ-2449967350' has been updated.
# Iteration: 50, Elapsed Time: 9 minutes and 59.04 seconds
# Row with Unique_ID 'PQ-2449571674' has been updated.
# Row with Unique_ID 'PQ-2449399881' has been updated.
# Row with Unique_ID 'PQ-2449154930' has been updated.
# Row with Unique_ID 'PQ-2449146170' has been updated.
# Row with Unique_ID 'PQ-2449125988' has been updated.
# Row with Unique_ID 'PQ-2458223659' has been updated.
# Row with Unique_ID 'PQ-2449005401' has been updated.
# Row with Unique_ID 'PQ-2448932892' has been updated.
# Row with Unique_ID 'PQ-2448592253' has been updated.
# Row with Unique_ID 'PQ-2456676431' has been updated.
# Iteration: 60, Elapsed Time: 12 minutes and 1.51 seconds
# Row with Unique_ID 'PQ-2447808236' has been updated.
# Row with Unique_ID 'PQ-2447713435' has been updated.
# Row with Unique_ID 'PQ-2447565139' has been updated.
# Row with Unique_ID 'PQ-2446976744' has been updated.
# Row with Unique_ID 'PQ-2446976580' has been updated.
# Row with Unique_ID 'PQ-2443977330' has been updated.
# Row with Unique_ID 'PQ-2442609741' has been updated.
# Row with Unique_ID 'PQ-2442049509' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2442018888' has been updated.
# Row with Unique_ID 'PQ-2441960536' has been updated.
# Iteration: 70, Elapsed Time: 14 minutes and 3.12 seconds
# Row with Unique_ID 'PQ-2441137391' has been updated.
# Row with Unique_ID 'PQ-2440245856' has been updated.
# Row with Unique_ID 'PQ-2439649199' has been updated.
# Row with Unique_ID 'PQ-2439618280' has been updated.
# Row with Unique_ID 'PQ-2439770787' has been updated.
# Row with Unique_ID 'PQ-2439531047' has been updated.
# Row with Unique_ID 'PQ-2438987818' has been updated.
# Row with Unique_ID 'PQ-2438859392' has been updated.
# Row with Unique_ID 'PQ-2438710428' has been updated.
# Row with Unique_ID 'PQ-2438370772' has been updated.
# Iteration: 80, Elapsed Time: 16 minutes and 3.24 seconds
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2438206252' has been updated.
# Row with Unique_ID 'PQ-2438105357' has been updated.
# Row with Unique_ID 'PQ-2437040192' has been updated.
# Row with Unique_ID 'PQ-2437028126' has been updated.
# Row with Unique_ID 'PQ-2437027766' has been updated.
# Row with Unique_ID 'PQ-2436965662' has been updated.
# Row with Unique_ID 'PQ-2436933290' has been updated.
# Row with Unique_ID 'PQ-2436892144' has been updated.
# Row with Unique_ID 'PQ-2436780066' has been updated.
# Row with Unique_ID 'PQ-2436762008' has been updated.
# Iteration: 90, Elapsed Time: 17 minutes and 54.18 seconds
# Row with Unique_ID 'PQ-2436683850' has been updated.
# Row with Unique_ID 'PQ-2436683849' has been updated.
# Row with Unique_ID 'PQ-2436608480' has been updated.
# Row with Unique_ID 'PQ-2436583181' has been updated.
# Row with Unique_ID 'PQ-2436546484' has been updated.
# Row with Unique_ID 'PQ-2435018141' has been updated.
# Row with Unique_ID 'PQ-2433639517' has been updated.
# Row with Unique_ID 'PQ-2430956816' has been updated.
# Row with Unique_ID 'PQ-2430687108' has been updated.
# Row with Unique_ID 'PQ-2429595521' has been updated.
# Iteration: 100, Elapsed Time: 19 minutes and 43.04 seconds
# Row with Unique_ID 'PQ-2429380975' has been updated.
# Row with Unique_ID 'PQ-2429348794' has been updated.
# Row with Unique_ID 'PQ-2429089130' has been updated.
# Row with Unique_ID 'PQ-2429055563' has been updated.
# Row with Unique_ID 'PQ-2428624961' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2426943010' has been updated.
# Row with Unique_ID 'PQ-2426063414' has been updated.
# Row with Unique_ID 'PQ-2425893050' has been updated.
# Row with Unique_ID 'PQ-2425422247' has been updated.
# Row with Unique_ID 'PQ-2424888002' has been updated.
# Iteration: 110, Elapsed Time: 21 minutes and 40.14 seconds
# Row with Unique_ID 'PQ-2424854070' has been updated.
# Row with Unique_ID 'PQ-2424742264' has been updated.
# Row with Unique_ID 'PQ-2424089170' has been updated.
# Row with Unique_ID 'PQ-2423432452' has been updated.
# Row with Unique_ID 'PQ-2419786561' has been updated.
# Row with Unique_ID 'PQ-2419608527' has been updated.
# Row with Unique_ID 'PQ-2419446002' has been updated.
# Row with Unique_ID 'PQ-2419445912' has been updated.
# Row with Unique_ID 'PQ-2419102873' has been updated.
# Row with Unique_ID 'PQ-2418937872' has been updated.
# Iteration: 120, Elapsed Time: 23 minutes and 32.15 seconds
# Row with Unique_ID 'PQ-2420029245' has been updated.
# Row with Unique_ID 'PQ-2418718278' has been updated.
# Row with Unique_ID 'PQ-2418543857' has been updated.
# Row with Unique_ID 'PQ-2417867929' has been updated.
# Row with Unique_ID 'PQ-2417173170' has been updated.
# Row with Unique_ID 'PQ-2416813816' has been updated.
# Row with Unique_ID 'PQ-2416745379' has been updated.
# Row with Unique_ID 'PQ-2416695967' has been updated.
# Row with Unique_ID 'PQ-2415818711' has been updated.
# Row with Unique_ID 'PQ-2413958672' has been updated.
# Iteration: 130, Elapsed Time: 25 minutes and 25.32 seconds
# Row with Unique_ID 'PQ-2413822217' has been updated.
# Row with Unique_ID 'PQ-2413166015' has been updated.
# Row with Unique_ID 'PQ-2412335205' has been updated.
# Row with Unique_ID 'PQ-2409932022' has been updated.
# Row with Unique_ID 'PQ-2407498370' has been updated.
# Row with Unique_ID 'PQ-2407487889' has been updated.
# Row with Unique_ID 'PQ-2406797800' has been updated.
# Row with Unique_ID 'PQ-2405760931' has been updated.
# Row with Unique_ID 'PQ-2403387629' has been updated.
# Row with Unique_ID 'PQ-2412431955' has been updated.
# Iteration: 140, Elapsed Time: 27 minutes and 21.02 seconds
# Row with Unique_ID 'PQ-2401965937' has been updated.
# Row with Unique_ID 'PQ-2399826211' has been updated.
# Row with Unique_ID 'PQ-2408381655' has been updated.
# Row with Unique_ID 'PQ-2397179046' has been updated.
# Row with Unique_ID 'PQ-2397129122' has been updated.
# Row with Unique_ID 'PQ-2396988654' has been updated.
# Row with Unique_ID 'PQ-2396875981' has been updated.
# Row with Unique_ID 'PQ-2396295080' has been updated.
# Row with Unique_ID 'PQ-2396303631' has been updated.
# Row with Unique_ID 'PQ-2396284965' has been updated.
# Iteration: 150, Elapsed Time: 29 minutes and 15.86 seconds
# Row with Unique_ID 'PQ-2396198772' has been updated.
# Row with Unique_ID 'PQ-2394691271' has been updated.
# Row with Unique_ID 'PQ-2393604341' has been updated.
# Row with Unique_ID 'PQ-2393213188' has been updated.
# Row with Unique_ID 'PQ-2393202834' has been updated.
# Row with Unique_ID 'PQ-2392562320' has been updated.
# Row with Unique_ID 'PQ-2392300565' has been updated.
# Row with Unique_ID 'PQ-2391770111' has been updated.
# Row with Unique_ID 'PQ-2391877873' has been updated.
# Row with Unique_ID 'PQ-2389213483' has been updated.
# Iteration: 160, Elapsed Time: 31 minutes and 8.27 seconds
# Row with Unique_ID 'PQ-2388703074' has been updated.
# Row with Unique_ID 'PQ-2400021997' has been updated.
# Row with Unique_ID 'PQ-2400021721' has been updated.
# Row with Unique_ID 'PQ-2400021458' has been updated.
# Row with Unique_ID 'PQ-2400021124' has been updated.
# Row with Unique_ID 'PQ-2400021108' has been updated.
# Row with Unique_ID 'PQ-2400020643' has been updated.
# Row with Unique_ID 'PQ-2387532729' has been updated.
# Row with Unique_ID 'PQ-2387146941' has been updated.
# Row with Unique_ID 'PQ-2386941184' has been updated.
# Iteration: 170, Elapsed Time: 33 minutes and 0.52 seconds
# Row with Unique_ID 'PQ-2386830165' has been updated.
# Row with Unique_ID 'PQ-2386062144' has been updated.
# Row with Unique_ID 'PQ-2385886975' has been updated.
# Row with Unique_ID 'PQ-2385831738' has been updated.
# Row with Unique_ID 'PQ-2385096299' has been updated.
# Row with Unique_ID 'PQ-2384779735' has been updated.
# Row with Unique_ID 'PQ-2384552412' has been updated.
# Row with Unique_ID 'PQ-2382046980' has been updated.
# Row with Unique_ID 'PQ-2379499612' has been updated.
# Row with Unique_ID 'PQ-2378965582' has been updated.
# Iteration: 180, Elapsed Time: 34 minutes and 53.53 seconds
# Row with Unique_ID 'PQ-2378909891' has been updated.
# Row with Unique_ID 'PQ-2377459231' has been updated.
# Row with Unique_ID 'PQ-2393205566' has been updated.
# Row with Unique_ID 'PQ-2374442372' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2371713511' has been updated.
# Row with Unique_ID 'PQ-2372516672' has been updated.
# Row with Unique_ID 'PQ-2371547503' has been updated.
# Row with Unique_ID 'PQ-2371106053' has been updated.
# Row with Unique_ID 'PQ-2371309257' has been updated.
# Row with Unique_ID 'PQ-2371098450' has been updated.
# Iteration: 190, Elapsed Time: 36 minutes and 50.20 seconds
# Row with Unique_ID 'PQ-2370291694' has been updated.
# Row with Unique_ID 'PQ-2367252413' has been updated.
# Row with Unique_ID 'PQ-2366793813' has been updated.
# Row with Unique_ID 'PQ-2363650062' has been updated.
# Row with Unique_ID 'PQ-2363280333' has been updated.
# Row with Unique_ID 'PQ-2363660987' has been updated.
# Row with Unique_ID 'PQ-2363660736' has been updated.
# Row with Unique_ID 'PQ-2363226190' has been updated.
# Row with Unique_ID 'PQ-2363169772' has been updated.
# Row with Unique_ID 'PQ-2363166923' has been updated.
# Iteration: 200, Elapsed Time: 38 minutes and 42.22 seconds
# Row with Unique_ID 'PQ-2362532719' has been updated.
# Row with Unique_ID 'PQ-2362532691' has been updated.
# Row with Unique_ID 'PQ-2362531836' has been updated.
# Row with Unique_ID 'PQ-2362531574' has been updated.
# Row with Unique_ID 'PQ-2362209842' has been updated.
# Row with Unique_ID 'PQ-2361576124' has been updated.
# Row with Unique_ID 'PQ-2361601122' has been updated.
# Row with Unique_ID 'PQ-2354612851' has been updated.
# Row with Unique_ID 'PQ-2353622615' has been updated.
# Row with Unique_ID 'PQ-2352778340' has been updated.
# Iteration: 210, Elapsed Time: 40 minutes and 37.70 seconds
# Row with Unique_ID 'PQ-2352395660' has been updated.
# Row with Unique_ID 'PQ-2351579267' has been updated.
# Row with Unique_ID 'PQ-2351446772' has been updated.
# Row with Unique_ID 'PQ-2350444636' has been updated.
# Row with Unique_ID 'PQ-2350274595' has been updated.
# Row with Unique_ID 'PQ-2349771591' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2349118518' has been updated.
# Row with Unique_ID 'PQ-2348794401' has been updated.
# Row with Unique_ID 'PQ-2348757503' has been updated.
# Row with Unique_ID 'PQ-2346242803' has been updated.
# Iteration: 220, Elapsed Time: 42 minutes and 44.82 seconds
# Row with Unique_ID 'PQ-2345949089' has been updated.
# Row with Unique_ID 'PQ-2343437031' has been updated.
# Row with Unique_ID 'PQ-2340167368' has been updated.
# Row with Unique_ID 'PQ-2339835547' has been updated.
# Row with Unique_ID 'PQ-2336163266' has been updated.
# Row with Unique_ID 'PQ-2336033246' has been updated.
# Row with Unique_ID 'PQ-2335764163' has been updated.
# Row with Unique_ID 'PQ-2334712389' has been updated.
# Row with Unique_ID 'PQ-2334061232' has been updated.
# Row with Unique_ID 'PQ-2333891210' has been updated.
# Iteration: 230, Elapsed Time: 44 minutes and 43.75 seconds
# Row with Unique_ID 'PQ-2332279979' has been updated.
# Row with Unique_ID 'PQ-2332146166' has been updated.
# Row with Unique_ID 'PQ-2332094986' has been updated.
# Row with Unique_ID 'PQ-2332028601' has been updated.
# Row with Unique_ID 'PQ-2331885945' has been updated.
# Row with Unique_ID 'PQ-2391980750' has been updated.
# Row with Unique_ID 'PQ-2331509547' has been updated.
# Row with Unique_ID 'PQ-2331269531' has been updated.
# Row with Unique_ID 'PQ-2331242810' has been updated.
# Row with Unique_ID 'PQ-2330936284' has been updated.
# Iteration: 240, Elapsed Time: 46 minutes and 35.97 seconds
# Row with Unique_ID 'PQ-2330836123' has been updated.
# Row with Unique_ID 'PQ-2330797032' has been updated.
# Row with Unique_ID 'PQ-2330587115' has been updated.
# Row with Unique_ID 'PQ-2330576904' has been updated.
# Row with Unique_ID 'PQ-2329798649' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2634846288' has been updated.
# Row with Unique_ID 'PQ-2634830546' has been updated.
# Row with Unique_ID 'PQ-2634767028' has been updated.
# Row with Unique_ID 'PQ-2634754226' has been updated.
# Row with Unique_ID 'PQ-2634722007' has been updated.
# Iteration: 250, Elapsed Time: 48 minutes and 31.67 seconds
# Row with Unique_ID 'PQ-2634683777' has been updated.
# Row with Unique_ID 'PQ-2634643277' has been updated.
# Row with Unique_ID 'PQ-2634634659' has been updated.
# Row with Unique_ID 'PQ-2632156011' has been updated.
# Row with Unique_ID 'PQ-2632068493' has been updated.
# Row with Unique_ID 'PQ-2632039219' has been updated.
# Row with Unique_ID 'PQ-2631837393' has been updated.
# Row with Unique_ID 'PQ-2631565450' has been updated.
# Row with Unique_ID 'PQ-2630589286' has been updated.
# Row with Unique_ID 'PQ-2629228730' has been updated.
# Iteration: 260, Elapsed Time: 50 minutes and 29.50 seconds
# Row with Unique_ID 'PQ-2629050139' has been updated.
# Row with Unique_ID 'PQ-2627834694' has been updated.
# Row with Unique_ID 'PQ-2626791216' has been updated.
# Row with Unique_ID 'PQ-2626201952' has been updated.
# Row with Unique_ID 'PQ-2626088076' has been updated.
# Row with Unique_ID 'PQ-2625995082' has been updated.
# Row with Unique_ID 'PQ-2625959270' has been updated.
# Row with Unique_ID 'PQ-2625859566' has been updated.
# Row with Unique_ID 'PQ-2625372929' has been updated.
# Row with Unique_ID 'PQ-2635752236' has been updated.
# Iteration: 270, Elapsed Time: 52 minutes and 25.39 seconds
# Row with Unique_ID 'PQ-2624957874' has been updated.
# Row with Unique_ID 'PQ-2635344606' has been updated.
# Row with Unique_ID 'PQ-2635343189' has been updated.
# Row with Unique_ID 'PQ-2624855836' has been updated.
# Row with Unique_ID 'PQ-2624561453' has been updated.
# Row with Unique_ID 'PQ-2624532259' has been updated.
# Row with Unique_ID 'PQ-2624463729' has been updated.
# Row with Unique_ID 'PQ-2624242198' has been updated.
# Row with Unique_ID 'PQ-2624157749' has been updated.
# Row with Unique_ID 'PQ-2624092487' has been updated.
# Iteration: 280, Elapsed Time: 54 minutes and 16.03 seconds
# Row with Unique_ID 'PQ-2624083488' has been updated.
# Row with Unique_ID 'PQ-2624054309' has been updated.
# Row with Unique_ID 'PQ-2623998915' has been updated.
# Row with Unique_ID 'PQ-2623895215' has been updated.
# Row with Unique_ID 'PQ-2623837782' has been updated.
# Row with Unique_ID 'PQ-2623809189' has been updated.
# Row with Unique_ID 'PQ-2623775996' has been updated.
# Row with Unique_ID 'PQ-2623732613' has been updated.
# Row with Unique_ID 'PQ-2623575854' has been updated.
# Row with Unique_ID 'PQ-2621670082' has been updated.
# Iteration: 290, Elapsed Time: 56 minutes and 6.07 seconds
# Row with Unique_ID 'PQ-2621097970' has been updated.
# Row with Unique_ID 'PQ-2629526890' has been updated.
# Row with Unique_ID 'PQ-2621037948' has been updated.
# Row with Unique_ID 'PQ-2620938694' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2620819812' has been updated.
# Row with Unique_ID 'PQ-2620752943' has been updated.
# Row with Unique_ID 'PQ-2620736647' has been updated.
# Row with Unique_ID 'PQ-2619617965' has been updated.
# Row with Unique_ID 'PQ-2618486662' has been updated.
# Row with Unique_ID 'PQ-2618485891' has been updated.
# Iteration: 300, Elapsed Time: 58 minutes and 8.77 seconds
# Row with Unique_ID 'PQ-2618157687' has been updated.
# Row with Unique_ID 'PQ-2618130212' has been updated.
# Row with Unique_ID 'PQ-2618023648' has been updated.
# Row with Unique_ID 'PQ-2617927908' has been updated.
# Row with Unique_ID 'PQ-2617083046' has been updated.
# Row with Unique_ID 'PQ-2616985634' has been updated.
# Row with Unique_ID 'PQ-2616921304' has been updated.
# Row with Unique_ID 'PQ-2616639258' has been updated.
# Row with Unique_ID 'PQ-2615910751' has been updated.
# Row with Unique_ID 'PQ-2615479089' has been updated.
# Iteration: 310, Elapsed Time: 60 minutes and 2.29 seconds
# Row with Unique_ID 'PQ-2614816757' has been updated.
# Row with Unique_ID 'PQ-2614291124' has been updated.
# Row with Unique_ID 'PQ-2614102073' has been updated.
# Row with Unique_ID 'PQ-2613762451' has been updated.
# Row with Unique_ID 'PQ-2612734337' has been updated.
# Row with Unique_ID 'PQ-2611570191' has been updated.
# Row with Unique_ID 'PQ-2609540248' has been updated.
# Row with Unique_ID 'PQ-2609720404' has been updated.
# Row with Unique_ID 'PQ-2609284140' has been updated.
# Row with Unique_ID 'PQ-2609256585' has been updated.
# Iteration: 320, Elapsed Time: 61 minutes and 55.37 seconds
# Row with Unique_ID 'PQ-2609209148' has been updated.
# Row with Unique_ID 'PQ-2608875357' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2608575157' has been updated.
# Row with Unique_ID 'PQ-2608476575' has been updated.
# Row with Unique_ID 'PQ-2607974000' has been updated.
# Row with Unique_ID 'PQ-2607535783' has been updated.
# Row with Unique_ID 'PQ-2607496731' has been updated.
# Row with Unique_ID 'PQ-2607099772' has been updated.
# Row with Unique_ID 'PQ-2606720958' has been updated.
# Row with Unique_ID 'PQ-2605729703' has been updated.
# Iteration: 330, Elapsed Time: 63 minutes and 55.30 seconds
# Row with Unique_ID 'PQ-2605734782' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2615534736' has been updated.
# Row with Unique_ID 'PQ-2605392959' has been updated.
# Row with Unique_ID 'PQ-2605141555' has been updated.
# Row with Unique_ID 'PQ-2605069697' has been updated.
# Row with Unique_ID 'PQ-2605051254' has been updated.
# Row with Unique_ID 'PQ-2605034098' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2604805865' has been updated.
# Row with Unique_ID 'PQ-2604805863' has been updated.
# Row with Unique_ID 'PQ-2599235621' has been updated.
# Iteration: 340, Elapsed Time: 66 minutes and 1.74 seconds
# Row with Unique_ID 'PQ-2597902027' has been updated.
# Row with Unique_ID 'PQ-2596221483' has been updated.
# Row with Unique_ID 'PQ-2595338839' has been updated.
# Row with Unique_ID 'PQ-2591323713' has been updated.
# Row with Unique_ID 'PQ-2591158652' has been updated.
# Row with Unique_ID 'PQ-2589875135' has been updated.
# Row with Unique_ID 'PQ-2589781328' has been updated.
# Row with Unique_ID 'PQ-2589048807' has been updated.
# Row with Unique_ID 'PQ-2774590730' has been updated.
# Row with Unique_ID 'PQ-2587948614' has been updated.
# Iteration: 350, Elapsed Time: 68 minutes and 0.37 seconds
# Row with Unique_ID 'PQ-2587948613' has been updated.
# Row with Unique_ID 'PQ-2587697315' has been updated.
# Row with Unique_ID 'PQ-2587629444' has been updated.
# Row with Unique_ID 'PQ-2586963731' has been updated.
# Row with Unique_ID 'PQ-2586925859' has been updated.
# Row with Unique_ID 'PQ-2586572691' has been updated.
# Row with Unique_ID 'PQ-2586461222' has been updated.
# Row with Unique_ID 'PQ-2586273659' has been updated.
# Row with Unique_ID 'PQ-2585981909' has been updated.
# Row with Unique_ID 'PQ-2585814870' has been updated.
# Iteration: 360, Elapsed Time: 69 minutes and 55.57 seconds
# Row with Unique_ID 'PQ-2585787786' has been updated.
# Row with Unique_ID 'PQ-2625006485' has been updated.
# Row with Unique_ID 'PQ-2584868574' has been updated.
# Row with Unique_ID 'PQ-2584161468' has been updated.
# Row with Unique_ID 'PQ-2583942109' has been updated.
# Row with Unique_ID 'PQ-2583765526' has been updated.
# Row with Unique_ID 'PQ-2583453438' has been updated.
# Row with Unique_ID 'PQ-2582791784' has been updated.
# Row with Unique_ID 'PQ-2580904027' has been updated.
# Row with Unique_ID 'PQ-2580852279' has been updated.
# Iteration: 370, Elapsed Time: 71 minutes and 49.23 seconds
# Row with Unique_ID 'PQ-2578960594' has been updated.
# Row with Unique_ID 'PQ-2578679903' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Error encountered: 'str' object has no attribute 'items'. Retry 2/5
# Row with Unique_ID 'PQ-2578587675' has been updated.
# Row with Unique_ID 'PQ-2578182512' has been updated.
# Row with Unique_ID 'PQ-2578102237' has been updated.
# Row with Unique_ID 'PQ-2577116789' has been updated.
# Row with Unique_ID 'PQ-2576914261' has been updated.
# Row with Unique_ID 'PQ-2576847305' has been updated.
# Row with Unique_ID 'PQ-2576661672' has been updated.
# Row with Unique_ID 'PQ-2576621655' has been updated.
# Iteration: 380, Elapsed Time: 73 minutes and 52.99 seconds
# Row with Unique_ID 'PQ-2576542197' has been updated.
# Row with Unique_ID 'PQ-2576542102' has been updated.
# Row with Unique_ID 'PQ-2574785664' has been updated.
# Row with Unique_ID 'PQ-2574802920' has been updated.
# Row with Unique_ID 'PQ-2571716329' has been updated.
# Row with Unique_ID 'PQ-2569703110' has been updated.
# Row with Unique_ID 'PQ-2568685392' has been updated.
# Row with Unique_ID 'PQ-2568692009' has been updated.
# Row with Unique_ID 'PQ-2567798168' has been updated.
# Row with Unique_ID 'PQ-2563474560' has been updated.
# Iteration: 390, Elapsed Time: 75 minutes and 46.51 seconds
# Row with Unique_ID 'PQ-2560871917' has been updated.
# Row with Unique_ID 'PQ-2558340803' has been updated.
# Row with Unique_ID 'PQ-2558052918' has been updated.
# Row with Unique_ID 'PQ-2556734051' has been updated.
# Row with Unique_ID 'PQ-2556572801' has been updated.
# Row with Unique_ID 'PQ-2556421021' has been updated.
# Row with Unique_ID 'PQ-2556421016' has been updated.
# Row with Unique_ID 'PQ-2555868048' has been updated.
# Row with Unique_ID 'PQ-2555652642' has been updated.
# Row with Unique_ID 'PQ-2555496254' has been updated.
# Iteration: 400, Elapsed Time: 77 minutes and 49.75 seconds
# Row with Unique_ID 'PQ-2555298056' has been updated.
# Row with Unique_ID 'PQ-2554997421' has been updated.
# Row with Unique_ID 'PQ-2554827063' has been updated.
# Row with Unique_ID 'PQ-2554615739' has been updated.
# Row with Unique_ID 'PQ-2553162752' has been updated.
# Row with Unique_ID 'PQ-2552977943' has been updated.
# Row with Unique_ID 'PQ-2552837424' has been updated.
# Row with Unique_ID 'PQ-2551427202' has been updated.
# Row with Unique_ID 'PQ-2548654153' has been updated.
# Row with Unique_ID 'PQ-2547889634' has been updated.
# Iteration: 410, Elapsed Time: 79 minutes and 42.28 seconds
# Row with Unique_ID 'PQ-2546868727' has been updated.
# Row with Unique_ID 'PQ-2546868715' has been updated.
# Row with Unique_ID 'PQ-2546770036' has been updated.
# Row with Unique_ID 'PQ-2546775564' has been updated.
# Row with Unique_ID 'PQ-2546689009' has been updated.
# Row with Unique_ID 'PQ-2546598031' has been updated.
# Row with Unique_ID 'PQ-2543901239' has been updated.
# Row with Unique_ID 'PQ-2543700151' has been updated.
# Row with Unique_ID 'PQ-2540764382' has been updated.
# Row with Unique_ID 'PQ-2540046220' has been updated.
# Iteration: 420, Elapsed Time: 81 minutes and 42.57 seconds
# Row with Unique_ID 'PQ-2540027812' has been updated.
# Row with Unique_ID 'PQ-2539904842' has been updated.
# Row with Unique_ID 'PQ-2539860166' has been updated.
# Row with Unique_ID 'PQ-2539449111' has been updated.
# Row with Unique_ID 'PQ-2539190206' has been updated.
# Row with Unique_ID 'PQ-2539121095' has been updated.
# Row with Unique_ID 'PQ-2537420770' has been updated.
# Row with Unique_ID 'PQ-2537420768' has been updated.
# Row with Unique_ID 'PQ-2537293691' has been updated.
# Row with Unique_ID 'PQ-2537271943' has been updated.
# Iteration: 430, Elapsed Time: 83 minutes and 46.55 seconds
# Row with Unique_ID 'PQ-2548036404' has been updated.
# Row with Unique_ID 'PQ-2536720302' has been updated.
# Row with Unique_ID 'PQ-2536600755' has been updated.
# Row with Unique_ID 'PQ-2536391023' has been updated.
# Row with Unique_ID 'PQ-2536263233' has been updated.
# Row with Unique_ID 'PQ-2535802630' has been updated.
# Row with Unique_ID 'PQ-2536017983' has been updated.
# Row with Unique_ID 'PQ-2535999807' has been updated.
# Row with Unique_ID 'PQ-2535761746' has been updated.
# Row with Unique_ID 'PQ-2535548374' has been updated.
# Iteration: 440, Elapsed Time: 85 minutes and 44.37 seconds
# Row with Unique_ID 'PQ-2545445113' has been updated.
# Row with Unique_ID 'PQ-2545444747' has been updated.
# Row with Unique_ID 'PQ-2545441616' has been updated.
# Row with Unique_ID 'PQ-2533651137' has been updated.
# Row with Unique_ID 'PQ-2533532967' has been updated.
# Row with Unique_ID 'PQ-2533577878' has been updated.
# Row with Unique_ID 'PQ-2533515116' has been updated.
# Row with Unique_ID 'PQ-2533460415' has been updated.
# Row with Unique_ID 'PQ-2533432114' has been updated.
# Row with Unique_ID 'PQ-2533109988' has been updated.
# Iteration: 450, Elapsed Time: 87 minutes and 44.93 seconds
# Row with Unique_ID 'PQ-2774491523' has been updated.
# Row with Unique_ID 'PQ-2545003804' has been updated.
# Row with Unique_ID 'PQ-2533068003' has been updated.
# Row with Unique_ID 'PQ-2532779344' has been updated.
# Row with Unique_ID 'PQ-2532635021' has been updated.
# Row with Unique_ID 'PQ-2532613067' has been updated.
# Row with Unique_ID 'PQ-2532502678' has been updated.
# Row with Unique_ID 'PQ-2532491185' has been updated.
# Row with Unique_ID 'PQ-2532442220' has been updated.
# Row with Unique_ID 'PQ-2532442208' has been updated.
# Iteration: 460, Elapsed Time: 112 minutes and 43.92 seconds
# Row with Unique_ID 'PQ-2532442173' has been updated.
# Row with Unique_ID 'PQ-2532335151' has been updated.
# Row with Unique_ID 'PQ-2532303015' has been updated.
# Row with Unique_ID 'PQ-2532283339' has been updated.
# Row with Unique_ID 'PQ-2532265642' has been updated.
# Row with Unique_ID 'PQ-2532229346' has been updated.
# Row with Unique_ID 'PQ-2532173695' has been updated.
# Row with Unique_ID 'PQ-2532105497' has been updated.
# Row with Unique_ID 'PQ-2532105495' has been updated.
# Row with Unique_ID 'PQ-2531963321' has been updated.
# Iteration: 470, Elapsed Time: 114 minutes and 36.85 seconds
# Row with Unique_ID 'PQ-2544335234' has been updated.
# Row with Unique_ID 'PQ-2531559000' has been updated.
# Row with Unique_ID 'PQ-2531508479' has been updated.
# Row with Unique_ID 'PQ-2542951398' has been updated.
# Row with Unique_ID 'PQ-2529614951' has been updated.
# Row with Unique_ID 'PQ-2529424479' has been updated.
# Row with Unique_ID 'PQ-2528419472' has been updated.
# Row with Unique_ID 'PQ-2528048175' has been updated.
# Row with Unique_ID 'PQ-2540428980' has been updated.
# Row with Unique_ID 'PQ-2540427563' has been updated.
# Iteration: 480, Elapsed Time: 116 minutes and 31.41 seconds
# Row with Unique_ID 'PQ-2540424643' has been updated.
# Row with Unique_ID 'PQ-2540423426' has been updated.
# Row with Unique_ID 'PQ-2527736409' has been updated.
# Row with Unique_ID 'PQ-2527593910' has been updated.
# Row with Unique_ID 'PQ-2526945255' has been updated.
# Row with Unique_ID 'PQ-2526062774' has been updated.
# Row with Unique_ID 'PQ-2520398375' has been updated.
# Row with Unique_ID 'PQ-2520398244' has been updated.
# Row with Unique_ID 'PQ-2534497496' has been updated.
# Row with Unique_ID 'PQ-2519977383' has been updated.
# Iteration: 490, Elapsed Time: 118 minutes and 19.53 seconds
# Row with Unique_ID 'PQ-2519926881' has been updated.
# Row with Unique_ID 'PQ-2519891876' has been updated.
# Row with Unique_ID 'PQ-2519678492' has been updated.
# Row with Unique_ID 'PQ-2519202085' has been updated.
# Row with Unique_ID 'PQ-2519132871' has been updated.
# Row with Unique_ID 'PQ-2519079155' has been updated.
# Row with Unique_ID 'PQ-2518891590' has been updated.
# Row with Unique_ID 'PQ-2518676093' has been updated.
# Row with Unique_ID 'PQ-2518151497' has been updated.
# Row with Unique_ID 'PQ-2531869129' has been updated.
# Iteration: 500, Elapsed Time: 119 minutes and 59.29 seconds
# Row with Unique_ID 'PQ-2518153748' has been updated.
# Row with Unique_ID 'PQ-2517909950' has been updated.
# Row with Unique_ID 'PQ-2516641409' has been updated.
# Row with Unique_ID 'PQ-2516621501' has been updated.
# Row with Unique_ID 'PQ-2516340721' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2529617166' has been updated.
# Row with Unique_ID 'PQ-2514964124' has been updated.
# Row with Unique_ID 'PQ-2514818614' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2514565663' has been updated.
# Row with Unique_ID 'PQ-2512407602' has been updated.
# Iteration: 510, Elapsed Time: 121 minutes and 45.53 seconds
# Row with Unique_ID 'PQ-2509527057' has been updated.
# Row with Unique_ID 'PQ-2509222441' has been updated.
# Row with Unique_ID 'PQ-2508218688' has been updated.
# Row with Unique_ID 'PQ-2505402825' has been updated.
# Row with Unique_ID 'PQ-2505700559' has been updated.
# Row with Unique_ID 'PQ-2500297665' has been updated.
# Row with Unique_ID 'PQ-2499282938' has been updated.
# Row with Unique_ID 'PQ-2499254435' has been updated.
# Row with Unique_ID 'PQ-2499015285' has been updated.
# Row with Unique_ID 'PQ-2498877583' has been updated.
# Iteration: 520, Elapsed Time: 123 minutes and 24.20 seconds
# Row with Unique_ID 'PQ-2496992509' has been updated.
# Row with Unique_ID 'PQ-2497249743' has been updated.
# Row with Unique_ID 'PQ-2508031384' has been updated.
# Row with Unique_ID 'PQ-2508031368' has been updated.
# Row with Unique_ID 'PQ-2508030824' has been updated.
# Row with Unique_ID 'PQ-2496747696' has been updated.
# Row with Unique_ID 'PQ-2496126853' has been updated.
# Row with Unique_ID 'PQ-2495976192' has been updated.
# Row with Unique_ID 'PQ-2495961141' has been updated.
# Row with Unique_ID 'PQ-2496337702' has been updated.
# Iteration: 530, Elapsed Time: 125 minutes and 7.79 seconds
# Row with Unique_ID 'PQ-2495484749' has been updated.
# Row with Unique_ID 'PQ-2495428733' has been updated.
# Row with Unique_ID 'PQ-2495264684' has been updated.
# Row with Unique_ID 'PQ-2507369490' has been updated.
# Row with Unique_ID 'PQ-2495216532' has been updated.
# Row with Unique_ID 'PQ-2495216374' has been updated.
# Row with Unique_ID 'PQ-2494781505' has been updated.
# Row with Unique_ID 'PQ-2494318073' has been updated.
# Row with Unique_ID 'PQ-2494214384' has been updated.
# Row with Unique_ID 'PQ-2494185849' has been updated.
# Iteration: 540, Elapsed Time: 126 minutes and 54.06 seconds
# Row with Unique_ID 'PQ-2493895108' has been updated.
# Row with Unique_ID 'PQ-2493715668' has been updated.
# Row with Unique_ID 'PQ-2493505019' has been updated.
# Row with Unique_ID 'PQ-2505571935' has been updated.
# Row with Unique_ID 'PQ-2491612337' has been updated.
# Row with Unique_ID 'PQ-2490405032' has been updated.
# Row with Unique_ID 'PQ-2489184288' has been updated.
# Row with Unique_ID 'PQ-2488070034' has been updated.
# Row with Unique_ID 'PQ-2487359190' has been updated.
# Row with Unique_ID 'PQ-2487322583' has been updated.
# Iteration: 550, Elapsed Time: 128 minutes and 35.04 seconds
# Row with Unique_ID 'PQ-2487118910' has been updated.
# Row with Unique_ID 'PQ-2486610930' has been updated.
# Row with Unique_ID 'PQ-2486500044' has been updated.
# Row with Unique_ID 'PQ-2486496971' has been updated.
# Row with Unique_ID 'PQ-2485947715' has been updated.
# Row with Unique_ID 'PQ-2485384511' has been updated.
# Row with Unique_ID 'PQ-2485321890' has been updated.
# Row with Unique_ID 'PQ-2485321172' has been updated.
# Row with Unique_ID 'PQ-2484918239' has been updated.
# Row with Unique_ID 'PQ-2484883015' has been updated.
# Iteration: 560, Elapsed Time: 130 minutes and 17.31 seconds
# Row with Unique_ID 'PQ-2484876808' has been updated.
# Row with Unique_ID 'PQ-2484837375' has been updated.
# Row with Unique_ID 'PQ-2484603484' has been updated.
# Row with Unique_ID 'PQ-2484603479' has been updated.
# Row with Unique_ID 'PQ-2484403928' has been updated.
# Row with Unique_ID 'PQ-2484308028' has been updated.
# Row with Unique_ID 'PQ-2484290042' has been updated.
# Row with Unique_ID 'PQ-2484282957' has been updated.
# Row with Unique_ID 'PQ-2484154061' has been updated.
# Row with Unique_ID 'PQ-2483940903' has been updated.
# Iteration: 570, Elapsed Time: 131 minutes and 59.42 seconds
# Row with Unique_ID 'PQ-2483799889' has been updated.
# Row with Unique_ID 'PQ-2483771734' has been updated.
# Row with Unique_ID 'PQ-2484145247' has been updated.
# Row with Unique_ID 'PQ-2483671975' has been updated.
# Row with Unique_ID 'PQ-2483404623' has been updated.
# Row with Unique_ID 'PQ-2483205634' has been updated.
# Row with Unique_ID 'PQ-2483015245' has been updated.
# Row with Unique_ID 'PQ-2482345098' has been updated.
# Row with Unique_ID 'PQ-2481455550' has been updated.
# Row with Unique_ID 'PQ-2481455407' has been updated.
# Iteration: 580, Elapsed Time: 133 minutes and 40.62 seconds
# Row with Unique_ID 'PQ-2481396359' has been updated.
# Row with Unique_ID 'PQ-2481221073' has been updated.
# Row with Unique_ID 'PQ-2481189625' has been updated.
# Row with Unique_ID 'PQ-2481096772' has been updated.
# Row with Unique_ID 'PQ-2480891534' has been updated.
# Row with Unique_ID 'PQ-2480650347' has been updated.
# Row with Unique_ID 'PQ-2480089072' has been updated.
# Row with Unique_ID 'PQ-2478817926' has been updated.
# Row with Unique_ID 'PQ-2478726100' has been updated.
# Row with Unique_ID 'PQ-2478657204' has been updated.
# Iteration: 590, Elapsed Time: 135 minutes and 19.62 seconds
# Row with Unique_ID 'PQ-2478200471' has been updated.
# Row with Unique_ID 'PQ-2478150121' has been updated.
# Row with Unique_ID 'PQ-2478163348' has been updated.
# Row with Unique_ID 'PQ-2478076294' has been updated.
# Row with Unique_ID 'PQ-2478010213' has been updated.
# Row with Unique_ID 'PQ-2478009015' has been updated.
# Row with Unique_ID 'PQ-2477722476' has been updated.
# Row with Unique_ID 'PQ-2477267544' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2476560818' has been updated.
# Row with Unique_ID 'PQ-2475861185' has been updated.
# Iteration: 600, Elapsed Time: 137 minutes and 2.36 seconds
# Row with Unique_ID 'PQ-2512319253' has been updated.
# Row with Unique_ID 'PQ-2475619025' has been updated.
# Row with Unique_ID 'PQ-2474589347' has been updated.
# Row with Unique_ID 'PQ-2474588815' has been updated.
# Row with Unique_ID 'PQ-2474348564' has been updated.
# Row with Unique_ID 'PQ-2474275984' has been updated.
# Row with Unique_ID 'PQ-2471081277' has been updated.
# Row with Unique_ID 'PQ-2471053937' has been updated.
# Row with Unique_ID 'PQ-2470787272' has been updated.
# Row with Unique_ID 'PQ-2478178985' has been updated.
# Iteration: 610, Elapsed Time: 138 minutes and 43.87 seconds
# Row with Unique_ID 'PQ-2470409504' has been updated.
# Row with Unique_ID 'PQ-2477837886' has been updated.
# Row with Unique_ID 'PQ-2477837382' has been updated.
# Row with Unique_ID 'PQ-2470134262' has been updated.
# Row with Unique_ID 'PQ-2470059362' has been updated.
# Row with Unique_ID 'PQ-2470009859' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2469952574' has been updated.
# Row with Unique_ID 'PQ-2469847982' has been updated.
# Row with Unique_ID 'PQ-2469823580' has been updated.
# Row with Unique_ID 'PQ-2469556812' has been updated.
# Iteration: 620, Elapsed Time: 140 minutes and 26.30 seconds
# Row with Unique_ID 'PQ-2469417618' has been updated.
# Row with Unique_ID 'PQ-2476490890' has been updated.
# Row with Unique_ID 'PQ-2469350826' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2469112294' has been updated.
# Row with Unique_ID 'PQ-2468959576' has been updated.
# Row with Unique_ID 'PQ-2468818093' has been updated.
# Row with Unique_ID 'PQ-2468590320' has been updated.
# Row with Unique_ID 'PQ-2468022942' has been updated.
# Row with Unique_ID 'PQ-2467848547' has been updated.
# Row with Unique_ID 'PQ-2467782548' has been updated.
# Iteration: 630, Elapsed Time: 142 minutes and 10.78 seconds
# Row with Unique_ID 'PQ-2467659348' has been updated.
# Row with Unique_ID 'PQ-2467551252' has been updated.
# Row with Unique_ID 'PQ-2467525973' has been updated.
# Row with Unique_ID 'PQ-2467506874' has been updated.
# Row with Unique_ID 'PQ-2466104230' has been updated.
# Row with Unique_ID 'PQ-2466104062' has been updated.
# Row with Unique_ID 'PQ-2465948139' has been updated.
# Row with Unique_ID 'PQ-2474392357' has been updated.
# Row with Unique_ID 'PQ-2465901936' has been updated.
# Row with Unique_ID 'PQ-2465821388' has been updated.
# Iteration: 640, Elapsed Time: 143 minutes and 50.47 seconds
# Row with Unique_ID 'PQ-2465669543' has been updated.
# Row with Unique_ID 'PQ-2465669525' has been updated.
# Row with Unique_ID 'PQ-2465570612' has been updated.
# Row with Unique_ID 'PQ-2465487384' has been updated.
# Row with Unique_ID 'PQ-2465486904' has been updated.
# Row with Unique_ID 'PQ-2464845343' has been updated.
# Row with Unique_ID 'PQ-2464566814' has been updated.
# Row with Unique_ID 'PQ-2464604359' has been updated.
# Row with Unique_ID 'PQ-2464541547' has been updated.
# Row with Unique_ID 'PQ-2464494204' has been updated.
# Iteration: 650, Elapsed Time: 145 minutes and 35.34 seconds
# Row with Unique_ID 'PQ-2967214043' has been updated.
# Row with Unique_ID 'PQ-2901792732' has been updated.
# Row with Unique_ID 'PQ-2900527371' has been updated.
# Row with Unique_ID 'PQ-2900817989' has been updated.
# Row with Unique_ID 'PQ-2897461879' has been updated.
# Row with Unique_ID 'PQ-2895137937' has been updated.
# Row with Unique_ID 'PQ-2895038109' has been updated.
# Row with Unique_ID 'PQ-2880296882' has been updated.
# Row with Unique_ID 'PQ-2853253212' has been updated.
# Row with Unique_ID 'PQ-2831429113' has been updated.
# Iteration: 660, Elapsed Time: 147 minutes and 24.24 seconds
# Row with Unique_ID 'PQ-2830473201' has been updated.
# Row with Unique_ID 'PQ-2828934022' has been updated.
# Row with Unique_ID 'PQ-2821029800' has been updated.
# Row with Unique_ID 'PQ-2813853758' has been updated.
# Row with Unique_ID 'PQ-2813715564' has been updated.
# Row with Unique_ID 'PQ-2810235907' has been updated.
# Row with Unique_ID 'PQ-2810039935' has been updated.
# Row with Unique_ID 'PQ-2776475145' has been updated.
# Row with Unique_ID 'PQ-2776232171' has been updated.
# Row with Unique_ID 'PQ-2747239066' has been updated.
# Iteration: 670, Elapsed Time: 149 minutes and 4.30 seconds
# Row with Unique_ID 'PQ-2715702627' has been updated.
# Row with Unique_ID 'PQ-2714237491' has been updated.
# Row with Unique_ID 'PQ-2712884191' has been updated.
# Row with Unique_ID 'PQ-2712125875' has been updated.
# Row with Unique_ID 'PQ-2712111967' has been updated.
# Row with Unique_ID 'PQ-2706110677' has been updated.
# Row with Unique_ID 'PQ-2705184310' has been updated.
# Row with Unique_ID 'PQ-2705174835' has been updated.
# Row with Unique_ID 'PQ-2705118452' has been updated.
# Row with Unique_ID 'PQ-2705046498' has been updated.
# Iteration: 680, Elapsed Time: 150 minutes and 49.74 seconds
# Row with Unique_ID 'PQ-2704990848' has been updated.
# Row with Unique_ID 'PQ-2704785118' has been updated.
# Row with Unique_ID 'PQ-2704701727' has been updated.
# Row with Unique_ID 'PQ-2704810862' has been updated.
# Row with Unique_ID 'PQ-2704162185' has been updated.
# Row with Unique_ID 'PQ-2704112885' has been updated.
# Row with Unique_ID 'PQ-2704062353' has been updated.
# Row with Unique_ID 'PQ-2701133433' has been updated.
# Row with Unique_ID 'PQ-2699929060' has been updated.
# Row with Unique_ID 'PQ-2699842960' has been updated.
# Iteration: 690, Elapsed Time: 152 minutes and 34.70 seconds
# Row with Unique_ID 'PQ-2699818476' has been updated.
# Row with Unique_ID 'PQ-2697460053' has been updated.
# Row with Unique_ID 'PQ-2697139949' has been updated.
# Row with Unique_ID 'PQ-2694229078' has been updated.
# Row with Unique_ID 'PQ-2693284635' has been updated.
# Row with Unique_ID 'PQ-2692022760' has been updated.
# Row with Unique_ID 'PQ-2692589992' has been updated.
# Row with Unique_ID 'PQ-2691422296' has been updated.
# Row with Unique_ID 'PQ-2691196096' has been updated.
# Row with Unique_ID 'PQ-2688971597' has been updated.
# Iteration: 700, Elapsed Time: 154 minutes and 15.52 seconds
# Row with Unique_ID 'PQ-2688770018' has been updated.
# Row with Unique_ID 'PQ-2688471279' has been updated.
# Row with Unique_ID 'PQ-2685980259' has been updated.
# Row with Unique_ID 'PQ-2685931087' has been updated.
# Row with Unique_ID 'PQ-2685773566' has been updated.
# Row with Unique_ID 'PQ-2684680370' has been updated.
# Row with Unique_ID 'PQ-2683958151' has been updated.
# Row with Unique_ID 'PQ-2683126959' has been updated.
# Row with Unique_ID 'PQ-2681503286' has been updated.
# Row with Unique_ID 'PQ-2681382178' has been updated.
# Iteration: 710, Elapsed Time: 155 minutes and 57.18 seconds
# Row with Unique_ID 'PQ-2681200985' has been updated.
# Row with Unique_ID 'PQ-2680317469' has been updated.
# Row with Unique_ID 'PQ-2680250511' has been updated.
# Row with Unique_ID 'PQ-2679710973' has been updated.
# Row with Unique_ID 'PQ-2679655952' has been updated.
# Row with Unique_ID 'PQ-2679590031' has been updated.
# Row with Unique_ID 'PQ-2663982026' has been updated.
# Row with Unique_ID 'PQ-2663430881' has been updated.
# Row with Unique_ID 'PQ-2661844360' has been updated.
# Row with Unique_ID 'PQ-2660777234' has been updated.
# Iteration: 720, Elapsed Time: 157 minutes and 39.10 seconds
# Row with Unique_ID 'PQ-2660673363' has been updated.
# Row with Unique_ID 'PQ-2659697669' has been updated.
# Row with Unique_ID 'PQ-2659394452' has been updated.
# Row with Unique_ID 'PQ-2656541574' has been updated.
# Row with Unique_ID 'PQ-2645378438' has been updated.
# Row with Unique_ID 'PQ-2640917431' has been updated.
# Row with Unique_ID 'PQ-2650975123' has been updated.
# Row with Unique_ID 'PQ-2650975114' has been updated.
# Row with Unique_ID 'PQ-2650974750' has been updated.
# Row with Unique_ID 'PQ-2650974598' has been updated.
# Iteration: 730, Elapsed Time: 159 minutes and 18.19 seconds
# Row with Unique_ID 'PQ-2640096684' has been updated.
# Row with Unique_ID 'PQ-2640012358' has been updated.
# Row with Unique_ID 'PQ-2640009105' has been updated.
# Row with Unique_ID 'PQ-2639875424' has been updated.
# Row with Unique_ID 'PQ-2638574684' has been updated.
# Row with Unique_ID 'PQ-2638461684' has been updated.
# Row with Unique_ID 'PQ-2638275804' has been updated.
# Row with Unique_ID 'PQ-2637586235' has been updated.
# Row with Unique_ID 'PQ-2647676194' has been updated.
# Row with Unique_ID 'PQ-2647628812' has been updated.
# Iteration: 740, Elapsed Time: 160 minutes and 58.53 seconds
# Row with Unique_ID 'PQ-2647477413' has been updated.
# Row with Unique_ID 'PQ-2637265939' has been updated.
# Row with Unique_ID 'PQ-2636364828' has been updated.
# Row with Unique_ID 'PQ-2636155200' has been updated.
# Row with Unique_ID 'PQ-2636123812' has been updated.
# Row with Unique_ID 'PQ-2636118044' has been updated.
# Row with Unique_ID 'PQ-2635919334' has been updated.
# Row with Unique_ID 'PQ-2635876825' has been updated.
# Row with Unique_ID 'PQ-2635844203' has been updated.
# Row with Unique_ID 'PQ-2635700101' has been updated.
# Iteration: 750, Elapsed Time: 162 minutes and 44.33 seconds
# Row with Unique_ID 'PQ-2635684695' has been updated.
# Row with Unique_ID 'PQ-2632124547' has been updated.
# Row with Unique_ID 'PQ-2603938368' has been updated.
# Row with Unique_ID 'PQ-2580664569' has been updated.
# Row with Unique_ID 'PQ-2559402711' has been updated.
# Row with Unique_ID 'PQ-2552585208' has been updated.
# Row with Unique_ID 'PQ-2525093646' has been updated.
# Row with Unique_ID 'PQ-2496990457' has been updated.
# Row with Unique_ID 'PQ-2489528304' has been updated.
# Row with Unique_ID 'PQ-2490851281' has been updated.
# Iteration: 760, Elapsed Time: 164 minutes and 37.02 seconds
# Row with Unique_ID 'PQ-2490848845' has been updated.
# Row with Unique_ID 'PQ-2490848793' has been updated.
# Row with Unique_ID 'PQ-2474378114' has been updated.
# Row with Unique_ID 'PQ-2469983703' has been updated.
# Row with Unique_ID 'PQ-2463570155' has been updated.
# Row with Unique_ID 'PQ-2460078898' has been updated.
# Row with Unique_ID 'PQ-2451256483' has been updated.
# Row with Unique_ID 'PQ-2447800621' has been updated.
# Row with Unique_ID 'PQ-2434446208' has been updated.
# Row with Unique_ID 'PQ-2434110218' has been updated.
# Iteration: 770, Elapsed Time: 166 minutes and 35.78 seconds
# Row with Unique_ID 'PQ-2421891493' has been updated.
# Row with Unique_ID 'PQ-2410842915' has been updated.
# Row with Unique_ID 'PQ-2409726865' has been updated.
# Row with Unique_ID 'PQ-2407626409' has been updated.
# Row with Unique_ID 'PQ-2398826370' has been updated.
# Row with Unique_ID 'PQ-2398423909' has been updated.
# Row with Unique_ID 'PQ-2398312028' has been updated.
# Row with Unique_ID 'PQ-2409946584' has been updated.
# Row with Unique_ID 'PQ-2405422022' has been updated.
# Row with Unique_ID 'PQ-2405410674' has been updated.
# Iteration: 780, Elapsed Time: 168 minutes and 38.31 seconds
# Row with Unique_ID 'PQ-2403415450' has been updated.
# Row with Unique_ID 'PQ-2403409522' has been updated.
# Row with Unique_ID 'PQ-2403409209' has been updated.
# Row with Unique_ID 'PQ-2403408849' has been updated.
# Row with Unique_ID 'PQ-2390060390' has been updated.
# Row with Unique_ID 'PQ-2390207567' has been updated.
# Row with Unique_ID 'PQ-2389699880' has been updated.
# Row with Unique_ID 'PQ-2386682270' has been updated.
# Row with Unique_ID 'PQ-2386392174' has been updated.
# Row with Unique_ID 'PQ-2386258973' has been updated.
# Iteration: 790, Elapsed Time: 170 minutes and 35.65 seconds
# Row with Unique_ID 'PQ-2386109619' has been updated.
# Row with Unique_ID 'PQ-2386069708' has been updated.
# Row with Unique_ID 'PQ-2385836977' has been updated.
# ...
# Row with Unique_ID 'PQ-2755290314' has been updated.
# Row with Unique_ID 'PQ-2753329729' has been updated.
# Row with Unique_ID 'PQ-2747179344' has been updated.
# Row with Unique_ID 'PQ-2740839174' has been updated.
# Row with Unique_ID 'PQ-2794855679' has been updated.
# Row with Unique_ID 'PQ-2794599395' has been updated.
# Row with Unique_ID 'PQ-2794599232' has been updated.
# Row with Unique_ID 'PQ-2737530948' has been updated.
# Row with Unique_ID 'PQ-2734795035' has been updated.
# Iteration: 1220, Elapsed Time: 249 minutes and 54.01 seconds
# Row with Unique_ID 'PQ-2734026315' has been updated.
# Row with Unique_ID 'PQ-2732255776' has been updated.
# Row with Unique_ID 'PQ-2731014111' has been updated.
# Row with Unique_ID 'PQ-2730948947' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2730875330' has been updated.
# Row with Unique_ID 'PQ-2730864235' has been updated.
# Row with Unique_ID 'PQ-2730530812' has been updated.
# Row with Unique_ID 'PQ-2728549024' has been updated.
# Row with Unique_ID 'PQ-2728485787' has been updated.
# Row with Unique_ID 'PQ-2727610098' has been updated.
# Iteration: 1230, Elapsed Time: 251 minutes and 47.68 seconds
# Row with Unique_ID 'PQ-2726789233' has been updated.
# Row with Unique_ID 'PQ-2725594900' has been updated.
# Row with Unique_ID 'PQ-2725367743' has been updated.
# Row with Unique_ID 'PQ-2725177870' has been updated.
# Row with Unique_ID 'PQ-2720490019' has been updated.
# Row with Unique_ID 'PQ-2720100676' has been updated.
# Row with Unique_ID 'PQ-2718529781' has been updated.
# Row with Unique_ID 'PQ-2718099647' has been updated.
# Row with Unique_ID 'PQ-2716267371' has been updated.
# Row with Unique_ID 'PQ-2716784619' has been updated.
# Iteration: 1240, Elapsed Time: 253 minutes and 36.63 seconds
# Row with Unique_ID 'PQ-2712368036' has been updated.
# Row with Unique_ID 'PQ-2709612245' has been updated.
# Row with Unique_ID 'PQ-2708074071' has been updated.
# Row with Unique_ID 'PQ-2699904559' has been updated.
# Row with Unique_ID 'PQ-2697255032' has been updated.
# Row with Unique_ID 'PQ-2697219657' has been updated.
# Row with Unique_ID 'PQ-2696908574' has been updated.
# Row with Unique_ID 'PQ-2695217448' has been updated.
# Row with Unique_ID 'PQ-2679791795' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2676208382' has been updated.
# Iteration: 1250, Elapsed Time: 255 minutes and 23.42 seconds
# Row with Unique_ID 'PQ-2676179740' has been updated.
# Row with Unique_ID 'PQ-2794091670' has been updated.
# Row with Unique_ID 'PQ-2794091226' has been updated.
# Row with Unique_ID 'PQ-2673663455' has been updated.
# Row with Unique_ID 'PQ-2673324948' has been updated.
# Row with Unique_ID 'PQ-2672330708' has been updated.
# Row with Unique_ID 'PQ-2664511759' has been updated.
# Row with Unique_ID 'PQ-2663581550' has been updated.
# Row with Unique_ID 'PQ-2663581091' has been updated.
# Row with Unique_ID 'PQ-2663135240' has been updated.
# Iteration: 1260, Elapsed Time: 257 minutes and 8.55 seconds
# Row with Unique_ID 'PQ-2663135131' has been updated.
# Row with Unique_ID 'PQ-2659017709' has been updated.
# Row with Unique_ID 'PQ-2658482286' has been updated.
# Row with Unique_ID 'PQ-2654391791' has been updated.
# Row with Unique_ID 'PQ-2653898852' has been updated.
# Row with Unique_ID 'PQ-2793851000' has been updated.
# Row with Unique_ID 'PQ-2651920319' has been updated.
# Row with Unique_ID 'PQ-2650165416' has been updated.
# Row with Unique_ID 'PQ-2648324214' has been updated.
# Row with Unique_ID 'PQ-2648319981' has been updated.
# Iteration: 1270, Elapsed Time: 259 minutes and 2.03 seconds
# Row with Unique_ID 'PQ-2645397876' has been updated.
# Row with Unique_ID 'PQ-2644278867' has been updated.
# Row with Unique_ID 'PQ-2641207098' has been updated.
# Row with Unique_ID 'PQ-2641206059' has been updated.
# Row with Unique_ID 'PQ-2640959272' has been updated.
# Row with Unique_ID 'PQ-2638299928' has been updated.
# Row with Unique_ID 'PQ-2636858734' has been updated.
# Row with Unique_ID 'PQ-2635748365' has been updated.
# Row with Unique_ID 'PQ-2635340306' has been updated.
# Row with Unique_ID 'PQ-2635266406' has been updated.
# Iteration: 1280, Elapsed Time: 261 minutes and 11.82 seconds
# Row with Unique_ID 'PQ-2637693028' has been updated.
# Row with Unique_ID 'PQ-2634722016' has been updated.
# Row with Unique_ID 'PQ-2635235941' has been updated.
# Row with Unique_ID 'PQ-2634349423' has been updated.
# Row with Unique_ID 'PQ-2634349385' has been updated.
# Row with Unique_ID 'PQ-2634819395' has been updated.
# Row with Unique_ID 'PQ-2634100414' has been updated.
# Row with Unique_ID 'PQ-2634077078' has been updated.
# Row with Unique_ID 'PQ-2633635235' has been updated.
# Row with Unique_ID 'PQ-2634378831' has been updated.
# Iteration: 1290, Elapsed Time: 263 minutes and 26.80 seconds
# Row with Unique_ID 'PQ-2633520774' has been updated.
# Row with Unique_ID 'PQ-2633345787' has been updated.
# Row with Unique_ID 'PQ-2633188629' has been updated.
# Row with Unique_ID 'PQ-2633008532' has been updated.
# Row with Unique_ID 'PQ-2629103253' has been updated.
# Row with Unique_ID 'PQ-2626791197' has been updated.
# Row with Unique_ID 'PQ-2626284319' has been updated.
# Row with Unique_ID 'PQ-2625974407' has been updated.
# Row with Unique_ID 'PQ-2623910075' has been updated.
# Row with Unique_ID 'PQ-2622321552' has been updated.
# Iteration: 1300, Elapsed Time: 265 minutes and 53.81 seconds
# Row with Unique_ID 'PQ-2618814994' has been updated.
# Row with Unique_ID 'PQ-2613819661' has been updated.
# Row with Unique_ID 'PQ-2610074465' has been updated.
# Row with Unique_ID 'PQ-2607588763' has been updated.
# Row with Unique_ID 'PQ-2606868941' has been updated.
# Row with Unique_ID 'PQ-2606396850' has been updated.
# Row with Unique_ID 'PQ-2603910157' has been updated.
# Row with Unique_ID 'PQ-2596530687' has been updated.
# Row with Unique_ID 'PQ-2595041665' has been updated.
# Row with Unique_ID 'PQ-2591999258' has been updated.
# Iteration: 1310, Elapsed Time: 268 minutes and 0.44 seconds
# Row with Unique_ID 'PQ-2591160472' has been updated.
# Row with Unique_ID 'PQ-2591049308' has been updated.
# Row with Unique_ID 'PQ-2591001991' has been updated.
# Row with Unique_ID 'PQ-2586257130' has been updated.
# Row with Unique_ID 'PQ-2585852200' has been updated.
# Row with Unique_ID 'PQ-2585849024' has been updated.
# Row with Unique_ID 'PQ-2585846390' has been updated.
# Row with Unique_ID 'PQ-2585805458' has been updated.
# Row with Unique_ID 'PQ-2583947366' has been updated.
# Row with Unique_ID 'PQ-2583743053' has been updated.
# Iteration: 1320, Elapsed Time: 270 minutes and 0.31 seconds
# Row with Unique_ID 'PQ-2579427043' has been updated.
# Row with Unique_ID 'PQ-2579071194' has been updated.
# Row with Unique_ID 'PQ-2578715590' has been updated.
# Row with Unique_ID 'PQ-2578700493' has been updated.
# Row with Unique_ID 'PQ-2576697947' has been updated.
# Row with Unique_ID 'PQ-2574996790' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2574258057' has been updated.
# Row with Unique_ID 'PQ-2574035735' has been updated.
# Row with Unique_ID 'PQ-2573802391' has been updated.
# Row with Unique_ID 'PQ-2572825853' has been updated.
# Iteration: 1330, Elapsed Time: 272 minutes and 2.81 seconds
# Row with Unique_ID 'PQ-2572737981' has been updated.
# Row with Unique_ID 'PQ-2572204348' has been updated.
# Row with Unique_ID 'PQ-2572195633' has been updated.
# Row with Unique_ID 'PQ-2572188108' has been updated.
# Row with Unique_ID 'PQ-2571872466' has been updated.
# Row with Unique_ID 'PQ-2567925243' has been updated.
# Row with Unique_ID 'PQ-2567795276' has been updated.
# Row with Unique_ID 'PQ-2562469793' has been updated.
# Row with Unique_ID 'PQ-2561030682' has been updated.
# Row with Unique_ID 'PQ-2557512872' has been updated.
# Iteration: 1340, Elapsed Time: 274 minutes and 9.06 seconds
# Row with Unique_ID 'PQ-2555268779' has been updated.
# Row with Unique_ID 'PQ-2560493142' has been updated.
# Row with Unique_ID 'PQ-2549320805' has been updated.
# Row with Unique_ID 'PQ-2548654125' has been updated.
# Row with Unique_ID 'PQ-2548394829' has been updated.
# Row with Unique_ID 'PQ-2540046181' has been updated.
# Row with Unique_ID 'PQ-2539906572' has been updated.
# Row with Unique_ID 'PQ-2539482641' has been updated.
# Row with Unique_ID 'PQ-2537109181' has been updated.
# Row with Unique_ID 'PQ-2537070647' has been updated.
# Iteration: 1350, Elapsed Time: 276 minutes and 23.72 seconds
# Row with Unique_ID 'PQ-2536662985' has been updated.
# Row with Unique_ID 'PQ-2531473026' has been updated.
# Row with Unique_ID 'PQ-2531324894' has been updated.
# Row with Unique_ID 'PQ-2531153228' has been updated.
# Row with Unique_ID 'PQ-2528368199' has been updated.
# Row with Unique_ID 'PQ-2528274557' has been updated.
# Row with Unique_ID 'PQ-2767061299' has been updated.
# Row with Unique_ID 'PQ-2518901807' has been updated.
# Row with Unique_ID 'PQ-2518642626' has been updated.
# Row with Unique_ID 'PQ-2516048226' has been updated.
# Iteration: 1360, Elapsed Time: 278 minutes and 41.11 seconds
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2515568056' has been updated.
# Row with Unique_ID 'PQ-2514263173' has been updated.
# Row with Unique_ID 'PQ-2513985953' has been updated.
# Row with Unique_ID 'PQ-2513979406' has been updated.
# Row with Unique_ID 'PQ-2509156574' has been updated.
# Row with Unique_ID 'PQ-2508847070' has been updated.
# Row with Unique_ID 'PQ-2508825441' has been updated.
# Row with Unique_ID 'PQ-2497895328' has been updated.
# Row with Unique_ID 'PQ-2491854937' has been updated.
# Row with Unique_ID 'PQ-2490148625' has been updated.
# Iteration: 1370, Elapsed Time: 280 minutes and 57.04 seconds
# Row with Unique_ID 'PQ-2489046366' has been updated.
# Error encountered: 'str' object has no attribute 'items'. Retry 1/5
# Row with Unique_ID 'PQ-2485384535' has been updated.
# Row with Unique_ID 'PQ-2480011920' has been updated.
# Row with Unique_ID 'PQ-2480011792' has been updated.
# Row with Unique_ID 'PQ-2479906884' has been updated.
# Row with Unique_ID 'PQ-2479906122' has been updated.
# Row with Unique_ID 'PQ-2479737224' has been updated.
# Row with Unique_ID 'PQ-2478764296' has been updated.
# Row with Unique_ID 'PQ-2478222689' has been updated.
# Row with Unique_ID 'PQ-2473960339' has been updated.
# Iteration: 1380, Elapsed Time: 283 minutes and 19.43 seconds
# Row with Unique_ID 'PQ-2473435885' has been updated.
# Row with Unique_ID 'PQ-2472950113' has been updated.
# Row with Unique_ID 'PQ-2471035335' has been updated.
# Row with Unique_ID 'PQ-2471034477' has been updated.
# Row with Unique_ID 'PQ-2471113316' has been updated.
# Row with Unique_ID 'PQ-2470885122' has been updated.
# Row with Unique_ID 'PQ-2470881893' has been updated.
# Row with Unique_ID 'PQ-2470557251' has been updated.
# Row with Unique_ID 'PQ-2470149919' has been updated.
# Row with Unique_ID 'PQ-2467233225' has been updated.
# Iteration: 1390, Elapsed Time: 285 minutes and 26.86 seconds
# Row with Unique_ID 'PQ-2459137923' has been updated.
# Row with Unique_ID 'PQ-2458929248' has been updated.
# Row with Unique_ID 'PQ-2458348035' has been updated.
# Row with Unique_ID 'PQ-2458347953' has been updated.
# Row with Unique_ID 'PQ-2457491997' has been updated.
# Row with Unique_ID 'PQ-2457312103' has been updated.
# Row with Unique_ID 'PQ-2454563690' has been updated.
# Row with Unique_ID 'PQ-2454327846' has been updated.
# Row with Unique_ID 'PQ-2453683459' has been updated.
# Row with Unique_ID 'PQ-2449764439' has been updated.
# Iteration: 1400, Elapsed Time: 287 minutes and 48.84 seconds
# Row with Unique_ID 'PQ-2448682116' has been updated.
# Row with Unique_ID 'PQ-2447022002' has been updated.
# Row with Unique_ID 'PQ-2446202734' has been updated.
# Row with Unique_ID 'PQ-2445259662' has been updated.
# Row with Unique_ID 'PQ-2444885402' has been updated.
# Row with Unique_ID 'PQ-2444185296' has been updated.
# Row with Unique_ID 'PQ-2443910600' has been updated.
# Row with Unique_ID 'PQ-2442694837' has been updated.
# Row with Unique_ID 'PQ-2442433683' has been updated.
# Row with Unique_ID 'PQ-2441706684' has been updated.
# Iteration: 1410, Elapsed Time: 290 minutes and 4.96 seconds
# Row with Unique_ID 'PQ-2439129406' has been updated.
# Row with Unique_ID 'PQ-2439128431' has been updated.
# Row with Unique_ID 'PQ-2436263970' has been updated.
# Row with Unique_ID 'PQ-2436777551' has been updated.
# Row with Unique_ID 'PQ-2436268783' has been updated.
# Row with Unique_ID 'PQ-2434909968' has been updated.
# Row with Unique_ID 'PQ-2430513992' has been updated.
# Row with Unique_ID 'PQ-2430038929' has been updated.
# Row with Unique_ID 'PQ-2429093191' has been updated.
# Row with Unique_ID 'PQ-2428809678' has been updated.
# Iteration: 1420, Elapsed Time: 292 minutes and 13.17 seconds
# Row with Unique_ID 'PQ-2428803833' has been updated.
# Row with Unique_ID 'PQ-2426940040' has been updated.
# Row with Unique_ID 'PQ-2426935602' has been updated.
# Row with Unique_ID 'PQ-2426747084' has been updated.
# Row with Unique_ID 'PQ-2424526725' has been updated.
# Row with Unique_ID 'PQ-2422296792' has been updated.
# Row with Unique_ID 'PQ-2420648588' has been updated.
# Row with Unique_ID 'PQ-2418523954' has been updated.
# Row with Unique_ID 'PQ-2417983118' has been updated.
# Row with Unique_ID 'PQ-2415792023' has been updated.
# Iteration: 1430, Elapsed Time: 294 minutes and 21.95 seconds
# Row with Unique_ID 'PQ-2414582108' has been updated.
# Row with Unique_ID 'PQ-2414552196' has been updated.
# Row with Unique_ID 'PQ-2414623079' has been updated.
# Row with Unique_ID 'PQ-2413301368' has been updated.
# Row with Unique_ID 'PQ-2413229345' has been updated.
# Row with Unique_ID 'PQ-2412798916' has been updated.
# Row with Unique_ID 'PQ-2411120191' has been updated.
# Row with Unique_ID 'PQ-2410927665' has been updated.
# Row with Unique_ID 'PQ-2410606776' has been updated.
# Row with Unique_ID 'PQ-2410321551' has been updated.
# Iteration: 1440, Elapsed Time: 296 minutes and 30.92 seconds
# Row with Unique_ID 'PQ-2398519352' has been updated.
# Row with Unique_ID 'PQ-2397943013' has been updated.
# Row with Unique_ID 'PQ-2396474394' has been updated.
# Row with Unique_ID 'PQ-2395456884' has been updated.
# Row with Unique_ID 'PQ-2395333770' has been updated.
# Row with Unique_ID 'PQ-2395206254' has been updated.
# Row with Unique_ID 'PQ-2393720337' has been updated.
# Row with Unique_ID 'PQ-2393258832' has been updated.
# Row with Unique_ID 'PQ-2393250959' has been updated.
# Row with Unique_ID 'PQ-2393244245' has been updated.
# Iteration: 1450, Elapsed Time: 298 minutes and 35.39 seconds
# Row with Unique_ID 'PQ-2385545404' has been updated.
# Row with Unique_ID 'PQ-2383658410' has been updated.
# Row with Unique_ID 'PQ-2377738991' has been updated.
# Row with Unique_ID 'PQ-2367463486' has been updated.
# Row with Unique_ID 'PQ-2367458875' has been updated.
# Row with Unique_ID 'PQ-2361958589' has been updated.
# Row with Unique_ID 'PQ-2377184835' has been updated.
# Row with Unique_ID 'PQ-2377184755' has been updated.
# Row with Unique_ID 'PQ-2377183973' has been updated.
# Row with Unique_ID 'PQ-2377183264' has been updated.
# Iteration: 1460, Elapsed Time: 300 minutes and 41.57 seconds
# Row with Unique_ID 'PQ-2353921308' has been updated.
# Row with Unique_ID 'PQ-2354623816' has been updated.
# Row with Unique_ID 'PQ-2353566334' has been updated.
# Row with Unique_ID 'PQ-2350780648' has been updated.
# Row with Unique_ID 'PQ-2350762315' has been updated.
# Row with Unique_ID 'PQ-2350534583' has been updated.
# Row with Unique_ID 'PQ-2350179355' has been updated.
# Row with Unique_ID 'PQ-2350178385' has been updated.
# Error encountered: 429 Resource has been exhausted (e.g. check quota).. Retry 1/5
# Error encountered: 429 Resource has been exhausted (e.g. check quota).. Retry 2/5
# Error encountered: 429 Resource has been exhausted (e.g. check quota).. Retry 3/5
# Error encountered: 429 Resource has been exhausted (e.g. check quota).. Retry 4/5
# Error encountered: 429 Resource has been exhausted (e.g. check quota).. Retry 5/5
# Failed to process unique_id PQ-2342968310 after 5 attempts. Stopping.
