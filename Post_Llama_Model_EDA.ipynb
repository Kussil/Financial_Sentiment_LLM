# %% [markdown]
# <a href="https://colab.research.google.com/github/Kussil/Financial_Sentiment_LLM/blob/main/Post_Llama_Model_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Connection to GitHub repository
# Import GitHub token with Google secrets and clone the repository
GITHUB_TOKEN = userdata.get('github')
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
# !git clone  https://{GITHUB_TOKEN}@github.com/Kussil/Financial_Sentiment_LLM.git
# Out:
# Cloning into 'Financial_Sentiment_LLM'...
# remote: Enumerating objects: 3001, done.
# remote: Counting objects: 100% (567/567), done.
# remote: Compressing objects: 100% (265/265), done.
# remote: Total 3001 (delta 327), reused 517 (delta 298), pack-reused 2434
# Receiving objects: 100% (3001/3001), 509.81 MiB | 13.03 MiB/s, done.
# Resolving deltas: 100% (1959/1959), done.
# Updating files: 100% (1214/1214), done.

# %%
path = "/content/Financial_Sentiment_LLM/03_Sentiment_Analysis/Revised_notebooks/Full_data_LLama_model_sentiment_analysis_results.csv"
llama_output = pd.read_csv(path)

# %%
# mapping original column/categories names to generalized version for visualization purposes
column_mapping = {
    'Finance': 'Finance',
    'Production': 'Production',
    'Reserves / Exploration / Acquisitions / Mergers / Divestments': 'Reserves/M&A',
    'Environment / Regulatory / Geopolitics': 'Regulatory',
    'Alternative Energy / Lower Carbon': 'Green Energy',
    'Oil Price / Natural Gas Price / Gasoline Price': 'OG Price'
}

# Rename the columns in the DataFrame
llama_output.rename(columns=column_mapping, inplace=True)

# Update the sentiment_columns list with the new names
sentiment_columns = ['Finance', 'Production', 'Reserves/M&A', 'Regulatory', 'Green Energy', 'OG Price']

# %%
# 1. Check for inconsistency in all sentiment categories
def check_sentiment_consistency(value):
    valid_sentiments = ['Positive', 'Neutral', 'Negative', 'mixed', 'Error', 'N/A', 'Other']
    return value in valid_sentiments

# Check inconsistency across all sentiment categories
inconsistent_data = llama_output[sentiment_columns].applymap(lambda x: not check_sentiment_consistency(x))
inconsistent_counts = inconsistent_data.sum()

print("Inconsistent sentiment values:")
print(inconsistent_counts)
# Out:
# Inconsistent sentiment values:
# Finance          419
# Production       555
# Reserves/M&A     617
# Regulatory       743
# Green Energy    2422
# OG Price         775
# dtype: int64

# %% [markdown]
# ***Findings***
#
# Llama model output results show very inconsistent results in terms of sentiment variables different from predefined by the prompt

# %%
# Printing out unique sentiment variables per each category for QC
for column in sentiment_columns:
    print(f"\nUnique values in {column}:")
    unique_values = llama_output[column].unique()
    print(unique_values)
    print(f"Total unique values in {column}: {len(unique_values)}")
# Out:
# Unique values in Finance:
# ['Neutral' 'Positive' 'Negative' '[Neutral]' 'NR' 'N' 'NR-Not Ranked'
#  'Error: Max retries reached' '[Positive]' 'N1B' 'NES' 'Mixed' 'N Relic'
#  'No JSON found']
# Total unique values in Finance: 14
#
# Unique values in Production:
# ['Positive' 'Neutral' 'Negative'
#  'Positive (small increase in U.S. production, likely 300,000 b/d to an estimated 13.2 mmb/d)'
#  'Mixed (Positive and Negative)' 'Negative/Positive (Mixed Sentiment)'
#  '[Neutral]' 'Slight Negative'
#  'Positive (6.0% increase in crude oil production, 7.3% increase in NGL production)'
#  'Positive (median increase of 0.4% in crude oil production, 5.1% in NGL production, and 4.8% in natural gas production)'
#  'N-Q'
#  'Positive (2.1% increase in crude oil production, 7.3% increase in natural gas production)'
#  'Positive (6.4% increase expected)'
#  'Mixed (Positive for crude oil, Neutral for NGL, Positive for natural gas)'
#  'Negative (3.0% decrease in NGL production and 0.7% increase in crude oil production expected)'
#  'Negative (0.7% increase in crude oil production, 3.0% decrease in NGL production)'
#  'Positive (median increase of 0.6% in crude oil production and 1.7% in NGL production)'
#  'N' 'Mixed' 'NANY DESCRIPTION'
#  'Negative (0.5% decrease in crude oil production and 2.8% reduction in natural gas production)'
#  'Mixed (Neutral/Negative)'
#  'Positive (2% decrease in crude oil production and 4.4% increase in NGL production)'
#  '-14% (Negative)' 'Neutral to Negative' 'Neutral/Negative'
#  'Negative/Neutral'
#  'Positive (5.3% increase in NGL production vs 2019 levels)'
#  '[No mention of production in the article]' 'Error: Max retries reached'
#  'Positive (14% increase in crude oil production, 10% increase in NGL production)'
#  '-Negative' 'Negative/Positive (mixed sentiment)'
#  'Negative (slowed production, expected 3% growth in 2019)'
#  'Positive/Negative' 'Negative (pulls back in the interim)' '[Sentiment]'
#  'Negative (-4.8% to -47%)'
#  'N2.2 MMb/d, in 202- (depending on coronavirus recovery and geopolitics)'
#  'N/d' 'N/A (No sentiment expressed)'
#  'Positive (due to small increase in domestic production)' 'NR'
#  'Positive (N reflects strong supply discipline)' '[No sentiment]'
#  'Negative (concerns over supply discipline)'
#  'Partly Negative, partly offset by concerns over the state of the economy in China.'
#  'Negative (-15.0%) vs 8.0% gain in S&P 1500 Composite Index'
#  'Positive (6.0% increase in crude oil, 7.3% increase in NGL, and 4.0% increase in natural gas)'
#  'Mixed (Negative and Positive)' 'Negative/Concerned'
#  'N/A (mixed sentiment)' 'N but we think risks remain high'
#  'Negative (Nled by Saudi Arabia and Russia)'
#  'Positive (0.8% increase in crude oil production, 3.6% increase in NGL production, and 4.6% increase in natural gas production)'
#  'Mixed (Positive/Negative)' '[No sentiment information provided]'
#  'Positive (N% over projected 2021 levels)' '[Positive]'
#  'Positive/Negative (depending on Canadian exposure)'
#  'Positive (median increase of 6.4% in natural gas production, median decrease of 3.0% in NGL production)'
#  'N/A (no data provided)' '[No sentiment mentioned]' '[No Sentiment]'
#  'Neutral to Positive'
#  'Negative (due to expected decrease in crude oil and natural gas production)'
#  'Negative (various negative sentiments)' 'E-Positive'
#  'Positive (anticipating lower US production and higher Canadian production)'
#  '[Not applicable]' 'Pessimistic' 'Nillate'
#  'N some initial cause for concern' 'Positive/Neutral'
#  'Negative (N shifting towards slower growth)'
#  'Mixed (Positive & Negative)' 'N (negative) towards slower growth'
#  'N/A (no relevant information)'
#  'Negative (due to high cost structure and potential failure of exploration efforts)'
#  'NIO' '[Negative]' '[Not Applicable]' 'Unknown' 'No JSON found'
#  'N.Notes Receivable from Participants' 'N0'
#  'Mixed (Positive and Neutral)' '[None]' '[No Mention]' '[No category]']
# Total unique values in Production: 90
#
# Unique values in Reserves/M&A:
# ['Neutral' 'Positive' 'Mixed (Positive and Negative)' 'Negative'
#  '[Neutral]' 'N Ltd.' 'N/A (not applicable)' 'No Sentiment'
#  'N/A (no mention of sentiment)' 'N/d' 'ND (No clear sentiment)' 'Nmb/d'
#  'NQ (No Quantifiable Information)' 'N'
#  'Positive (median increase of just 8.8% in capex)'
#  'N/A (no specific sentiment mentioned)'
#  'Mixed (includes positive and negative comments)' 'NR'
#  'Not Available (NM)' 'N.S.' 'Mixed' 'Mixed (both positive and negative)'
#  'N/b' 'Negative/Neutral'
#  'Negative (E&Ps are expected to cut capex by 45%)'
#  'Positive/Negative (dependent on operator)' '-47% (Negative)' 'Ncall'
#  'N/A (no information provided)'
#  '[No mention of reserves, exploration, acquisitions, mergers, or divestments in the article]'
#  'Error: Max retries reached'
#  'NA (no direct mention of reserves or exploration)'
#  'Mixed (Neutral and Negative)' 'Mixed (positive/negative)'
#  'Mixed (some positive, some negative)' 'Not Applicable' '[Sentiment]'
#  'NR-Not Ranked' 'Not Available' 'N (Neutral)' 'P' 'NU'
#  'N/A (No sentiment expressed)' 'N/A (no mention)'
#  'Negative (potential for OPEC+ discipline to slip in 2024)'
#  'Partly negative (due to concerns over the state of the economy in China)'
#  'Positive (collective 3.7 mmb/d of production cuts, extra voluntary cuts by Saudi Arabia and Russia)'
#  'Positive/Negative (depending on country)'
#  'Positive (withdrew crude oil from Strategic Petroleum Reserve in 2022)'
#  'Positive (release of 1 million barrels of crude oil per day from the Strategic Petroleum Reserve)'
#  'NM' 'NA (Not Available)' 'N.l.c.' 'Neutral/Negative' 'N.c.'
#  'Mixed (Positive for OPEC+, Negative for Russia)'
#  'Mixed (both Neutral and Negative)' 'Mixed (Positive/Negative)'
#  'Mixed (neutral on SPR drawdown, neutral on reserves)'
#  'Negative (due to challenges of selling assets to pay down debt)'
#  'N/A (no specific mention)' '[No sentiment information provided]'
#  'N/A (no sentiment indicated)' 'Absent' 'Mixed (Negative and Neutral)'
#  'N/A (no relevant information)' 'N/gallon' 'NA-Not Available'
#  'N/A (no data provided)' 'Uncertain' 'N/A (No sentiment indicated)'
#  'Negative (Note: The article does not specifically discuss these topics, but based on the general context of oil and gas refining and marketing, it can be inferred that there may be some negative sentiment related to acquisitions, mergers, or divestments.)'
#  '[No sentiment mentioned]' '[No Sentiment]' 'Nsolutions'
#  'N/A (Not Mentioned)' 'Not applicable' 'N0' 'No Sentiment Mentioned'
#  'Not mentioned' '[Not applicable]' 'Positive/Negative'
#  'Mixed (some risk, some achievement)' 'N0.74' 'Mixed (Neutral/Negative)'
#  '[Positive]' 'Mixed (Neutral and Positive)' 'Nillate'
#  'Mixed (some Neutral, some Negative)' 'N/A (no clear sentiment)'
#  'N/A (No specific information provided)'
#  'Mixed (some positive, some neutral)'
#  'Mixed (Positive for some companies, Negative for others)'
#  'Positive (potential upside from exploration efforts)' 'NIO'
#  'Mixed (Negative and Positive)' '[Not Applicable]' 'N opportunity'
#  'Unknown' 'No JSON found' '[No Mention]' 'Mixed (Positive and Neutral)'
#  'Negative/Undecided']
# Total unique values in Reserves/M&A: 103
#
# Unique values in Regulatory:
# ['Neutral' 'Negative' 'Negative (potential risk)'
#  'Negative (potential for adverse economic news from China)'
#  'Negative (unless Israel-Gaza war spreads to Iran and adversely affects Iran’s crude oil production)'
#  'Negative (unless Israel-Gaza war spreads to Iran)'
#  'Neutral (N) but remain below $3.00 per million BTU in 2024'
#  'Neutral/Negative'
#  "Neutral (with a hint of Negative, as there is no substantial geopolitical risk premium for energy prices unless the Israel-Gaza war spreads to Iran and adversely affects Iran's crude oil production)"
#  'Negative (potential)'
#  'Negative/Negative Risk Premium for energy prices, unless the Israel-Gaza war spreads to Iran and adversely affects Iran’s crude oil production (currently 3.2 mmb/d)'
#  'NCE' 'Slight Negative'
#  'Negative (referencing withdrawal of crude oil from Strategic Petroleum Reserve)'
#  '[Negative]' '[Neutral]' 'No Sentiment' 'Negative/Neutral'
#  'Negative (no mention of adverse impacts from weather in the Bakken)'
#  'Negative (mention of sanctions against Iran)'
#  'Negative ( possibility of lifting sanctions against Iran)'
#  'Negative (against Iran)'
#  'Negative (due to mention of sanctions and potential impact on high oil prices)'
#  'Negative (referring to possible sanctions lift on Iran)'
#  'Mixed (Neutral and Negative)'
#  'Negative/Negative (potential for Iranian crude oil exports to hit the market)'
#  'Mixed (Negative: sanctions against Iran, Positive: urgency for meeting immediate demand and discourages further storage)'
#  'N/A (not applicable)' 'Mixed (Positive and Negative)'
#  'Negative/Neutral ( mention of sanctions against Iran and potential impact on oil prices)'
#  'Negative (due to mention of sanctions and high oil prices)' 'N/d'
#  'Mixed (Negative and Positive)'
#  'Negative (due to mention of high oil prices and potential sanctions on Iran)'
#  'Negative (mentions sanctions against Iran and potential impact on oil prices)'
#  'Mixed (Neutral/Negative)'
#  'Negative ( mention of sanctions against Iran)' 'N'
#  'Negative/Positive (anticipates possible U.S.-imposed sanctions on Russia, but believes President Biden has little appetite for policy moves that would cause further pain at the pump for U.S. drivers)'
#  'N.S.' 'N (neutral/co-see some possibility)' 'Positive'
#  'Negative (discourages further storage)'
#  'Negative/Neutral (concern about price relapse)'
#  'N/A (no specific sentiment mentioned)'
#  'Negative (mention of federal permitting practices and potential changes after 2021 elections)'
#  'UR' 'Not Available (NM)' 'N/A (not mentioned)'
#  'Positive (initially, then Neutral)' 'N/A (no mention)' 'NCFA'
#  'Negative (due to drone strikes on Saudi Arabia)' '-33% (Negative)'
#  'Mixed (Positive/Negative)' 'Positive/Negative (wildcards)'
#  'Positive/Negative (depending on wildcards)'
#  'Mixed (Negative and Neutral)'
#  'Mixed (includes negative sentiment towards oil demand decline and potential OPEC cuts, but also mentions a potential thawing of relations between Saudi Arabia and Russia)'
#  'Positive (mention of potential thawing of relations between Saudi Arabia and Russia, and a faster than expected improvement in the fight against the coronavirus)'
#  'Negative (market reacting faster than consensus estimates, potential thawing of relations between Saudi Arabia and Russia, faster than expected improvement in the fight against coronavirus, and a sizable cut in production by the U.S. shale community)'
#  'Negative (due to concerns about global economy and deceleration of oil demand)'
#  'N/A (no information provided)'
#  '[No mention of environment, regulatory, or geopolitics in the article]'
#  'Error: Max retries reached' 'N/A (Not applicable to this article)'
#  'Neutral (discussion of global demand and OPEC supply)'
#  'Negative (due to pessimistic concerns about the global economy)'
#  'NA (no direct mention of environment, regulatory, or geopolitics)'
#  "Negative (N attacks on Saudi Arabia's crude production and processing facilities, the subsequent boost to oil prices)"
#  'Negative (Trade war, weakening demand)' 'N/A (no sentiment mentioned)'
#  'Negative (NAngola)'
#  'Negative (due to concern over global economy and Ukraine war)'
#  'Negative/Positive' 'Negative (due to mention of potential dividend cut)'
#  '[Sentiment]'
#  'Positive (thawing of geopolitical relations between Saudi Arabia and Russia)'
#  'Negative ( mentions Israel-Gaza war and Russia-Ukraine war, but does not expect a substantial impact on energy prices)'
#  'Negative (minor)' 'N/A (No sentiment expressed)' 'N.g.'
#  'Negative/Neutral (due to mentions of geopolitical risks and potential saber-rattling)'
#  'Negative (N to Iran)'
#  "Negative ( mention of potential war and adverse effects on Iran's crude oil production)"
#  'Neutral (with a mention of potential geopolitical risk)'
#  'Negative (some)'
#  'Positive (mention of potential OPEC+ production cuts, but also a note on the need for resilience to future supply shocks)'
#  'NR' 'Negative (concerns over state of economy in China)'
#  'Negative (risk of recession)'
#  'Negative/Partly Offset by Concerns over State of Economy'
#  'Neutral/Negative (depending on country)' 'N but we think risks remain'
#  'N (Negative, mentions potential further sanctions against Russia)'
#  'Positive/Negative (depending on global economy)' 'Positive/Negative'
#  'Negative (due to potential supply shocks and sanctions)'
#  'Positive/Negative (mixed sentiment)'
#  'Negative (reducing resilience to future supply shocks, sanctions against Russia)'
#  'Negative/Negative (criticizing lack of absolute emissions Scope 3 interim targets)'
#  'Negative/Concerned'
#  'Mixed (includes both positive and negative sentiments)'
#  'Negative (Nled by Ukraine invasion)'
#  'Negative/Concerned (Ukraine invasion)' 'Negative/Positive (mixed)'
#  'Mixed' 'Negative (due to concerns over the Ukraine invasion)'
#  'Negative/Positive (depending on the scenario)'
#  'Negative (concern about SPR drawdown impact on resilience to future supply shocks)'
#  'Mixed (some negative, some neutral)'
#  'Negative (due to risks of a sharp recession)'
#  'Mixed (includes Positive and Negative sentiments)'
#  'Negative (OPEC-Plus cuts, uncertainty over coronavirus recovery)'
#  '[No sentiment information provided]'
#  'Negative (discusses EIA estimates of price increases)'
#  'Negative/Positive (dependent on specific points)'
#  'Mixed (Positive & Negative)'
#  'Negative (mention of sulfur emissions reduction and price changes)'
#  'Negative (due to uncertainty over how long the coronavirus may damage crude oil demand)'
#  'Positive/Negative (dependent on perspective)'
#  'Negative (referring to the pandemic)'
#  'Negative (low U.S. onshore capex budgets)'
#  'Negative (IMO 2020 regulations and potential moratoriums in Alberta)'
#  'Negative/Positive (emissions regulations and impact of IMO 2020)'
#  'NR-Not Ranked' 'N/A (no data provided)' 'N/A (No sentiment indicated)'
#  'Mixed (Neutral, Positive)' 'Negative (NCAPEx fell more than 40%)'
#  '[No sentiment mentioned]' '[No Sentiment]'
#  'Negative (concern over pandemic and OPEC-Plus cuts)'
#  'Negative (oil price)'
#  'Negative (stringent energy regulations and potential for moratoriums)'
#  'N/bbl' 'Not mentioned' '[Not applicable]' 'Not applicable' 'Pessimistic'
#  'Negative/Negative' 'N/A (multiple wildcards, no clear sentiment)'
#  'N/A (No specific information provided)'
#  'Neutral/Negative (due to mention of trade tensions and potential supply deficit)'
#  'Negative (due to mentions of volatility in the refining industry)'
#  'Negative (Concerns about OPEC production growth and geopolitical risks)'
#  'N.A.' 'Mixed (Negative, Positive)' '[Not Applicable]' 'N opportunity'
#  'Mixed (Positive, Negative)' 'Mixed (Negative, Neutral)'
#  'Mixed (Neutral and Positive)' 'Mixed (Positive, Neutral, Negative)'
#  'Unknown' 'Nan' 'Mixed (Negative, Neutral, Positive)' 'No JSON found'
#  'Risks and Uncertainties' 'N0' '[None]' '[No category]'
#  'Mixed (Negative)' 'Mixed (Neutral & Negative)' 'N3'
#  'Positive and Neutral']
# Total unique values in Regulatory: 166
#
# Unique values in Green Energy:
# ['Not applicable' 'Negative' 'Not Applicable' 'None (not mentioned)'
#  'Neutral' 'Not mentioned' 'N/A (Not mentioned)' 'Not Mentioned'
#  'Not applicable (not mentioned)'
#  'Not Applicable (No mention in the article)' 'NA (Not Applicable)'
#  'None mentioned' 'N/A (not mentioned)' 'N/A (no sentiment detected)'
#  'N/A (Not Applicable)'
#  'Not Applicable (since this article is about traditional energy sources)'
#  'NQ' 'Not Relevant' 'Not applicable (no mention)'
#  'N-rate (Not relevant to the article)' 'Not Applicable (no mention)'
#  'N/A (Not applicable)' 'Not Available' 'N/A (not applicable)' 'N/b'
#  'Not applicable (N/A)' 'N/b (Not mentioned)'
#  'Not Applicable (no mention of alternative energy or lower carbon)'
#  'N/A (no relevant information)' 'Positive' 'N' 'None (Not Mentioned)'
#  'Not Provided (N ESP)' 'N. Still' 'N/A (Not Relevant)' 'NCE' 'NQT'
#  '[Neutral]' 'Ns' 'None (Not mentioned)' 'Not Applicable (No mention)'
#  'Non' 'Nof'
#  'Not applicable (article is about oil and gas exploration and production)'
#  'N/A (no mention)' 'Not Relevant (no information provided)'
#  'Not Applicable (N/A)' 'N.S.' 'No Sentiment'
#  'Not Applicable (Oil and Gas related)' 'NDR'
#  'Not applicable (this article is about oil and gas, not alternative energy)'
#  'Not Applicable (NA)' 'N/d' 'Nan' 'Nerra' 'N Ltd.'
#  'Not applicable (article focuses on traditional energy sector)'
#  'Not FANG'
#  'Negative (not mentioned explicitly, but implied by the focus on oil and gas exploration)'
#  'Nmb/d'
#  'Not Applicable (as the article does not mention alternative energy or lower carbon)'
#  'Not applicable (article does not mention alternative energy or lower carbon)'
#  'N/A (no mention of sentiment)' 'Not Relevant (article does not mention)'
#  'Not Given' 'ND (No clear sentiment)'
#  'Not Applicable (no relevant information provided)' 'N-Q'
#  '[Not mentioned]' 'Ncf'
#  'Not Applicable (Oil and Gas Exploration and Production)'
#  'N.S. (Not Significant)' 'N/A (Not Mentioned)'
#  'Not Applicable (no mention of alternative energy)'
#  'Not Relevant (No mention)'
#  'Not applicable (no mention of alternative energy)'
#  'Not Applicable (None)' 'N/A (no information provided)'
#  'None (not relevant)' 'Not applicable (no relevant information provided)'
#  'Not applicable (article does not discuss alternative energy)'
#  'N/A (no specific sentiment mentioned)'
#  'Not applicable (article does not mention alternative energy/lower carbon)'
#  'None (no mention)' 'N/A (not mentioned in the article)' 'NX'
#  'Not Available (NA)' 'NB all-stock deal' 'N0.10 loss/share' 'N0 levels'
#  'Not Rated' 'Not applicable (Oil and Gas industry)' 'NR'
#  'None (Not Relevant)' 'NR-Not Ranked' 'Not Available (NR)' 'N0'
#  '[Not Mentioned]' 'Not Categorized' 'No Sentiment Mentioned' 'Nil HOLD'
#  'Not applicable (NA)' 'Nil'
#  'Negative (suspension of $5 billion annual share repurchase program)'
#  'N Nil -60% Nil SELL' 'Not applicable (finance report)' 'NTD'
#  'Not Present' 'NCFA' 'Absent' 'Nable' 'Not Categorized (N CFA)'
#  'Not applicable (article does not mention this topic)'
#  'Not applicable (mentioned as a separate topic)' 'Nil HOLD (Neutral)'
#  'None/Not mentioned' 'Ncall' 'N/C' 'Not Applicable (Not Relevant)'
#  'None/Mentioned' 'NIMO' 'Not Applicable (Not Relevant to the Article)'
#  'None (Not Applicable)'
#  '[No mention of alternative energy or lower carbon in the article]'
#  'NMB/d' 'Error: Max retries reached'
#  'Not applicable (no mention of alternative energy or lower carbon)'
#  'N/A (Not applicable to this article)' 'N HOLD'
#  'NA (no direct mention of alternative energy or lower carbon)'
#  'NOS (Not Operationally Significant)' 'N (Not mentioned)'
#  'Not Applicable (does not relate to this article)' 'NARGUS'
#  'None (not applicable)'
#  'Negative (not explicitly mentioned, but implied through the mention of oil and gas prices)'
#  'N/A (Not discussed)' 'Not Relevant (no mention)' 'Not Applicable (NYTD)'
#  'Not Available (N/A)' 'Not applicable (article does not mention)'
#  '[Positive]' 'Positive (share buybacks, low debt)' '[Sentiment]'
#  'Not applicable (since it is a refining and marketing sub-industry)' 'NB'
#  'NU' 'N5' 'N/A (No sentiment expressed)' 'Nsy.'
#  'Not Applicable (not mentioned)' 'N.g.' 'Nillate'
#  'Positive (mentioning renewable energy making inroads)' 'Positive (some)'
#  'Not Applicable (since no relevant information is provided)' 'N-WT'
#  '[No sentiment]' 'Not Applicable (Not discussed in the article)'
#  'Not Offered (Variable)' 'Unknown' 'None (Not applicable)'
#  'Not Applicable (No mention of alternative energy or lower carbon in the article)'
#  'Not Applicable (N3)'
#  'Not Relevant (since there is no mention of alternative energy or lower carbon in the article)'
#  'NA (Not Available)' 'N2 (Not Applicable)' 'N.l.c.' 'NI' 'N.c.'
#  'Not applicable (article is focused on oil and gas industry)'
#  'Not Ranked' 'Not Pass Muster'
#  'Not applicable (mentioned briefly, but not a main focus)'
#  'N/A (no specific mention)' 'Ns (No sentiment detected)' 'NQPEC+'
#  'Not applicable ( Oil & Gas industry)' 'NQPEC' 'Non-OPEC actors'
#  'Not Applicable (article does not mention Alternative Energy/Lower Carbon)'
#  'Nx (No Sentiment)' 'N/A (No mention)'
#  '[No sentiment information provided]'
#  'N/A (no relevant information provided)' 'Negative (no mention)'
#  'N/A (no sentiment indicated)'
#  'Not Relevant (as there is no mention of these topics)'
#  'Not applicable (this section is not relevant to the article)' 'N/gallon'
#  'N1' 'Not Applicable (N1)' 'NA-Not Available' 'N/A (no data provided)'
#  'Not Meaningful' 'N/A (No sentiment indicated)'
#  'Not applicable (The article does not specifically discuss alternative energy or lower carbon initiatives.)'
#  'Not applicable (not mentioned in the article)'
#  '[No sentiment mentioned]' '[No Sentiment]' 'Not Applicable (N-oriented)'
#  'NFA' 'N/A (no sentiment)' 'Not Meaningful (for 2020)' 'N0B' 'N/bbl'
#  'N/A (Not relevant)' '[Not applicable]' 'Not Provided' 'N0.74' 'N20'
#  'NR (Not Ranked)' 'Not Applicable (N0)'
#  'N/A (not relevant to the article)'
#  'N/A (No specific information provided)' 'N5%' 'N.L.C.' 'N-industry'
#  'None (No mention)'
#  'Not Relevant (article is about oil refining and marketing)'
#  'Not Warranted' 'Not Warranted to be Accurate, Complete or Timely' 'N.A.'
#  'N:VLP' 'Nof this information.' 'NIO' 'Mixed'
#  'Mixed (some positive, some negative)' '[None]'
#  'Mixed (Both Positive and Negative)' 'Mixed (Negative and Positive)'
#  'Positive/Negative' '[Not Applicable]' 'N opportunity' 'Neutral/Positive'
#  'Mixed (Positive, Neutral)' 'Mixed (Positive and Negative)'
#  'Mixed (both Positive and Negative)' 'Unmentioned' 'P' 'No JSON found'
#  'NN' 'N.FAIR VALUE MEASUREMENTS' '[No Mention]' '[No category]'
#  'Negative (referring to GHG emissions)' 'Mixed (Positive & Neutral)'
#  'Niscernible' 'N3']
# Total unique values in Green Energy: 250
#
# Unique values in OG Price:
# ['Neutral' 'Positive' 'Negative' 'Not applicable'
#  'Positive (prices will improve marginally, but remain below $3.00 per million BTU in 2024)'
#  'NQ' 'Not Relevant' 'Not mentioned'
#  'Neutral (as prices are expected to improve marginally, but remain below $3.00 per million BTU in 2024)'
#  'Not Applicable' 'N/A (Not Relevant)' 'Mixed' '[Neutral]'
#  'Mixed (caution on prices falling, but current high levels are attractive for dividend yield)'
#  'Slight Positive' 'Mixed (Positive and Negative)'
#  'Positive (oil prices expected to average $3.40 per MMBtu in 2023, rising to $4.04/MMBtu in 2024)'
#  'Positive (expectation of high prices, but no specific sentiment)'
#  'Positive (expected increase in prices, but no sentiment on the prices themselves)'
#  'Positive (due to expected increase in crude oil production, but negative due to expected high refined product prices)'
#  'Positive (projected average prices of $7.15 per MMBtu in 2022 and $6.00/MMBtu in 2023)'
#  'Positive (mentioning relief from high prices)' 'Positive/Negative'
#  'Negative (mention of high oil prices)'
#  'Negative (due to high oil prices)'
#  'Negative (although it may do little to blunt high refined product prices, since refineries are already running near full-blast as it is)'
#  'Negative (mentions high prices and potential relief from increased production)'
#  'N-Q'
#  'Negative/Positive (anticipates possible impact of sanctions on oil prices, but notes that even if cooler heads prevail, fundamentals point to crude prices in the $80+/b range)'
#  'Negative (with a note of relief due to expected increase in production and decrease in prices)'
#  'Not Applicable (Oil and Gas Exploration and Production)'
#  'Negative (N% over projected 2022 levels)'
#  'Positive (mention of higher prices)' 'Not Mentioned'
#  'Negative (crude oil and natural gas prices expected to increase)'
#  'Positive (Henry Hub natural gas prices to average $3.17 per MMBtu in 2021)'
#  'Mixed (Positive trend expected for Henry Hub natural gas prices, Neutral trend expected for crude oil prices)'
#  'Positive (Henry Hub natural gas prices expected to average $3.17/MMBtu in 2021, up from $2.11 in 2019)'
#  'Positive (Henry Hub natural gas prices expected to average $3.17 per MMBtu in 2021, up from $2.11 in 2019)'
#  'Positive (Henry Hub natural gas prices to average $3.07 per MMBtu in 2021, rising to $3.40/MMBtu in 2022)'
#  'N' 'N-Estimated' 'Negative (decrease in oil and natural gas prices)'
#  'Not Categorized' 'No Sentiment Mentioned' 'Mildly Positive'
#  'Mixed (Positive in 2020, Negative in 2021)'
#  'Mixed (Negative for 2020, Positive for 2021)'
#  'Near the low end of the historical range (Negative)' 'NCE'
#  'Negative (energy market instability, price fluctuations)'
#  'Positive (initially, then Neutral)' 'Not Present' 'NCFA'
#  'Positive (increased oil prices due to geopolitical risk premium)'
#  'No Sentiment' 'None mentioned' 'Not applicable (no mention)'
#  'Negative (WTI crude oil prices averaging $35/barrel in 2020, rising to $44/barrel in 2021, with risk to those estimates being to the downside)'
#  '-10% to -37% (Negative)'
#  'Negative (median increase of just 0.3% in natural gas production vs 2020 levels)'
#  'N/A (no information provided)' 'Error: Max retries reached'
#  'Negative (discussing decreased oil prices, with a 7.6% decline in the S&P Oil & Gas Exploration & Production Index)'
#  '-Negative'
#  'Positive (expecting crude oil prices to average $58 per barrel in 2019 and rising to $62 per barrel in 2020)'
#  'Negative (Softening emerging-market demand, strength in US dollar)'
#  'Mixed (Negative and Neutral)'
#  'Mixed (positive for West Texas Intermediate crude and negative for oversupply and oil price volatility)'
#  'Negative (volatile prices, expected range of $50-$70 per barrel in 2019)'
#  'Neutral/Negative' 'Mixed (Negative and Positive)' '[Positive]'
#  'Negative (decline and uncertainty over how long the coronavirus may damage crude oil demand)'
#  '[Sentiment]' 'Negative (-29.8% to -40.8%)' 'NB'
#  'Positive (prices will improve marginally but remain below $3.00 per million BTU in 2024)'
#  'Neutral to Positive (expecting $75-$80 per barrel range for WTI crude and prices improving marginally but remaining below $3.00 per million BTU for natural gas)'
#  'Mixed (risk of price drop if China enters recession, but demand growth expected)'
#  'Mixed (Positive: demand growth, Negative: recession risk)'
#  'Partly positive, partly offset by concerns over the state of the economy in China'
#  'Negative (concerns over the state of the economy in China, risk of recession)'
#  'Partly Positive, partly Negative (risks remain)' 'NA (Not Applicable)'
#  'Negative/Neutral'
#  'Positive (mentions average gas prices will decrease in 2023 and 2024)'
#  'N% over projected 2023 levels'
#  'Positive (gasoline prices expected to average $3.39 per gallon in 2023, down from $3.97 per gallon mark in 2022)'
#  'Negative (Henry HUB natural gas prices expected to average $3.40/MMBtu in 2023, rising to $4.04/MMBtu in 2024)'
#  'Positive (gasoline prices expected to average $3.39 per gallon in 2023 and $3.10 per gallon in 2024)'
#  'E' 'Neutral to Negative' 'N2 (Not Applicable)'
#  'Mixed (Positive: EIA projects gasoline prices to average $4.07 per gallon in 2022, and remain in the $3.66/gallon range in 2023. Negative: The article mentions that a sharp recession would be an effective approach to curbing high prices at the pump.)'
#  'Neutral/Negative (concerns about potential impact on global economy)'
#  'Positive/Negative (mixed)'
#  'Positive/Negative (depending on the scenario)'
#  'Mixed (Positive/Negative)'
#  'Positive (refining margins expected to widen, gasoline prices forecasted to average $4.07/gallon in 2022)'
#  'Positive (temporary downward impact) but Negative (long-term effects)'
#  'Nhigh energy prices' 'Mixed (Positive and Negative sentiments)'
#  'Positive (High)'
#  'Negative (Henry HUB natural gas prices expected to average $7.69 per MMBtu in 2022, dropping to $4.92/MMBtu in 2023)'
#  'Mixed (includes Positive and Negative sentiments)'
#  'Mixed (Positive: temporary decrease, Negative: potential long-term impact)'
#  'Neutral/Negative (depending on specific prices and trends)'
#  'Negative (projected price increases)' 'Not Given'
#  'Mixed (positive for temporary price drop, negative for potential impact on resilience to future supply shocks)'
#  'Unknown'
#  'Neutral/Negative (depending on the spread between WTI and WCS)'
#  'Negative ($2.44/gallon in 2020)'
#  '-$2.44/gallon in 2021 ($2.44/gallon in 2020)' 'Uncertain'
#  'Positive (The article mentions that U.S. residential prices for heating oil will average $2.71/gallon in 2021, which is an increase from the previous year.)'
#  '[No Sentiment]' 'Nsolutions'
#  'Negative (due to expected decrease in oil and gas prices)'
#  'Negative (oil prices expected to decrease, natural gas prices expected to rise)'
#  'Negative (mention of price decreases)'
#  'Mixed (Negative for 2020, Neutral for 2021)' 'Negative (oil price)'
#  'Positive (anticipating higher prices due to diverging WTI and WCS crude oil prices)'
#  'Not Provided' 'Positive/Neutral'
#  'Negative (spot prices for LNG have been somewhat disappointing)'
#  'N/A (no relevant information)'
#  'Positive (crude oil prices expected to remain at or near $55 per barrel)'
#  'N.A.'
#  'Negative (Hess is more leveraged to oil prices than other integrated firms)'
#  'NIO' 'N/A (Not mentioned)' '[None]' 'Mixed (Positive and Neutral)'
#  'Mixed (Both Positive and Negative)' 'Unrelated' '[Not Applicable]'
#  'Variable' 'NHHI' 'N Relic' 'No JSON found' 'NN' 'N.Payment of Benefits'
#  'N0' 'None (no mention)' '[No Mention]' '[No category]'
#  'Mixed (Negative/Positive)' 'Mixed (Positive, Neutral)' 'Niscernible']
# Total unique values in OG Price: 152

# %% [markdown]
# **Findings**
# - Llama produced differnt variations of the same sentiment, including additional comments supporting the dicision.
# - Most of the sentiment options can be generalized using the renaming function using the keywords.

# %%
def improved_standardize_sentiment(value):
    value = str(value).lower().strip()

    # Positive sentiments
    positive_indicators = [
        'positive', 'increase', 'growth', 'improve', 'higher', 'small increase',
        '2.1% increase', '2% increase', '5.3% increase', '6.0% increase',
        '7.3% increase', 'median increase', 'temporary decrease', 'temporary drop'
    ]

    # Negative sentiments
    negative_indicators = [
        'negative', 'decrease', 'decline', 'lower', 'risk', 'concern', 'no json found',
        'none', 'uncertainty', 'pessimistic', 'concerns over', 'concerned',
        'pulls back', 'lower growth', 'high cost structure', 'failure of exploration efforts',
        'stringent energy regulations', 'moratoriums', 'volatility', 'high prices', 'slowed production'
    ]

    # Neutral sentiments
    neutral_indicators = [
        'neutral', 'unchanged', 'stable', 'mixed', 'n', 'nr', 'nes', 'nmb/d',
        'n.a.', 'nd', 'absent', 'neutral to', 'neutral/negative', 'neutral/positive',
        'neutral (with a mention)', 'n.d.', 'na', 'neutral/neutral'
    ]

    # Mixed sentiments
    mixed_indicators = [
        'mixed', 'positive/negative', 'negative/positive', 'mixed sentiment',
        'partly', 'includes', 'some', 'depending', 'neutral and', 'some neutral',
        'positive trend', 'negative trend', 'both positive and negative', 'positive and negative'
    ]

    # Not Applicable categories
    not_applicable_indicators = [
        'n/a', 'not applicable', 'not mentioned', 'no mention',
        'none mentioned', 'nq', 'absent', 'no sentiment', 'not rated', 'not relevant',
        'no specific information provided', 'no direct mention', 'no information provided',
        'not applicable to', 'no data provided', 'unknown', 'not significant'
    ]

    # Error categories
    error_indicators = [
        'error', 'error: max retries reached', 'no JSON found'
    ]

    # Positive sentiments
    if any(word in value for word in positive_indicators):
        return 'Positive'

    # Negative sentiments
    elif any(word in value for word in negative_indicators):
        return 'Negative'

    # Neutral sentiments
    elif any(word in value for word in neutral_indicators):
        return 'Neutral'

    # Mixed sentiments
    elif any(word in value for word in mixed_indicators):
        return 'Mixed'

    # Not Applicable categories
    elif any(word in value for word in not_applicable_indicators):
        return 'N/A'

    # Error categories
    elif any(word in value for word in error_indicators):
        return 'Error'

    # If none of the above, categorize as Other
    else:
        return 'Other'

# %%
# Apply the improved standardization to each sentiment column
sentiment_columns = ['Finance', 'Production', 'Reserves/M&A', 'Regulatory', 'Green Energy', 'OG Price']
standartized_llama_output = llama_output.copy()
for column in sentiment_columns:
    standartized_llama_output[column] = standartized_llama_output[column].apply(improved_standardize_sentiment)

# Print standardized value counts for each category
for column in sentiment_columns:
    print(f"\nStandardized value counts for {column}:")
    print(standartized_llama_output[column].value_counts())
# Out:
# Standardized value counts for Finance:
# Finance
# Neutral     6768
# Positive    2077
# Negative    1227
# Error         53
# Name: count, dtype: int64
#
# Standardized value counts for Production:
# Production
# Neutral     5045
# Positive    3079
# Negative    1948
# Error         53
# Name: count, dtype: int64
#
# Standardized value counts for Reserves/M&A:
# Reserves/M&A
# Neutral     6608
# Positive    2080
# Negative    1382
# Error         53
# Other          2
# Name: count, dtype: int64
#
# Standardized value counts for Regulatory:
# Regulatory
# Neutral     5909
# Negative    3300
# Positive     862
# Error         53
# Other          1
# Name: count, dtype: int64
#
# Standardized value counts for Green Energy:
# Green Energy
# Neutral     7985
# Positive    1410
# Negative     675
# Error         53
# Other          2
# Name: count, dtype: int64
#
# Standardized value counts for OG Price:
# OG Price
# Neutral     5510
# Negative    2636
# Positive    1924
# Error         53
# Other          2
# Name: count, dtype: int64

# %%
standartized_llama_output["Source"].unique()
# Out:
# array(['Investment Research', 'ProQuest', 'SEC Filings',
#        'Earnings Call Presentations', 'Earnings Call Q&A'], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plot_horizontal_grouped_sentiment_by_source(data, sentiment_columns):
    # Prepare the data
    sentiment_counts = {}
    sources = data['Source'].unique()

    for column in sentiment_columns:
        sentiment_counts[column] = data.groupby('Source')[column].value_counts(normalize=True).unstack()

    # Set up the plot
    fig, ax = plt.subplots(figsize=(15, 3 * len(sources)))

    # Define simplified color scheme
    color_map = {
        'Positive': '#00A86B',  # Green
        'Neutral': '#87CEEB',   # Blue
        'Negative': '#FF4136',  # Red
        'Error': '#000000'      # Black
    }

    # Convert color_map keys to a list for indexing
    sentiment_order = list(color_map.keys())

    # Set the height of each bar and the positions of the bars
    bar_height = 0.15
    r = np.arange(len(sources))

    # Plot bars for each sentiment category
    for i, column in enumerate(sentiment_columns):
        # Ensure all sentiment categories are present, fill with 0 if missing
        for sentiment in sentiment_order:
            if sentiment not in sentiment_counts[column].columns:
                sentiment_counts[column][sentiment] = 0

        # Plot bars
        for sentiment in sentiment_order:
            left = sentiment_counts[column][[s for s in sentiment_order if sentiment_order.index(s) < sentiment_order.index(sentiment)]].sum(axis=1)
            ax.barh(r + i*bar_height, sentiment_counts[column][sentiment], left=left, color=color_map[sentiment], height=bar_height)

        # Add text labels
        ax.text(1.02, r[len(r)//2] + i*bar_height, f'{column}', va='center', ha='left', fontsize=10)

    # Customize the plot
    ax.set_ylabel('Source', fontweight='bold')
    ax.set_xlabel('Proportion', fontweight='bold')
    ax.set_title('Sentiment Distribution by Source and Category', fontweight='bold')
    ax.set_yticks(r + bar_height * (len(sentiment_columns) - 1) / 2)
    ax.set_yticklabels(sources)

    # Add simplified legend
    handles = [plt.Rectangle((0,0),1,1, color=color) for color in color_map.values()]
    ax.legend(handles, color_map.keys(), title="Sentiment", bbox_to_anchor=(1.05, 1), loc='upper left')

    # Add grid lines
    ax.set_axisbelow(True)
    ax.xaxis.grid(color='gray', linestyle='dashed', alpha=0.7)

    plt.tight_layout()
    plt.show()

# Use the function
plot_horizontal_grouped_sentiment_by_source(standartized_llama_output, sentiment_columns)

# %%
import seaborn as sns

def plot_violin(data, sentiment_columns):
    # Prepare data for violin plot
    violin_data = data.melt(value_vars=sentiment_columns, var_name='Category', value_name='Sentiment')

    plt.figure(figsize=(12, 6))
    sns.violinplot(x='Category', y='Sentiment', data=violin_data)
    plt.title('Distribution of Sentiments Across Categories')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

plot_violin(standartized_llama_output, sentiment_columns)

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_parallel_categories(data, sentiment_columns):
    # Define color scheme
    color_map = {
        'Positive': '#00A86B',  # Green
        'Neutral': '#87CEEB',   # Blue
        'Negative': '#FF4136',  # Red
        'Error': '#000000'      # Black
    }

    # Prepare dimensions
    dimensions = [
        {'label': 'Source', 'values': data['Source']}
    ]
    for col in sentiment_columns:
        dimensions.append({'label': col, 'values': data[col]})

    # Prepare color data
    color_data = []
    for col in sentiment_columns:
        color_data.extend([color_map.get(val, '#CCCCCC') for val in data[col]])

    # Create the parallel categories diagram
    fig = go.Figure(data=[go.Parcats(
        dimensions=dimensions,
        line={'color': color_data, 'shape': 'hspline'},
        hoveron='color',
        hoverinfo='count+probability',
        labelfont={'size': 14, 'family': 'Arial'},
        tickfont={'size': 12, 'family': 'Arial'},
        arrangement='freeform',
    )])

    fig.update_layout(
        title='Parallel Categories of Sentiments Across Sources',
        height=500,  # Increase height for better visibility
        margin=dict(l=100, r=100, t=100, b=100)  # Adjust margins
    )

    fig.show()

plot_parallel_categories(standartized_llama_output, sentiment_columns)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40fba95c-c4b1-4520-8a2a-3814aebf8bb7" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40fba95c-c4b1-4520-8a2a-3814aebf8bb7")) {                    Plotly.newPlot(                        "40fba95c-c4b1-4520-8a2a-3814aebf8bb7",                        [{"arrangement":"freeform","dimensions":[{"label":"Source","values":["Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","Investment Research","I ...

# %%
# generate matrix 6x6 to show correlation between categorie
corr = standartized_llama_output[sentiment_columns].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-491526c06532> in <cell line: 2>()
#       1 # generate matrix 6x6 to show correlation between categorie
# ----> 2 corr = standartized_llama_output[sentiment_columns].corr()
#       3 sns.heatmap(corr, annot=True, cmap='coolwarm')
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1730                 arr.flags.writeable = False
#    1731         else:
# -> 1732             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733             # The underlying data was copied within _interleave, so no need
#    1734             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1792             else:
#    1793                 arr = blk.get_values(dtype)
# -> 1794             result[rl.indexer] = arr
#    1795             itemmask[rl.indexer] = 1
#    1796
#
# ValueError: could not convert string to float: 'Neutral'

# %%
# compare to Finbert, Llama, Gemini
