# %% [markdown]
# ## Install Dependencies, Import Libraries, Clone Github, and Load Data

# %%
# Install Dependenies
# !pip install -q -U langchain langchain_community transformers bitsandbytes accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 37.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 2.2 MB/s eta 0:00:00

# %%
# Import Libraries
import os
from google.colab import userdata
import pandas as pd
import torch
from transformers import BitsAndBytesConfig
from langchain import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import time

# %%
# Import github token with google secrets thingy and clone git repository
GITHUB_TOKEN = userdata.get('github')
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
# !git clone https://{GITHUB_TOKEN}@github.com/Kussil/CVX_Rice_project.git
# Out:
# Cloning into 'CVX_Rice_project'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 143 (delta 40), reused 0 (delta 0), pack-reused 62
# Receiving objects: 100% (143/143), 57.48 MiB | 11.97 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
text_df = pd.read_csv('CVX_Rice_project/Text_Data/Consolidated_Text_Data.csv')
display(text_df.head())
# Out:
#   Ticker                   Date  \
# 0    CVX  May 13, 2024 10:05 PM
# 1    CVX  May 13, 2024 03:29 PM
# 2    CVX  May 11, 2024 06:00 PM
# 3    CVX  May 04, 2024 05:49 PM
# 4    CVX  May 01, 2024 10:03 PM
#
#                                     Article Headline  \
# 0                                Chevron Corporation
# 1  CFRA LIFTS VIEW ON SHARES OF CHEVRON CORPORATI...
# 2                                Chevron Corporation
# 3                                Chevron Corporation
# 4                                Chevron Corporation
#
#                                         Article Text
# 0  Stock Report | March 12, 2022 | NYSE Symbol: C...
# 1  Stock Report | August 05, 2023 | NYSE Symbol: ...
# 2  Stock Report | March 04, 2023 | NYSE Symbol: C...
# 3  Stock Report | October 17, 2020 | NYSE Symbol:...
# 4  Stock Report | December 25, 2021 | NYSE Symbol...

# %% [markdown]
# ## Load Llama 3

# %%
# Define Quantization
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True)

# Load Model and Tokenizer
model_4bit = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Meta-Llama-3-8B-Instruct",
    device_map="auto",
    quantization_config=quantization_config)
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B-Instruct")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Create Hugging Face Pipeline
pipeline_inst = pipeline(
        "text-generation",
        model=model_4bit,
        tokenizer=tokenizer,
        use_cache=True,
        device_map="auto",
        max_length=5000, # Need to find the max tokens per article
        truncation=True,
        do_sample=True,
        top_k=5,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id)

llm = HuggingFacePipeline(pipeline=pipeline_inst)

# %%
# Prompt and response function
template = """<s> Given the text from a financial news article, analyze the content and produce a structured summary categorizing the company's performance and related impacts across multiple predefined categories. Each category should be listed with a corresponding sentiment derived from the article. If a category is not mentioned or relevant based on the article content, mark it as 'N/A'. Ensure that all categories are addressed for a comprehensive summary.

        Categories and Sentiment Options to be Analyzed:
        •	Financial Targets
            •	Greatly Exceeded Target
            •	Exceeded Target
            •	Achieved Target
            •	Below Target
            •	Significantly below Target
        •	Exploration / Discoveries
            •	Major Discovery
            •	Minor Discovery
            •	Favorable Exploration Results
            •	Unfavorable Exploration Results
            •	Exploration Failure
        •	Reserves
            •	Significant Reserves Add
            •	Minor Reserves Add
            •	Stable Reserve Levels
            •	Small Reserves Loss / Writeoff
            •	Significant Reserves Depletions / Writeoff
        •	Production Targets
            •	Greatly Exceeded Target
            •	Exceeded Target
            •	Achieved Target
            •	Below Target
            •	Significantly below Target
        •	New Energy Investments / Projects
            •	Major Advancements in New Energy Initiatives
            •	Minor Advancements in New Energy Initiatives
            •	Setback in New Energies Project
            •	New Energy Projects Abandoned or Failed
        •	Acquisitions and Mergers
            •	Major Acquisition or Merger
            •	Minor Acquisition or Merger
            •	Delay in Acquisition or Merger
            •	Cancelled Acquisition or Merger
        •	Divestments
            •	Major Divestment
            •	Small Divestment
        •	Public Sentiment
            •	Very Positive
            •	Positive
            •	Neutral
            •	Negative
            •	Very Negative
        •	Regulatory / Geopolitical Factors
            •	Favorable change to Operations
            •	Potential Large Disruption to Operations
            •	Potential Small Disruption to Operations
        •	Environmental Factors
            •	Very Positive
            •	Positive
            •	Neutral
            •	Negative
            •	Very Negative

        Output Format:
        •	Use bullet points for each category.
        •	For each category, provide the status or sentiment extracted from the article. If no specific information is available, indicate 'N/A'.

        Example Output:
            •	Financial Targets - Achieved Target
            •	Exploration / Discoveries - N/A
            •	Reserves - Minor Reserves Add
            •	Production Targets - Greatly Exceeded Target
            •	New Energy Investments / Projects - Major Advancements in New Energy Initiatives
            •	Acquisitions and Mergers - Major Acquisition or Merger
            •	Divestments - N/A
            •	Public Sentiment - Very Positive
            •	Regulatory / Geopolitical Factors - Potential Small Disruption to Operations
            •	Environmental Factors - Neutral

        Task:
        •	Parse the article text to identify relevant data points and sentiments for each category.
        •	Summarize the findings in the specified output format.
        •	Maintain accuracy and clarity in categorization and summary presentation.

        **Constraints:** ONLY RESPOND USING THE PROVIDED FORMAT/n/n

        The text from the financial news article is below:
        {article} </s>
        """

def generate_response(article):
  prompt = PromptTemplate(template=template, input_variables=["article"])
  llm_chain = LLMChain(prompt=prompt, llm=llm)
  response = llm_chain.run({"article":article})
  return response

# %%
# Test Function on first article
article = text_df.iloc[0]['Article Text']
full_response = generate_response(article)
split_response = full_response.split("</s>", 1)
final_response = split_response[1]
print(final_response)
# Out:
#          ```
#         **Output:**
#         •	Financial Targets - Achieved Target
#         •	Exploration / Discoveries - N/A
#         •	Reserves - Minor Reserves Add
#         •	Production Targets - Greatly Exceeded Target
#         •	New Energy Investments / Projects - Major Advancements in New Energy Initiatives
#         •	Acquisitions and Mergers - N/A
#         •	Divestments - N/A
#         •	Public Sentiment - Very Positive
#         •	Regulatory / Geopolitical Factors - Potential Small Disruption to Operations
#         •	Environmental Factors - Neutral
#         **Note:** The article does not mention specific information about the company's reserves, exploration, or mergers and acquisitions, so the corresponding categories are marked as 'N/A'. The company's financial targets, production targets, and new energy investments are highlighted as 'Achieved Target', 'Greatly Exceeded Target', and 'Major Advancements in New Energy Initiatives', respectively. The public sentiment is reported as 'Very Positive' based on the article's tone and the company's share price performance. The regulatory/geopolitical factors are noted as 'Potential Small Disruption to Operations' due to the mention of oil price volatility and geopolitical risk. The environmental factors are reported as 'Neutral' since there is no specific information provided about the company's environmental performance.

# %%
# Add sentiment categories to DF
sentiment_categories = {'Financial Targets' : None,
                        'Exploration / Discoveries' : None,
                        'Reserves' : None,
                        'Production Targets' : None,
                        'New Energy Investments / Projects' : None,
                        'Acquisitions and Mergers' : None,
                        'Divestments' : None,
                        'Public Sentiment' : None,
                        'Regulatory / Geopolitical Factors' : None,
                        'Environmental Factors' : None}
text_df = text_df.assign(**sentiment_categories)
display(text_df.head())
# Out:
#   Ticker                   Date  \
# 0    CVX  May 13, 2024 10:05 PM
# 1    CVX  May 13, 2024 03:29 PM
# 2    CVX  May 11, 2024 06:00 PM
# 3    CVX  May 04, 2024 05:49 PM
# 4    CVX  May 01, 2024 10:03 PM
#
#                                     Article Headline  \
# 0                                Chevron Corporation
# 1  CFRA LIFTS VIEW ON SHARES OF CHEVRON CORPORATI...
# 2                                Chevron Corporation
# 3                                Chevron Corporation
# 4                                Chevron Corporation
#
#                                         Article Text Financial Targets  \
# 0  Stock Report | March 12, 2022 | NYSE Symbol: C...              None
# 1  Stock Report | August 05, 2023 | NYSE Symbol: ...              None
# 2  Stock Report | March 04, 2023 | NYSE Symbol: C...              None
# 3  Stock Report | October 17, 2020 | NYSE Symbol:...              None
# 4  Stock Report | December 25, 2021 | NYSE Symbol...              None
#
#   Exploration / Discoveries Reserves Production Targets  \
# 0                      None     None               None
# 1                      None     None               None
# 2                      None     None               None
# 3                      None     None               None
# 4                      None     None               None
#
#   New Energy Investments / Projects Acquisitions and Mergers Divestments  \
# 0                              None                     None        None
# 1                              None                     None        None
# 2                              None                     None        None
# 3                              None                     None        None
# 4                              None                     None        None
#
#   Public Sentiment Regulatory / Geopolitical Factors Environmental Factors
# 0             None                              None                  None
# 1             None                              None                  None
# 2             None                              None                  None
# 3             None                              None                  None
# 4             None                              None                  None

# %%
# Test Adding results to DF
lines = final_response.strip().split('\n')

for category in sentiment_categories:
    for line in lines:
        if category in line:
            _, sentiment = line.split(' - ', 1)
            print(sentiment)
            text_df.loc[0, category] = sentiment
            break

display(text_df.head(1))
# Out:
# Achieved Target
# N/A
# Minor Reserves Add
# Greatly Exceeded Target
# Major Advancements in New Energy Initiatives
# N/A
# N/A
# Very Positive
# Potential Small Disruption to Operations
# Neutral
#   Ticker                   Date     Article Headline  \
# 0    CVX  May 13, 2024 10:05 PM  Chevron Corporation
#
#                                         Article Text Financial Targets  \
# 0  Stock Report | March 12, 2022 | NYSE Symbol: C...   Achieved Target
#
#   Exploration / Discoveries            Reserves       Production Targets  \
# 0                       N/A  Minor Reserves Add  Greatly Exceeded Target
#
#               New Energy Investments / Projects Acquisitions and Mergers  \
# 0  Major Advancements in New Energy Initiatives                      N/A
#
#   Divestments Public Sentiment         Regulatory / Geopolitical Factors  \
# 0         N/A    Very Positive  Potential Small Disruption to Operations
#
#   Environmental Factors
# 0               Neutral

# %% [markdown]
# ## Loop through articles and append results to df

# %%
# Test first 5 articles
start_time = time.time()

for index, article in enumerate(text_df['Article Text'].iloc[:5]):
    # Get LLM response
    full_response = generate_response(article)
    split_response = full_response.split("</s>", 1)
    final_response = split_response[1]
    print(index)
    print(final_response)
    print()

    # Split into lines
    lines = final_response.strip().split('\n')

    for category in sentiment_categories:
        for line in lines:
            if category in line:
                _, sentiment = line.split(' - ', 1)
                text_df.loc[index, category] = sentiment
                break

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
display(text_df.head(5))
# Out:
# 0
#
#          """
#
#         # Extract the article text
#         article_text = text
#
#         # Initialize the categories and sentiments
#         financial_targets = 'N/A'
#         exploration_discoveries = 'N/A'
#         reserves = 'N/A'
#         production_targets = 'N/A'
#         new_energy_investments_projects = 'N/A'
#         acquisitions_mergers = 'N/A'
#         divestments = 'N/A'
#         public_sentiment = 'N/A'
#         regulatory_geopolitical_factors = 'N/A'
#         environmental_factors = 'N/A'
#
#         # Parse the article text
#         for line in article_text.splitlines():
#             # Check for financial targets
#             if 'capital spending' in line:
#                 financial_targets = 'Below Target'
#             elif 'capital spending over the next five years would range from $15B - $17B' in line:
#                 financial_targets = 'Achieved Target'
#             elif 'likely being towards the low end of the range' in line:
#                 financial_targets = 'Below Target'
#             elif 'we estimate that CVX's upstream unit profitability' in line:
#                 financial_targets = 'Achieved Target'
#
#             # Check for exploration and discoveries
#             if'major discovery' in line:
#                 exploration_discoveries = 'Major Discovery'
#             elif'minor discovery' in line:
#                 exploration_discoveries = 'Minor Discovery'
#             elif 'favorable exploration results' in line:
#                 exploration_discoveries = 'Favorable Exploration Results'
#             elif 'unfavorable exploration results' in line:
#                 exploration_discoveries = 'Unfavorable Exploration Results'
#
#             # Check for reserves
#             if'minor reserves add' in line:
#                 reserves = 'Minor Reserves Add'
#             elif'stable reserve levels' in line:
#                 reserves = 'Stable Reserve Levels'
#             elif'small reserves loss/writeoff' in line:
#                 reserves = 'Small Reserves Loss/Writeoff'
#             elif'significant reserves depletions/writeoff' in line:
#                 reserves = 'Significant Reserves Depletions/Writeoff'
#
#             # Check for production targets
#             if 'greatly exceeded target' in line:
#                 production_targets = 'Greatly Exceeded Target'
#             elif 'exceeded target' in line:
#                 production_targets = 'Exceeded Target'
#             elif 'achieved target' in line:
#                 production_targets = 'Achieved Target'
#             elif 'below target' in line:
#                 production_targets = 'Below Target'
#
#             # Check for new energy investments and projects
#             if'major advancements in new energy initiatives' in line:
#                 new_energy_investments_projects = 'Major Advancements in New Energy Initiatives'
#             elif'minor advancements in new energy initiatives' in line:
#                 new_energy_investments_projects = 'Minor Advancements in New Energy Initiatives'
#             elif'setback in new energies project' in line:
#                 new_energy_investments_projects = 'Setback in New Energies Project'
#
#             # Check for acquisitions and mergers
#             if'major acquisition or merger' in line:
#                 acquisitions_mergers = 'Major Acquisition or Merger'
#             elif'minor acquisition or merger' in line:
#                 acquisitions_mergers = 'Minor Acquisition or Merger'
#             elif 'delay in acquisition or merger' in line:
#                 acquisitions_mergers = 'Delay in Acquisition or Merger'
#
#             # Check for divestments
#             if'major divestment' in line:
#                 divestments = 'Major Divestment'
#             elif'small divestment' in line:
#                 divestments = 'Small Divestment'
#
#             # Check for public sentiment
#             if'very positive' in line:
#                 public_sentiment = 'Very Positive'
#             elif 'positive' in line:
#                 public_sentiment = 'Positive'
#             elif 'neutral' in line:
#                 public_sentiment = 'Neutral'
#             elif 'negative' in line:
#                 public_sentiment = 'Negative'
#             elif'very negative' in line:
#                 public_sentiment = 'Very Negative'
#
#             # Check for regulatory and geopolitical factors
#             if 'favorable change to operations' in line:
#                 regulatory_geopolitical_factors = 'Favorable Change to Operations'
#             elif 'potential large disruption to operations' in line:
#                 regulatory_geopolitical_factors = 'Potential Large Disruption to Operations'
#             elif 'potential small disruption to operations' in line:
#                 regulatory_geopolitical_factors = 'Potential Small Disruption to Operations'
#
#             # Check for environmental factors
#             if'very positive' in line:
#                 environmental_factors = 'Very Positive'
#             elif 'positive' in line:
#                 environmental_factors = 'Positive'
#             elif 'neutral' in line:
#                 environmental_factors = 'Neutral'
#             elif 'negative' in line:
#                 environmental_factors = 'Negative'
#             elif'very negative' in line:
#                 environmental_factors = 'Very Negative'
#
#         # Create the summary
#         summary = {
#             'Financial Targets': financial_targets,
#             'Exploration / Discoveries': exploration_discoveries,
#             'Reserves': reserves,
#             'Production Targets': production_targets,
#             'New Energy Investments / Projects': new_energy_investments_projects,
#             'Acquisitions and Mergers': acquisitions_mergers,
#             'Divestments': divestments,
#             'Public Sentiment': public_sentiment,
#             'Regulatory / Geopolitical Factors': regulatory_geopolitical_factors,
#             'Environmental Factors': environmental_factors
#         }
#
#         return summary
#     except Exception as e:
#         print(f"Error occurred: {str(e)}")
#         return None
# # </s>
#
# # Example usage
# text = """
# Stock Report | March 12, 2022 | NYSE Symbol: CVX | CVX is in the S&P 500
# Chevron Corporation
# Recommendation Price 12-Mo. Target Price Report Currency Investment Style
# HOLD « « « « «
# USD 170.90 (as of market close Mar 11, 2022) USD 163.00 USD Large-Cap Value
# Equity Analyst Stewart Glickman, CFA
# GICS Sector Energy Summary This global integrated oil company (formerly ChevronTexaco) has interests in exploration &
# Sub-Industry Integrated Oil and Gas production, refining & marketing, and petrochemicals.
# Key Stock Statistics (Source: CFRA, S&P Global Market Intelligence (SPGMI), Company Reports)
# 52-Wk Range USD 174.76 - 92.86 Oper.EPS2022E USD 11.52 Market Capitalization[B] USD 332.68 Beta 1.12
# Trailing 12-Month EPS USD 8.14 Oper.EPS2023E USD 10.25 Yield [%] 3.33 3-yr Proj. EPS CAGR[%] 13
# Trailing 12-Month P/E 21.0 P/E on Oper.EPS2022E 14.84 Dividend Rate/Share USD 5.68 SPGMI's Quality Ranking B-
# USD 10K Invested 5 Yrs Ago 19,325.0 Common Shares Outstg.[M] 1,930.00 Trailing 12-Month Dividend USD 5.44 Institutional Ownership [%] 65.0
# Price Performance Analyst's Risk Assessment
# LOW MEDIUM HIGH
# Our risk assessment reflects our view of Chevron's
# exposure to volatile, cyclical, and capital-intensive
# segments of the energy sector. While we view positively
# the company's size and breadth of operations across the
# energy value chain, we also note that upstream operations
# are exposed to volatile energy prices.
# Revenue/Earnings Data
# Revenue (Million USD)
# 1Q 2Q 3Q 4Q Year
# 2023 E 48,000 E 47,000 E 46,000 E 46,000 E 187,000
# 2022 E 50,000 E 51,000 E 53,000 E 49,000 E 203,000
# 2021 31,076 36,117 42,552 45,861 155,606
# 2020 29,705 15,926 23,997 24,843 94,471
# 2019 34,189 36,323 34,779 34,574 139,865
# 2018 35,968 40,491 42,105 40,338 158,902
# Source: CFRA, S&P Global Market Intelligence Earnings Per Share (USD)
# Past performance is not an indication of future performance and should not be relied upon as such. 1Q 2Q 3Q 4Q Year
# Analysis prepared by Stewart Glickman, CFA on Mar 07, 2022 06:41 PM ET, when the stock traded at USD 159.90.
# 2023 E 2.51 E 2.60 E 2.62 E 2.52 E 10.25
# 2022 E 3.03 E 2.97 E 2.88 E 2.64 E 11.52
# Highlights Investment Rationale/Risk
# 2021 0.72 1.60 3.19 2.63 8.14
# uIn January, CVX suggested that its annual uOur recommendation is Hold, cut from Buy on 2020 1.29 -4.46 -0.12 -0.35 -2.96
# capital spending over the next five years would valuation, with shares up 35% YTD through early 2019 1.39 2.27 1.36 -3.53 1.54
# range from $15B - $17B, with 2022 likely being March. CVX is delivering higher operating cash 2018 1.90 1.78 2.11 1.95 7.74
# towards the low end of the range. While this is a flow despite lower capital spending, which we Fiscal Year ended Dec 31. EPS Estimates based on CFRA's
# healthy uptick from 2021’s $11.7B, it is well think is a testament to improved unit Operating Earnings; historical GAAP earnings are as reported in
# below CVX’s pre-Covid-19 projected spending profitability. We estimate that CVX’s upstream Company reports.
# level of $19B - $22B per year. In our view, this unit profitability was better than that of chief
# likely reflects (1) higher hurdle rates for rival Exxon Mobil (XOM 87 ****) in 2021. Dividend Data
# selected projects, (2) improved capital Longer-term, we think CVX will expand its
# Amount Date Ex-Div. Stk. of Payment
# efficiency, and (3) a corporate decision to offerings in low-carbon solutions, renewable
# ( USD) Decl. Date Record Date
# allocate a greater percentage of available fuels and hydrogen.
# capital to dividends and buybacks. uRisks to our opinion and target include a decline 1.4200 Jan 26 Feb 15 Feb 16 Mar 10 '22
# 1.3400 Oct 27 Nov 17 Nov 18 Dec 10 '21
# uAlso in January, CVX said that chemicals in oil & gas prices, geopolitical risk, lower-than-
# 1.3400 Jul 28 Aug 18 Aug 19 Sep 10 '21
# margins have pulled back from the highs early expected production from onshore shale oil
# 1.3400 Apr 28 May 18 May 19 Jun 10 '21
# in 2021, but remain above mid-cycle levels. plays, and an unanticipated dividend cut.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-1341f3080cc1> in <cell line: 4>()
#      17         for line in lines:
#      18             if category in line:
# ---> 19                 _, sentiment = line.split(' - ', 1)
#      20                 text_df.loc[index, category] = sentiment
#      21                 break
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
display(text_df.head(5))
