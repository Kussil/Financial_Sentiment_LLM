# %% [markdown]
# # Import Libraries and Clone Github

# %%
# Import Libraries
import os
import sys
import time

# %%
# Determine the project directory from the current working directory
project_dir = os.path.abspath(os.path.join(os.getcwd(), '../..'))
source_code_dir = os.path.join(project_dir, '10_Source_Code')

# Add the path to the directory containing your module to the system path
sys.path.append(source_code_dir)

# Now you can import your module
import data_setup as ds
import gemini_setup as gs

# %%
# Global Variables
CATEGORIES = [
        "Finance",
        "Production",
        "Reserves / Exploration / Acquisitions / Mergers / Divestments",
        "Environment / Regulatory / Geopolitics",
        "Alternative Energy / Lower Carbon",
        "Oil Price / Natural Gas Price / Gasoline Price"]

SENTIMENT_RESULTS_FILE_PATH = 'Prompt1_Sentiment_Analysis_Results_CHECK.csv'

ROWS_TO_DROP = ['PQ-2840736837']

# %% [markdown]
# # Import Data

# %%
# Load and merge data using the function from data_setup
text_df = ds.load_cleaned_data()

# %%
# Display initial data
display(text_df.shape)
display(text_df.head())
display(text_df.tail())
# Out:
# (10053, 7)
#                 Source Unique_ID Ticker        Date          Article Headline  \
# 0  Investment Research      IR-1    MRO  2024-05-16  Marathon Oil Corporation
# 1  Investment Research      IR-2    EOG  2024-05-14       EOG Resources, Inc.
# 2  Investment Research      IR-3    EOG  2024-05-11       EOG Resources, Inc.
# 3  Investment Research      IR-4    DVN  2024-05-11  Devon Energy Corporation
# 4  Investment Research      IR-5    COP  2024-05-07            ConocoPhillips
#
#                                         Article Text  URL
# 0  Stock Report | May 16, 2024 | NYSESymbol: MRO ...  NaN
# 1  Stock Report | May 14, 2024 | NYSESymbol: EOG ...  NaN
# 2  Stock Report | May 11, 2024 | NYSESymbol: EOG ...  NaN
# 3  Stock Report | May 11, 2024 | NYSESymbol: DVN ...  NaN
# 4  Stock Report | May 07, 2024 | NYSESymbol:\n\nC...  NaN
#                   Source Unique_ID Ticker        Date  \
# 10048  Earnings Call Q&A    EQ-338    XOM  2021-02-02
# 10049  Earnings Call Q&A    EQ-339    COP  2021-02-02
# 10050  Earnings Call Q&A    EQ-340    EOG  2019-05-03
# 10051  Earnings Call Q&A    EQ-341   SHEL  2019-05-02
# 10052  Earnings Call Q&A    EQ-342    COP  2019-04-30
#
#                                         Article Headline  \
# 10048  Exxon Mobil Corporation, Q4 2020 Earnings Call...
# 10049  ConocoPhillips, Q4 2020 Earnings Call, Feb 02,...
# 10050  EOG Resources, Inc., Q1 2019 Earnings Call, Ma...
# 10051  Royal Dutch Shell plc, Q1 2019 Earnings Call, ...
# 10052  ConocoPhillips, Q1 2019 Earnings Call, Apr 30,...
#
#                                             Article Text  URL
# 10048  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10049  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10050  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10051  Question and Answer\nOperator\n[Operator Instr...  NaN
# 10052  Question and Answer\nOperator\n[Operator Instr...  NaN

# %%
text_df = ds.drop_unprocessable_rows(text_df, ROWS_TO_DROP)
print(f"Dropped rows: {ROWS_TO_DROP}")
# Out:
# Dropped rows: ['PQ-2840736837']

# %%
# Check if sentiment analysis results file exists
file_exists = ds.check_file_exists(SENTIMENT_RESULTS_FILE_PATH)

if file_exists:
    print(f"The file exists in the current directory.")
else:
    print(f"The file does not exist in the current directory.")
    empty_sentiment_df = ds.create_empty_sentiment_df(text_df, CATEGORIES)
    ds.save_dataframe_to_csv(empty_sentiment_df, SENTIMENT_RESULTS_FILE_PATH)
    print(f"Created and saved an empty sentiment analysis DataFrame to {SENTIMENT_RESULTS_FILE_PATH}")
# Out:
# The file exists in the current directory.

# %% [markdown]
# ### NOTE: If you want to re-run the sentiment analysis, delete or archive the csv to create a blank one

# %% [markdown]
# # Sentiment Analysis
# NOTE: Google gemini **currently** has a daily query limit of 1,500 requests per day.  As we have over 10,000 documents, the code will be designed to run over multiple days and pick up where we last left off.  After the code is run, the user will still need to manually download the csv and upload to github.

# %% [markdown]
# **Gemini Free Rate Limits**
# *   15 RPM (requests per minute)
# *   1 million TPM (tokens per minute)
# *   1,500 RPD (requests per day)

# %%
# Find the first unique ID with empty values
unique_id = ds.find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
print(unique_id)
# Out:
# IR-1

# %%
# Get Gemini inputs
company, source, headline, text = ds.get_model_inputs(text_df, unique_id)
print(f"Company: {company}\n")
print(f"Source: {source}\n")
print(f"Headline: {headline}\n")
print(f"Text:\n{text}")
# Out:
# Company: MRO
#
# Source: Investment Research
#
# Headline: Marathon Oil Corporation
#
# Text:
# Stock Report | May 16, 2024 | NYSESymbol: MRO | MRO is in the SGP 500
# Marathon Oil Corporation
#
# Recommendation Price 12-Mo. Target Price Report Currency
# | HOLD | «| * | | USD 26.44 (as of market close May 15, 2024) USD 28.00 USD
#
# Equity Analyst Jonnathan Handshoe
#
# CFRA
#
# Investment Style
# Mid-Cap Blend
#
# GICS Sector Energy
# Sub-Industry Oil and Gas Exploration and Production
#
# Summary Having spun off downstream assets in mid-2011, MRO is now an independent upstream
# company with mainly U.S. operations, complemented by assets in Equatorial Guinea.
#
# Key Stock Statistics (Source: CFRA, S&P Global Market Intelligence (SPGMI), Company Reports)
#
# 52-Wk Range USD 30.06 - 21.81 Oper.EPS2024E USD 2.82 = Market Capitalization[B] USD 14.91 Beta 2.23
# Trailing 12-Month EPS USD 2.49  Oper.EPS2025E USD 3.20 = Yield [%] 1.66 = 3-yr Proj. EPS CAGR[%] 7
# Trailing 12-Month P/E 10.62 P/E on Oper.EPS2024E 9.38 Dividend Rate/Share USD 0.44 = SPGMI's Quality Ranking B-
# USD 10K Invested 5 Yrs Ago 18,349.0 Common Shares Outstg.[M] 568.00 = Trailing 12-Month Dividend USDO.53 Institutional Ownership [%] 81.0
# Price Performance Analyst's Risk Assessment
# 30-Week Mov. Avg. ==== 10-Week Mov. Avg. == == GAAP Earnings vs. Previous Year Volume Above Avg. Hh STARS LOW MEDIUM HIGH
# 12-Mo. Target Price = A. Up YW Down p> No Change Below Avo. || xl In early 2020, we lifted our Risk Assessment on MRO to
#
# High from Medium. This is due in part to the ongoing shift
# in portfolio mix, with an increased emphasis on the Eagle
# Ford and Bakken shale plays, as well as a streamlining of
# international operations to a single location. In addition,
# with about 26% of total production coming from the
# Bakken, we note exposure to the possibility of a court-
# ordered shutdown of the Dakota Access Pipeline (which we
# think could indirectly put pressure on crude oil pricing in-
# region). Finally, we note low use of hedging for 2022, which
# could be savvy or ill-timed, depending on crude oil prices.
#
# Share Price
#
# Vol (ln)
#
# hth lil lh = pial tition ttn
#
# Revenue/Earnings Data
#
# AMJJASONDJFMAMJJASONDJFMAMJJASONDJFMAMJJASONOJFMAMJJASONDJFMAMJJ Revenue (Million USD)
#
# 2019 2020 2021 2022 2023 2024 1Q 2Q 3Q 4Q Year
# 2025 E1,789 €1,765 E1,797 £1,804 £7155
# Source: CFRA, S&P Global Market Intelligence e0ed 1536 £1,705 £1,805 £1,785 £6,843
# P . a . 2023 1,680 1,513 1,813 1,612 6,453
# ast performance is not an indication of future performance and should not be relied upon as such. 5922 1753 3 303 9 O47 1.733 8.536
# Analysis prepared by Jonnathan Handshoe on May 16, 2024 01:06 PM, when the stock traded at USD 26.27. 5021 1180 1.259 1.439 1.229 4157
# Highlights Investment Rationale/Risk e020 1,031 496 784 831 3,122
#
# > In Q1 2024, MRO’s total production (371k boe/ —_—& Our rating is Hold. Crude oil prices will likely Earnings Per Share (USD)
# d] fell 6% Y/Y and 8% sequentially due to remain flat in 2024 vs, 2023, as the EIA 1Q 2Q 3Q 4Q Year
# weaker international volumes (-18%]. MRO estimates WTI pricing to average about $78/b in 2025 E079 £078 E081 E082 £3.20
# reiterated its 2024 production guidance, with 2024 [in line with about $78/b in 2023). 2024 055 £0.70 E077 E080 E282
# production expected to be in the range of 390k However, natural gas prices are expected to 2023 0.67 0.48 0.77 0.69 2.61
# boe/d at the midpoint (vs. 405k boe/d in 2023), average $2.27/MMBtu in 2024 (vs. $2.54/ 2022 1.02 1.32 124 0.88 4.46
# as it expects to see a 10% decrease in MMBtu in 2023], which could present 2021 0.21 0.22 0.39 0.77 1.57
# 2020 -0.16 -0.60 -0.28 -0.12 -1.16
#
# international production volumes.
#
# > In Q1 2024, MRO’s capex ($603 million)
# increased 13% Y/Y and about 68% sequentially.
# For 2024, MRO expects capex to be in the range
# of $2 billion at the midpoint (in line with $2
# billion in 2023). We see MRO with free cash flow
# in the range of $2 billion {in line with $2 billion
# in 2023) in 2024. MRO anticipates it can return
# a minimum of 40% of its operating cash flaws
# to shareholders (we estimate approximately
# $1.6 billion) in 2024, which we believe is fair
# given that its breakeven price post dividend is
# under $50 per barrel.
#
# > In Q1 2024, MRO’s revenue (about $1.6 billion)
# fell 8% Y/Y and sequentially, driven by weaker
# natural gas pricing (-15%]. For 2024, we see
# MRO with revenue growth of about 2% on lower
# production volumes, and 2% growth in 2025.
#
# headwinds to MRO’s earnings potential, given
# that natural gas production accounts for 30% of
# its total production. We estimate MRO has
# hedged around 30% of its expected 2024
# production with an average floor price of $65/b
# and a ceiling price of $101.50/b. For 2024, MRO
# has guided to $3.9 billion in operating cash
# flows (vs. $4.1 billion in 2023). However, we are
# wary of its cash flow goals should energy prices
# fall due to concerns surrounding demand and
# having a small portion of its expected
# production hedged.
#
# > Risks to our recommendation and target price
#
# include weaker-than-expected crude oil or
# natural gas prices; unfavorable regulatory
# changes, particularly in the Bakken Shale; and
# higher-than-expected oil services cost inflation.
#
# > Our 12-month target price of $28 implies a 4.8x
#
# forward multiple of enterprise value to projected
# 2024 EBITDA, in line with MRO’s historical
# average. Shares yield 1.7%.
#
# Fiscal Year ended Dec 31. EPS Estimates based on CFRA's
# Operating Earnings; historical earnings are adjusted. In periods
# where a different currency has been reported, this has been
# adjusted to match the current quoted currency.
#
# Dividend Data
#
# Amount Date Ex-Div. Stk. of Payment
# ( USD) Decl. Date Record Date
# 0.1100 Apre4 May14 May15  Jun10'24
# 0.1100 Jan31 Feb20 Feb21 = Mari1l'24
# 0.1100 Oct2S5 Novl4 Novi15  Dec1l'23
# 0.1000 Jule6 Aug15 Augl16 Sep1l1'23
#
# Dividends have been paid since 1971 . Source: Company reports
# Past performance is not an indication of future performance
# and should not be relied as such.
#
# Forecasts are not a reliable indicator of future performance.
# Dividends paid in currencies other than the Trading currency have
# been accordingly converted for display purposes.
#
# Redistribution or reproduction is prohibited without written permission. Copyright ©2024 CFRA. This document is not intended to provide personal investment advice and it does not take into account the specific investment
# objectives, financial situation and the particular needs of any specific person who may receive this report. Investors should seek independent financial advice regarding the suitability and/or appropriateness of making an investment
# or implementing the investment strategies discussed in this document and should understand that statements regarding future prospects may not be realized. Investors should note that income from such investments, if any,
# may fluctuate and that the value of such investments may rise or fall. Accordingly, investors may receive back less than they originally invested. Investors should seek advice concerning any impact this investment may have on
# their personal tax position from their own tax advisor. Please note the publication date of this document. It may contain specific information that is no longer current and should not be used to make an investment decision. Unless
# otherwise indicated, there is no intention to update this document. 1
#
# Stock Report | May 16, 2024 | NYSESymbol: MRO | MRO is in the SGP 500
# Marathon Oil Corporation
#
# CFRA
#
# Business Summary Mar 13, 2024
#
# CORPORATE OVERVIEW. Until mid-2011, Marathon Oil (MRO, formerly USX-Marathon Group, a part of USX
# Corp.) was engaged in three operating segments: Exploration & Production; Oil Sands Mining, Refining,
# Marketing, and Transportation; and Integrated Gas. In June 2011, MRO spun off its downstream RM&T
# business into a new publicly traded entity, Marathon Petroleum Corp. (MPC 175 ***}, and, in June 2017, sold
# its former Oil Sands division in Canada. MRO now operates just two segments—U.S. E&P and International
# ESP.
#
# The company’s estimated proved reserves, as of December 31, 2023, totaled approximately 1.3 bboe (billion
# barrels of oil equivalent], in line with 2022 levels. At this estimated level, and assuming that 2023 production
# levels could be held constant, MRO’s estimated reserve life (the amount of time it would take before such
# reserves would be exhausted] is 8.9 years, which is well below the peer average of about 15 years. As a
# result, while replacing reserves is an issue for any oil and gas producer, in our view, this takes on acute
# significance for MRO.
#
# MRO possesses a fairly diverse set of assets in the U.S., with four different regions contributing significant
# production. The U.S. EGP segment (355,000 barrels of oil equivalent per day in 2023, up 71,000 boe/d
# versus 2022 production) was comprised of Eagle Ford shale assets in South Texas (151,000 boe/d), the
# Bakken Shale (111,000 boe/d), Oklahoma Resource plays (50,000 boe/d), the Permian Basin (41,000 boe/
# dj, and other shale plays comprising the remaining 2,000 boe/d.
#
# U.S. acreage acquisitions have been fairly frequent in the last few years. In 2018, MRO acquired an additional
# 61,000 acres in Oklahoma, on top of its existing 265,000 acres, which we think will add meaningfully to its
# liquids production in the state going forward. In addition, MRO purchased 70,000 net acres in the Northern
# Delaware section of the Permian Basin for $1.9 billion, an average price of about $27,000 per acre. We view
# this as a reasonable price for Permian acreage, although a premium to many other shale plays. In the fourth
# quarter of 2019, MRO acquired approximately 18,000 net acres in the Eagle Ford for $191 million and
# approximately 40,000 acres in a Texas Delaware oil play in West Texas for $106 million. As of December 31,
# 2023, MRO’s held net acreage stood at 1,113,000 acres (down from 1,176,000 acres in 2022), with the U.S.
# making up 94% and Equatorial Guinea making up 6%.
#
# The company’s International EGP segment (50,000 boe/d in 2023, down 9,000 boe/d from 2022) now
# consists solely of acreage in Equatorial Guinea.
#
# MRO has made recent improvements in its cost structure. In 2023, MRO achieved an average production
# cost of $10.13/boe, down 3% from $10.42/boe in 2022. Meanwhile, costs in Equatorial Guinea grew 36% to
# $4.13/boe. Essentially, the gap in costs between the two regions closed, but production costs in Africa
# remain considerably lower than those in the U.S.
#
# CORPORATE STRATEGY. MRO’s growth assets are where it expects to make significant investments in order
# to realize oil and gas production and reserve increases. It is focused on U.S. growth by developing liquids-
# rich shale play positions, a strong position in the core of the Eagle Ford shale and in the Bakken shale. As of
# March 2024, MRO plans to spend $2 billion on capital investments in 2024, as it expects to operate
# approximately nine rigs and four frac crews on average in 2024 while keeping production levels flat.
#
# IMPACT OF MAJOR DEVELOPMENTS. Over 2017-2020, MRO has steadily pursued non-core asset sales to
# streamline the company to a handful of core plays. Almost all of this activity has been outside North
# America, although the largest proceeds came from its 2017 sale of its former Canadian operations for $2.5
# billion. In 2019, MRO sold its former U.K. assets for $95 million, along with its Kurdistan assets for $63
# million. In 2018, MRO sold its former Libya assets for $450 million. Collectively, from 2017 through 2019,
# MRO sold assets that yielded net proceeds of roughly $3.0 billion.
#
# FINANCIAL TRENDS. In October 2023, MRO boosted its quarterly dividend to a revised $0.11 per share, versus
# prior $0.10 per share. The implied annual dividend of $0.44 per share is a 1.8% dividend yield. In addition,
# MRO has aggressively repurchased around $5 billion of shares since October 2021, reducing its share count
# by about 27%. In 2023, MRO generated around $2 billion in free cash flow, in line with $2 billion in 2022. We
# estimate MRO with free cash flow in the range of $2 billion in 2024, with a payout ratio of about 15%; we see
# opportunities for additional buybacks or further dividend hikes.
#
# Corporate information
#
# Investor contact
# G. A. Baber (713 629 6600)
#
# Office
# 990 Town and Country Boulevard, Houston, Texas,
# 77024-2217
#
# Telephone
# 713 629 6600
#
# Fax
# N/A
#
# Website
# www.marathonoil.com
#
# Officers
# Chairman, President & CEO Senior VP of Technology &
# L. M. Tillman Innovation and Chief
#
# oo . Information Officer
# Executive Vice President of B. A. McCullough
# Operations
# M. A. Henderson Executive VP, General
# Counsel & Secretary
#
# Executive VP & CFO K. 0. Warnica
#
# R. L. White
# VP, Controller & Chief
# Accounting Officer
#
# Z. Dailey
# Board Members
# B. J. Smolik M. A. McCollum
# C. C. Deaton M. E. Donadio
# H. C. Ladhani M. E. Hyland
# L. M. Tillman S. D. Williams
# Domicile Auditor
# Delaware PricewaterhouseCoopers
# LLP
# Founded
# 1887
# Employees
# 1,681
# Stockholders
# 23,837
#
# Redistribution or reproduction is prohibited without prior written permission. Copyright ©2024 CFRA.
#
# Stock Report | May 16, 2024 | NYSESymbol: MRO | MRO is in the SGP 500 CFRA
# Marathon Oil Corporation
#
# Fair Value Rank 5 2023 «42022 8=62021 = 2020
#
# LOWEST HIGHEST  Price/Sales 2.28 2.46 2.30 1.69
#
# Based on CFRA's proprietary quantitative model, Price/Tangible Book Value 1.24 1.50 1.14 0.50
#
# stocks are ranked from most overvalued (1) to most Price/Pretax Income 7.69 4.92 12.89 NM
#
# undervalued (5). P/E Ratio 9.26 6.04 10.46 NM
# Fair Value USD Analysis of the stock’s current worth, based on CFRA’s Avg. Diluted Shares Outstg. (M} 608.00 68700 788.09 792.00
# Calculation 29.29 proprietary quantitative model suggests that MRO is Figures based on fiscal year-end price
#
# undervalued by USD 2.85 or 10.78%
#
# a Key Growth Rates and averages
#
# Technical BEARISH Since May, 2024, the technical indicators for MRO
#
# Evaluation have been BEARISH" Past Growth Rate (%) 1Year 3Years_ 5 Years
# Net Income NM 2.31 7.23
# Insider Activity NEUTRAL Revenue 14.81 27.38 1.29
# Ratio Analysis (Annual Avg.)
# Net Margin (%] 24.08 29.54 10.30
# % LT Debt to Capitalization 20.01 26.17 28.59
# Per Share Data (USD} 2023 2022 2021 2020 2019 2018 2017 2016 2015 2014
# Tangible Book Value 19.43 18.00 14.38 13.38 15.14 14.69 13.64 20.57 27.24 30.46
# Free Cash Flow 3.38 5.76 2.80 0.16 0.25 0.57 0.18 -0.08 -2.69 0.48
# Earnings 2.56 5.26 1.20 -1.83 0.59 1.29 -0.98 -2.55 -2.51 142
# Earnings (Normalized) 2.61 4.48 1.57 -1.16 0.75 0.71 -0.25 -0.85 -1.28 2.53
# Dividends 0.42 0.35 0.22 0.06 0.20 0.20 0.20 0.20 0.52 0.80
# Payout Ratio (%] 16.15 6.09 14.90 NM 33.75 15.42 NM NM NM 17.83
# Prices: High 32.54 33.42 17.59 14.07 18.93 24.20 18.27 19.28 31.53 41.92
# Prices: Low 20.57 16.23 6.60 3.02 11.06 12.57 10.55 6.52 12.11 24.28
# P/E Ratio: High 12.50 7.50 11.20 NM 25.20 34.10 NM NM NM 16.60
# P/E Ratio: Low 7.90 3.60 4.20 NM 14.70 17.70 NM NM NM 9.60
# Income Statement Analysis [Million USD)
# Revenue 6,453 7,575 5,616 3,122 5,125 6,052 4,487 3,198 4,557 10,684
# Depreciation + Amortization 2,250 1,818 2,066 2,316 2,397 2,649 2,847 2,418 3,757 3,299
# Operating Expenses 662.00 982.00 1138 523.00 885.00 1,010 1,247 1,080 2,911 2,447
# Effective Tax Rate (%] 18.70 4.40 5.80 1.00 -22.40 23.20 -82.80 -79.30 30.30 28.80
# Net Income 1,554 3,612 946.00 NM 480.00 1,096 NM NM NM 3,046
# Net Income (Normalized) 1,185 2,401 760.00 NM 230.60 739.40 NM NM NM 906.90
# Balance Sheet and Other Financial Data [Million USD)
# Gross Property 43,370 41,400 36,998 36,129 35,202 38,634 39,229 36,982 50,321 50,924
# Net Property 17456 17,524 14,586 15,771 17199 16,804 17665 16,727 27,061 29,040
# Capital Expenditures 2,033 1,480 1,032 1,343 2,550 2,753 1,974 1,204 3,485 5,160
# Capital Expnd to Revenue (%] 31.50 19.50 18.40 43.00 49.80 45.50 44.00 37.60 76.50 48.30
# % Long Term Debt of Capitalization 20.00 31.60 26.90 33.60 30.80 31.20 31.90 26.50 28.20 19.30
# Capitalization: Common 11,205 11,397 10,686 10561 12153 12128 11,708 17541 18,553 21,020
# Capitalization: Preferred N/A N/A N/A N/A N/A N/A N/A N/A N/A N/A
# Fixed Charges Coverage 6.03 16.43 5.67 -3.25 1.88 4.23 -1.38 -3.80 -6.32 4.57
# % Operating Ratio 66.84 69.11 57.28 46.38 57.03 63.33 53.49 31.96 38.05 42.72
# % Net Income Margin 24.08 47.68 16.84 -46.48 9.37 18.11 -12755 -66.92 -48.37 28.51
# % Return on Invested Capital 7.51 13.24 4.65 -3.19 1.85 4.25 -1.33 -3.45 -4.75 2.97
# % Return on Common Equity 13.80 32.70 8.90 -12.80 4.00 9.20 -5.70 -11.60 -8.60 4.80
#
# Source: S&P Global Market Intelligence. Data may be preliminary or restated; before results of discontinued operations/special items. Per share data adjusted for stock dividends; EPS diluted.
# E-Estimated. NA-Not Available. NM-Not Meaningful. NR-Not Ranked. UR-Under Review.
#
# Redistribution or reproduction is prohibited without prior written permission. Copyright ©2024 CFRA. 3
#
# Stock Report | May 16, 2024 | NYSESymbol: MRO | MRO is in the SGP 500
#
# Marathon Oil Corporation
#
# CFRA
#
# Our fundamental outlook for the oil & gas
# exploration and production (E&P) sub-industry for
# the next 12 months is neutral, recently cut from
# positive. We had previously thought that
# disciplined cuts from key producing nations should
# be able to blunt demand weakness that may occur
# in 2024. We now, however, see more question
# marks on both counts.
#
# On the supply side, the OPEC cartel lost Angola as
# a member, and the December 2023 OPEC meeting
# ended poorly, in our view, with no collective
# agreement on voluntary cuts beyond quotas. It is
# not out of the realm of possibility that OPEC
# discipline - which has been remarkably strong
# since the onset of Covid-19 - could begin to wane
# if cartel members grow tired of voluntary cuts,
# particularly while U.S. production rises. On the
# demand side, China remains the linchpin for global
# incremental demand growth, and the early 2024
# consensus estimate on China’s real GDP growth in
# 2024 is a mere 4.6%, per NikkeiAsia, down 60 bps
# from 2023. Meanwhile, the International Energy
# Agency sees crude oil demand growth of 1.2 mmb/
# din 2024 (+1.2%], roughly in line with normalized
# demand growth. While it is possible for global
# demand growth to be typical even if China’s GDP
# disappoints, we think this may be challenging.
#
# For U.S. West Texas Intermediate (WTI) crude, we
# think an overall average in the $75 to $80 per
# barrel (/b} range for 2024 as a whole (versus $78/
# b in 2023) is viable. U.S. producers continue to
# show a preference for free cash flow growth over
# production growth, although we do expect the U.S.
# to eke out a small increase in domestic
# production, likely 300,000 b/d to an estimated
# 13.2 mmb/d. For U.S. natural gas, we think prices
# will improve marginally, but remain below $3.00
# per million BTU in 2024. We do not bake ina
# substantial geopolitical risk premium for energy
# prices, unless the Israel-Gaza war spreads to Iran
# and adversely affects Iran’s crude oil production
# (currently 3.2 mmb/d).
#
# E&Ps in 2024 should see a flattish earnings
# profile, albeit at a relatively high level. We think
# both 2023 and 2024 will ultimately exhibit strong
#
# earnings power relative to most of the prior
# decade, but not as strong as in the 2022 peak.
# Most E&Ps today feature strong balance
# sheets, their cost structures are in good shape,
# and the conservative approach to spending
# should yield strong free cash flows. As a result,
# we still expect EGPs to support dividend and
# buyback programs, augmented by modest
# capex growth.
#
# Commercial crude inventories stood at 429.9
# million barrels in early January 2024, 3% below
# the five-year average for this time of year. The
# crude oil futures curve is currently in only slight
# backwardation, which does not really
# incentivize further storage.
#
# The U.S. EIA noted that the U.S. working gas in
# storage stood at 3.18 tcf as of mid January
# 2024, 11% above the five-year average for this
# time. The EIA also projects Henry Hub natural
# gas prices to average $2.66/MMBtu in 2023
# (slightly above the average of $2.54/MMBtu in
# 2023), rising to $2.95/MMBtu in 2025.
#
# In 2023, the S&P Oil & Gas Exploration &
# Production Index was down 3.0% versus a
# 23.4% gain in the S&P 1500 Composite Index.
#
# | Stewart Glickman, CFA
#
# GICS Sector:Energy
# Sub-Industry:Oil and Gas Exploration and Production
#
# Based on S&P 1500 Indexes
# Five-Year market price performance through May 11, 2024
#
# — NYSE:MRO —— Sub-Industry ~~ S&P 1500
#
# 160% ~
#
# 120% ~
#
# 80% ~
#
# 40% +
#
# % Change
#
# 0% -
#
# -40% +
#
# -B0% +
#
# 2020 2021 2022 2023 2024
# NOTE: A sector chart appears when the sub-industry does not have
# sufficient historical index data.
#
# All Sector & Sub-Industry information is based on the Global Industry
# Classification Standard (GICS}.
#
# Past performance is not an indication of future performance and should
# not be relied upon as such.
#
# Source: CFRA, S&P Global Market Intelligence
#
# Stock
# Peer Group Symbol
# Marathon Oil Corporation MRO
# APA Corporation APA
# ARC Resources Ltd. AETU.F
# Antero Resources Corporation AR
# Chesapeake Energy Corporation CHK
# Coterra Energy Inc. CTRA
# EQT Corporation EQT
# Ovintiv Inc. Ov
# Permian Resources Corporation PR
# Texas Pacific Land Corporation TPL
# Tourmaline Oil Corp. TRML.F
#
# Recent 30-Day 1-Year Fair Return
# Stock Stk. Mkt. Price Price P/E Value Yield on Equity LTD to
# Exchange Currency Price Cap.(M) Chg.(%J Chg. (%) Ratio Calc. (%) (%) Cap (%)
# NYSE USD 26.57 14,986.0 -8.7 17.2 11.0 29.29 1.7 12.7 27.6
# NasdagGS USD 30.17 11,199.0 -10.5 -8.4 7.0 15.26 3.3 121.6 57.5
# OTCPK USD 18.42 5,037.0 -17 44.2 3.0 N/A 2.7 16.7 118
# NYSE USD 33.97 10,558.0 14.0 50.8 334.0 17.01 N/A 18 12.9
# NasdagGS USD 90.81 11,901.0 2.5 10.7 2.0 N/A 2.5 10.1 15.9
# NYSE USD 28.16 20,958.0 19 10.2 5.0 28.27 3.0 10.1 12.9
# NYSE USD 40.71 17,9770 9.3 15.8 28.0 34,02 15 45 23.7
# NYSE USD 49.78 13,324.0 -74 48.9 8.0 46.79 2.4 21.3 31.4
# NYSE USD 16.83 9,802.0 -5.1 793.0 5.0 N/A 48 11.7 29.2
# NYSE USD 607.68 13,970.0 0.3 33.0 32.0 N/A 0.8 44.4 N/A
# OTCPK USD 47.90 23,100.0 0.5 11.1 3.0 N/A 19 12.7 8.6
#
# *For Peer Groups with more than 10 companies or stocks, selection of issues is based on market capitalization.
#
# NA-Not Available; NM-Not Meaningful.
#
# Note: Peers are selected based on Global Industry Classification Standards and market capitalization. The peer group list includes companies with similar characteristics, but may not include all the companies within the same
#
# industry and/or that engage in the same line of business.
#
# Redistribution or reproduction is prohibited without prior written permission. Copyright ©2024 CFRA.
#
# Stock Report | May 16, 2024 | NYSESymbol: MRO | MRO is in the SGP 500
#
# Marathon Oil Corporation
#
# CFRA

# %%
# Define the prompt template
prompt_template = f"""
Given the text from {{source}} about {{company}}, analyze the content and perform sentiment analysis across multiple predefined categories.

Sentiment options:
  - Positive
  - Neutral
  - Negative

Categories:
  - Finance
  - Production
  - Reserves / Exploration / Acquisitions / Mergers / Divestments
  - Environment / Regulatory / Geopolitics
  - Alternative Energy / Lower Carbon
  - Oil Price / Natural Gas Price / Gasoline Price

Each category should be evaluated and given a sentiment output derived from the text.
If a category is not mentioned or relevant based on the text content, mark it as 'Neutral'.

Before giving your answer, explain your reasoning and reference the article.
After going through all the categories, provide a summary in the following format:
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment

Example Output:
- Finance - Positive
- Production - Neutral
- Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative
- Environment / Regulatory / Geopolitics - Neutral
- Alternative Energy / Lower Carbon - Positive
- Oil Price / Natural Gas Price / Gasoline Price - Neutral

Make sure to use plain text, do not bold or bullet the output summary.

The text from {{source2}} is below:
{{headline}}
{{text}}

Remember to summarize your final answers in the following format exactly:
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment
- Category - Sentiment

Make sure to use plain text and stick to the given categories and sentiment options.
DO NOT bold or bullet the output summary.
"""

# %%
# Create the actual prompt
text_source_dict = {
    "Investment Research": ("an analyst report", "the analyst report"),
    "ProQuest": ("a news article", "the news article"),
    "SEC Filings": ("an SEC filing", "the SEC filing"),
    "Earnings Call Presentations": ("an earnings call presentation", "the earnings call presentation"),
    "Earnings Call Q&A": ("an earnings call Q&A session", "the earnings call Q&A session")
}
text_source, text_source2 = text_source_dict.get(source, ("a source", "the source"))

# %%
prompt = prompt_template.format(source=text_source, source2=text_source2, company=company, headline=headline, text=text)

# %%
# Set up Gemini
model = gs.configure_gemini()

# Query Gemini
response = gs.query_gemini(prompt, model)
print(response)

# Parse sentiment
sentiment_dict = gs.parse_sentiment(response, CATEGORIES)
print(type(sentiment_dict))
# Out:
# Here's an analysis of the analyst report on MRO, categorized by sentiment:
#
# **Reasoning:**
#
# * **Finance:** The report highlights MRO's strong financial performance, including its dividend increase, share buybacks, and free cash flow generation. The analyst expects this trend to continue.
# * **Production:**  The report notes that MRO expects production to remain flat in 2024,  but this is not necessarily a negative sentiment. It reflects a focus on free cash flow over production growth, a common industry trend.
# * **Reserves / Exploration / Acquisitions / Mergers / Divestments:** The report mentions MRO's reserve life being below the peer average, leading to concerns about reserve replacement. While MRO has been active in acquiring acreage, the report also points out the decline in its net acreage held from 2022 to 2023. This suggests a mixed picture, making the sentiment slightly negative.
# * **Environment / Regulatory / Geopolitics:** The report mentions potential risks related to regulatory changes in the Bakken Shale and a possible shutdown of the Dakota Access Pipeline. This uncertainty creates a negative sentiment in this category.
# * **Alternative Energy / Lower Carbon:** There is no mention of alternative energy or lower carbon initiatives in the report.
# * **Oil Price / Natural Gas Price / Gasoline Price:** The report discusses expectations for flat oil prices in 2024, with a slight improvement in natural gas prices. However, the analyst is wary of MRO's cash flow goals should energy prices fall. Overall, the sentiment is neutral.
#
# **Summary:**
#
# - Finance - Positive
# - Production - Neutral
# - Reserves / Exploration / Acquisitions / Mergers / Divestments - Negative
# - Environment / Regulatory / Geopolitics - Negative
# - Alternative Energy / Lower Carbon - Neutral
# - Oil Price / Natural Gas Price / Gasoline Price - Neutral
#
# <class 'dict'>

# %%
# Check if sentiment_dict is a dictionary before updating the CSV
if isinstance(sentiment_dict, dict):
    gs.update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict)
else:
    print("Error: Sentiment dictionary not found. Skipping update.")
# Out:
# Row with Unique_ID 'IR-1' has been updated.
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Positive' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Neutral' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Negative' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Negative' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Neutral' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment
# /Users/ilyaskussanov/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:103: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Neutral' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[row_index, category] = sentiment

# %%
# Main Loop
start_time = time.time()
unique_id = ds.find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
count = 0
max_tries = 5

while unique_id:
    retries = 0
    success = False

    while retries < max_tries and not success:
        try:
            company, source, headline, text = ds.get_model_inputs(text_df, unique_id)
            text_source, text_source2 = text_source_dict.get(source, ("a source", "the source"))
            prompt = prompt_template.format(source=text_source, source2=text_source2, company=company, headline=headline, text=text)
            response = gs.query_gemini(prompt, model)
            sentiment_dict = gs.parse_sentiment(response, CATEGORIES)

            # Check if sentiment_dict is a dictionary before updating the CSV
            if isinstance(sentiment_dict, dict):
                gs.update_csv(SENTIMENT_RESULTS_FILE_PATH, unique_id, sentiment_dict)
                success = True
            else:
                print("Error: Sentiment dictionary not found. Skipping update.")
                success = True  # To break the retry loop

        except Exception as e:
            retries += 1
            print(f"Error encountered: {e}. Retry {retries}/{max_tries}")

            if retries >= max_tries:
                print(f"Failed to process unique_id {unique_id} after {max_tries} attempts. Stopping.")
                unique_id = None
                break

    if not success:
        break

    count += 1
    if count % 10 == 0:
        elapsed_time = time.time() - start_time
        minutes, seconds = divmod(elapsed_time, 60)
        print(f"Iteration: {count}, Elapsed Time: {int(minutes)} minutes and {seconds:.2f} seconds")

    unique_id = ds.find_first_unique_id_with_empty_values(SENTIMENT_RESULTS_FILE_PATH, CATEGORIES)
# Out:
# Row with Unique_ID 'IR-2' has been updated.
# Row with Unique_ID 'IR-3' has been updated.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 16
#      14 text_source, text_source2 = text_source_dict.get(source, ("a source", "the source"))
#      15 prompt = prompt_template.format(source=text_source, source2=text_source2, company=company, headline=headline, text=text)
# ---> 16 response = gs.query_gemini(prompt, model)
#      17 sentiment_dict = gs.parse_sentiment(response, CATEGORIES)
#      19 # Check if sentiment_dict is a dictionary before updating the CSV
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/10_Source_Code/gemini_setup.py:57, in query_gemini(prompt, model)
#      46 def query_gemini(prompt, model):
#      47     """
#      48     Query Gemini to perform sentiment analysis on text from various sources about a company.
#      49
#    (...)
#      55         str: The sentiment analysis results for predefined categories in the specified format.
#      56     """
# ---> 57     response = model.generate_content(prompt)
#      58     return response.text
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/generativeai/generative_models.py:258, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     256         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     257     else:
# --> 258         response = self._client.generate_content(
#     259             request,
#     260             **request_options,
#     261         )
#     262         return generation_types.GenerateContentResponse.from_response(response)
#     263 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:812, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     809 self._validate_universe_domain()
#     811 # Send the request.
# --> 812 response = rpc(
#     813     request,
#     814     retry=retry,
#     815     timeout=timeout,
#     816     metadata=metadata,
#     817 )
#     819 # Done; return the response.
#     820 return response
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/grpc/_channel.py:1178, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1166 def __call__(
#    1167     self,
#    1168     request: Any,
#    (...)
#    1173     compression: Optional[grpc.Compression] = None,
#    1174 ) -> Any:
#    1175     (
#    1176         state,
#    1177         call,
# -> 1178     ) = self._blocking(
#    1179         request, timeout, metadata, credentials, wait_for_ready, compression
#    1180     )
#    1181     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/Documents/GitHub/Financial_Sentiment_LLM/LLM/lib/python3.9/site-packages/grpc/_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:400, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:
