# %% [markdown]
# # Import Libraries and Data

# %%
# import libraries
import os
from google.colab import userdata
from google.colab import output
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Import github token with google secrets thingy and clone git repository
GITHUB_TOKEN = userdata.get('github')
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
# !git clone https://{GITHUB_TOKEN}@github.com/Kussil/Financial_Sentiment_LLM.git
# Out:
# fatal: destination path 'Financial_Sentiment_LLM' already exists and is not an empty directory.

# %%
# Load prepped data
gemini_sentiment = pd.read_csv('/content/Financial_Sentiment_LLM/04_Stock_Modeling/Flat_Stock_Data/Gemini_Prompt2/02_Prompt2_Gemini_Prepped_Stock_Data.csv')
print(gemini_sentiment.shape)
display(gemini_sentiment.head())
print(gemini_sentiment.isna().sum())
# Out:
# (9474, 12)
#                 Source      Unique_ID Ticker        Date  \
# 0             ProQuest  PQ-2463687415     BP  2019-01-09
# 1             ProQuest  PQ-2311280728     BP  2019-02-11
# 2  Investment Research        IR-4891     BP  2019-02-20
# 3             ProQuest  PQ-2300507429     BP  2019-03-10
# 4             ProQuest  PQ-2311444292     BP  2019-03-11
#
#                                                  URL   Finance Production  \
# 0  https://www.proquest.com/newspapers/markets-co...  Positive    Neutral
# 1  https://www.proquest.com/newspapers/arabia-sau...   Neutral    Neutral
# 2                                                NaN  Positive   Positive
# 3  https://www.proquest.com/newspapers/bp-ceo-ste...  Positive    Neutral
# 4  https://www.proquest.com/newspapers/aramco-arr...  Positive    Neutral
#
#   Reserves/M&A Regulatory Green Energy  OG Price   Returns
# 0     Positive    Neutral      Neutral   Neutral  0.008244
# 1      Neutral    Neutral      Neutral   Neutral -0.006589
# 2      Neutral    Neutral      Neutral  Positive  0.002360
# 3      Neutral   Negative      Neutral   Neutral  0.001894
# 4      Neutral    Neutral     Negative   Neutral  0.001894
# Source             0
# Unique_ID          0
# Ticker             0
# Date               0
# URL             4887
# Finance            0
# Production         0
# Reserves/M&A       0
# Regulatory         0
# Green Energy       0
# OG Price           0
# Returns            0
# dtype: int64

# %%
# Drop extra columns
gemini_sentiment = gemini_sentiment.drop(['Unique_ID','URL'], axis=1)

# Convert the 'Date' column to datetime
gemini_sentiment['Date'] = pd.to_datetime(gemini_sentiment['Date'])

# Sort by date for Grid Search using Time Split later
gemini_sentiment = gemini_sentiment.sort_values(by='Date')
gemini_sentiment = gemini_sentiment.reset_index(drop=True)
display(gemini_sentiment.head())
display(gemini_sentiment.tail())
# Out:
#                         Source Ticker       Date   Finance Production  \
# 0          Investment Research    CVX 2019-01-02  Positive   Positive
# 1          Investment Research    CVX 2019-01-02  Positive   Positive
# 2                  SEC Filings    CVX 2019-01-02  Positive    Neutral
# 3                  SEC Filings    XOM 2019-01-02   Neutral    Neutral
# 4  Earnings Call Presentations    XOM 2019-01-02  Positive   Positive
#
#   Reserves/M&A Regulatory Green Energy OG Price   Returns
# 0     Positive    Neutral      Neutral  Neutral -0.004365
# 1     Positive    Neutral      Neutral  Neutral -0.004365
# 2      Neutral    Neutral      Neutral  Neutral -0.004365
# 3      Neutral    Neutral      Neutral  Neutral  0.005200
# 4     Positive    Neutral      Neutral  Neutral  0.005200
#                    Source Ticker       Date   Finance Production Reserves/M&A  \
# 9469  Investment Research    XOM 2024-06-04   Neutral   Positive     Positive
# 9470          SEC Filings    OXY 2024-06-05   Neutral    Neutral      Neutral
# 9471  Investment Research    EOG 2024-06-05  Positive   Positive     Positive
# 9472             ProQuest    DVN 2024-06-05   Neutral    Neutral      Neutral
# 9473  Investment Research   SHEL 2024-06-05  Positive    Neutral      Neutral
#
#      Regulatory Green Energy  OG Price   Returns
# 9469    Neutral     Positive   Neutral -0.015553
# 9470    Neutral      Neutral   Neutral -0.000835
# 9471    Neutral     Positive   Neutral  0.004257
# 9472    Neutral      Neutral   Neutral -0.000643
# 9473    Neutral     Positive  Negative -0.003995

# %% [markdown]
# # One Hot Encode and Split Data

# %%
# One hot encode categorical variables
gemini_sentiment_encoded = pd.get_dummies(gemini_sentiment, columns=['Ticker',
                                                                     'Source',
                                                                     'Finance',
                                                                     'Production',
                                                                     'Reserves/M&A',
                                                                     'Regulatory',
                                                                     'Green Energy',
                                                                     'OG Price'], drop_first=True)
display(gemini_sentiment_encoded.head())
# Out:
#         Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 0 2019-01-02 -0.004365       False        True       False       False
# 1 2019-01-02 -0.004365       False        True       False       False
# 2 2019-01-02 -0.004365       False        True       False       False
# 3 2019-01-02  0.005200       False       False       False       False
# 4 2019-01-02  0.005200       False       False       False       False
#
#    Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  Production_Neutral  \
# 0        False       False       False       False  ...               False
# 1        False       False       False       False  ...               False
# 2        False       False       False       False  ...                True
# 3        False       False       False       False  ...                True
# 4        False       False       False       False  ...               False
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                 True                 False                   True
# 1                 True                 False                   True
# 2                False                  True                  False
# 3                False                  True                  False
# 4                 True                 False                   True
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0                True                False                  True
# 1                True                False                  True
# 2                True                False                  True
# 3                True                False                  True
# 4                True                False                  True
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                  False              True              False
# 1                  False              True              False
# 2                  False              True              False
# 3                  False              True              False
# 4                  False              True              False
#
# [5 rows x 33 columns]

# %%
# Split into test and train
split_date = pd.to_datetime('2024-01-01')

# Split the DataFrame
train_df = gemini_sentiment_encoded[(gemini_sentiment_encoded['Date'] < split_date)]
test_df = gemini_sentiment_encoded[gemini_sentiment_encoded['Date'] >= split_date]

display(train_df.tail())
display(test_df.head())
# Out:
#            Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 8976 2023-12-30  0.021702        True       False       False       False
# 8977 2023-12-30  0.005079       False       False       False       False
# 8978 2023-12-30 -0.020833       False       False       False       False
# 8979 2023-12-30  0.005672       False       False       False       False
# 8980 2023-12-30  0.021161       False       False        True       False
#
#       Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  \
# 8976        False       False       False       False  ...
# 8977        False       False       False       False  ...
# 8978        False        True       False       False  ...
# 8979        False       False       False       False  ...
# 8980        False       False       False       False  ...
#
#       Production_Neutral  Production_Positive  Reserves/M&A_Neutral  \
# 8976               False                 True                  True
# 8977                True                False                  True
# 8978                True                False                 False
# 8979                True                False                 False
# 8980               False                 True                 False
#
#       Reserves/M&A_Positive  Regulatory_Neutral  Regulatory_Positive  \
# 8976                  False                True                False
# 8977                  False               False                 True
# 8978                   True                True                False
# 8979                  False                True                False
# 8980                   True               False                False
#
#       Green Energy_Neutral  Green Energy_Positive  OG Price_Neutral  \
# 8976                  True                  False             False
# 8977                 False                   True              True
# 8978                  True                  False             False
# 8979                 False                   True              True
# 8980                  True                  False             False
#
#       OG Price_Positive
# 8976               True
# 8977              False
# 8978               True
# 8979              False
# 8980               True
#
# [5 rows x 33 columns]
#            Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 8981 2024-01-02  0.026961       False       False       False       False
# 8982 2024-01-02  0.002825       False       False       False       False
# 8983 2024-01-02  0.008637       False       False       False       False
# 8984 2024-01-03  0.019066       False        True       False       False
# 8985 2024-01-03  0.019066       False        True       False       False
#
#       Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  \
# 8981        False       False        True       False  ...
# 8982        False       False       False       False  ...
# 8983        False       False       False       False  ...
# 8984        False       False       False       False  ...
# 8985        False       False       False       False  ...
#
#       Production_Neutral  Production_Positive  Reserves/M&A_Neutral  \
# 8981                True                False                  True
# 8982               False                False                 False
# 8983                True                False                 False
# 8984                True                False                 False
# 8985               False                 True                 False
#
#       Reserves/M&A_Positive  Regulatory_Neutral  Regulatory_Positive  \
# 8981                  False                True                False
# 8982                  False               False                False
# 8983                   True                True                False
# 8984                   True               False                 True
# 8985                  False                True                False
#
#       Green Energy_Neutral  Green Energy_Positive  OG Price_Neutral  \
# 8981                 False                   True             False
# 8982                  True                  False             False
# 8983                  True                  False             False
# 8984                 False                   True              True
# 8985                  True                  False             False
#
#       OG Price_Positive
# 8981              False
# 8982              False
# 8983              False
# 8984              False
# 8985               True
#
# [5 rows x 33 columns]

# %%
# Define X and y
X_train = train_df.drop(columns=['Date','Returns'])
X_test = test_df.drop(columns=['Date','Returns'])

y_train = train_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)
y_test = test_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)

print(len(X_train), len(y_train), len(X_test), len(y_test))
display(X_train.head())
display(y_train.head())
# Out:
# 8981 8981 493 493
#    Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 0       False        True       False       False        False       False
# 1       False        True       False       False        False       False
# 2       False        True       False       False        False       False
# 3       False       False       False       False        False       False
# 4       False       False       False       False        False       False
#
#    Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Production_Neutral  \
# 0       False       False       False       False  ...               False
# 1       False       False       False       False  ...               False
# 2       False       False       False       False  ...                True
# 3       False       False       False       False  ...                True
# 4       False       False       False       False  ...               False
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                 True                 False                   True
# 1                 True                 False                   True
# 2                False                  True                  False
# 3                False                  True                  False
# 4                 True                 False                   True
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0                True                False                  True
# 1                True                False                  True
# 2                True                False                  True
# 3                True                False                  True
# 4                True                False                  True
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                  False              True              False
# 1                  False              True              False
# 2                  False              True              False
# 3                  False              True              False
# 4                  False              True              False
#
# [5 rows x 31 columns]
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: Returns, dtype: int64

# %% [markdown]
# # Random Forest

# %%
# Baseline Random Forest
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(rf_clf, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50       248
#            1       0.53      0.62      0.58       245
#
#     accuracy                           0.54       493
#    macro avg       0.54      0.54      0.54       493
# weighted avg       0.54      0.54      0.54       493

# %%
# Random Forest Tuned with GridSearchCV

# Define the parameter grid
param_grid = {
   'n_estimators': [500],
   'max_depth': [None, 10, 20, 30],
   'max_features': [None, 'sqrt', 'log2']
}

# Create a Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_clf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)

# Make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# {'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.27      0.34       248
#            1       0.48      0.69      0.57       245
#
#     accuracy                           0.48       493
#    macro avg       0.48      0.48      0.45       493
# weighted avg       0.48      0.48      0.45       493

# %%
# Extract feature importances from the best model
importances = best_model.feature_importances_
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'Feature {i}' for i in range(X_train.shape[1])]

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Sort the DataFrame by importance
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['Feature'], feature_importances_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %%
# Random Forest Tuned with GridSearchCV using TimeSeriesSplit

# Define the parameter grid
param_grid = {
   'n_estimators': [100, 250, 500],
   'max_depth': [None, 10, 20, 30],
   'max_features': ['sqrt', 'log2']
}

# Create a Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)

# Initialize TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)

# Initialize GridSearchCV with TimeSeriesSplit
grid_search = GridSearchCV(estimator=rf_clf, param_grid=param_grid, cv=tscv, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)

# Make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 250}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.27      0.34       248
#            1       0.48      0.69      0.57       245
#
#     accuracy                           0.48       493
#    macro avg       0.48      0.48      0.45       493
# weighted avg       0.48      0.48      0.45       493

# %%
# Extract feature importances from the best model
importances = best_model.feature_importances_
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'Feature {i}' for i in range(X_train.shape[1])]

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Sort the DataFrame by importance
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['Feature'], feature_importances_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Manual Tuning as GridSearch had worse results than base model

# %%
# Plot vs n_estimators
n_estimators_range = range(10, 500, 10)
accuracy_scores = []

# Loop over the n_estimators_range
for n in n_estimators_range:
    rf_clf = RandomForestClassifier(n_estimators=n, random_state=42)
    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# Plot the accuracy scores
plt.figure(figsize=(10, 6))
plt.plot(n_estimators_range, accuracy_scores, marker='o')
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Estimators in Random Forest')
plt.grid(True)
plt.show()

# Find the best n_estimators
best_n = n_estimators_range[np.argmax(accuracy_scores)]
best_score = max(accuracy_scores)

# Train the final model with the best n_estimators
best_rf_clf = RandomForestClassifier(n_estimators=best_n, random_state=42)
best_rf_clf.fit(X_train, y_train)
y_pred_best = best_rf_clf.predict(X_test)

# Print the classification report and display the confusion matrix
print(f"Best Number of Estimators: {best_n}")
print(f"Best Accuracy Score: {best_score}")
print("Classification Report for the Best Model:")
print(classification_report(y_test, y_pred_best))
ConfusionMatrixDisplay.from_estimator(best_rf_clf, X_test, y_test)
plt.show()
# Out:
# Best Number of Estimators: 90
# Best Accuracy Score: 0.5415821501014199
# Classification Report for the Best Model:
#               precision    recall  f1-score   support
#
#            0       0.56      0.45      0.50       248
#            1       0.53      0.64      0.58       245
#
#     accuracy                           0.54       493
#    macro avg       0.54      0.54      0.54       493
# weighted avg       0.54      0.54      0.54       493

# %%
# Plot vs tree depth
max_depth_range = [10, 20, 30, 40, 50, None]
accuracy_scores = []

# Loop over the max_depth_range
for depth in max_depth_range:
    rf_clf = RandomForestClassifier(max_depth=depth, random_state=42)
    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# Plot the accuracy scores
plt.figure(figsize=(10, 6))
plt.plot([str(depth) for depth in max_depth_range], accuracy_scores, marker='o')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Max Depth in Random Forest')
plt.grid(True)
plt.show()

# Find the best max_depth
best_depth = max_depth_range[np.argmax(accuracy_scores)]
best_score = max(accuracy_scores)

# Train the final model with the best max_depth
best_rf_clf = RandomForestClassifier(max_depth=best_depth, random_state=42)
best_rf_clf.fit(X_train, y_train)
y_pred_best = best_rf_clf.predict(X_test)

# Print the classification report and display the confusion matrix
print(f"Best Max Depth: {best_depth}")
print(f"Best Accuracy Score: {best_score}")
print("Classification Report for the Best Model:")
print(classification_report(y_test, y_pred_best))
ConfusionMatrixDisplay.from_estimator(best_rf_clf, X_test, y_test)
plt.show()
# Out:
# Best Max Depth: 40
# Best Accuracy Score: 0.5415821501014199
# Classification Report for the Best Model:
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50       248
#            1       0.53      0.62      0.58       245
#
#     accuracy                           0.54       493
#    macro avg       0.54      0.54      0.54       493
# weighted avg       0.54      0.54      0.54       493

# %%
# Plot vs max features
max_features_range = ['sqrt', 'log2', 0.2, 0.4, 0.6, 0.8, None]
accuracy_scores = []

# Loop over the max_features_range
for feature in max_features_range:
    rf_clf = RandomForestClassifier( max_features=feature, random_state=42)
    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# Plot the accuracy scores
plt.figure(figsize=(10, 6))
plt.plot([str(feature) for feature in max_features_range], accuracy_scores, marker='o')
plt.xlabel('Max Features')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Max Features in Random Forest')
plt.grid(True)
plt.show()

# Find the best max_features
best_feature = max_features_range[np.argmax(accuracy_scores)]
best_score = max(accuracy_scores)

# Train the final model with the best max_features
best_rf_clf = RandomForestClassifier(max_features=best_feature, random_state=42)
best_rf_clf.fit(X_train, y_train)
y_pred_best = best_rf_clf.predict(X_test)

# Print the classification report and display the confusion matrix
print(f"Best Max Features: {best_feature}")
print(f"Best Accuracy Score: {best_score}")
print("Classification Report for the Best Model:")
print(classification_report(y_test, y_pred_best))
ConfusionMatrixDisplay.from_estimator(best_rf_clf, X_test, y_test)
plt.show()
# Out:
# Best Max Features: log2
# Best Accuracy Score: 0.5456389452332657
# Classification Report for the Best Model:
#               precision    recall  f1-score   support
#
#            0       0.56      0.44      0.50       248
#            1       0.54      0.65      0.59       245
#
#     accuracy                           0.55       493
#    macro avg       0.55      0.55      0.54       493
# weighted avg       0.55      0.55      0.54       493

# %%
# Plot vs min_samples_split
min_samples_split_range = range(2, 20, 2)
accuracy_scores = []

# Loop over the min_samples_split_range
for split in min_samples_split_range:
    rf_clf = RandomForestClassifier(min_samples_split=split, random_state=42)
    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# Plot the accuracy scores
plt.figure(figsize=(10, 6))
plt.plot(min_samples_split_range, accuracy_scores, marker='o')
plt.xlabel('Min Samples Split')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Min Samples Split in Random Forest')
plt.grid(True)
plt.show()

# Find the best min_samples_split
best_split = min_samples_split_range[np.argmax(accuracy_scores)]
best_score = max(accuracy_scores)

# Train the final model with the best min_samples_split
best_rf_clf = RandomForestClassifier(min_samples_split=best_split, random_state=42)
best_rf_clf.fit(X_train, y_train)
y_pred_best = best_rf_clf.predict(X_test)

# Print the classification report and display the confusion matrix
print(f"Best Min Samples Split: {best_split}")
print(f"Best Accuracy Score: {best_score}")
print("Classification Report for the Best Model:")
print(classification_report(y_test, y_pred_best))
ConfusionMatrixDisplay.from_estimator(best_rf_clf, X_test, y_test)
plt.show()
# Out:
# Best Min Samples Split: 2
# Best Accuracy Score: 0.5415821501014199
# Classification Report for the Best Model:
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50       248
#            1       0.53      0.62      0.58       245
#
#     accuracy                           0.54       493
#    macro avg       0.54      0.54      0.54       493
# weighted avg       0.54      0.54      0.54       493

# %%
# Plot vs min_samples_leaf
min_samples_leaf_range = range(1, 21)
accuracy_scores = []

# Loop over the min_samples_leaf_range
for leaf in min_samples_leaf_range:
    rf_clf = RandomForestClassifier(min_samples_leaf=leaf, random_state=42)
    rf_clf.fit(X_train, y_train)
    y_pred = rf_clf.predict(X_test)
    accuracy_scores.append(accuracy_score(y_test, y_pred))

# Plot the accuracy scores
plt.figure(figsize=(10, 6))
plt.plot(min_samples_leaf_range, accuracy_scores, marker='o')
plt.xlabel('Min Samples Leaf')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Min Samples Leaf in Random Forest')
plt.grid(True)
plt.show()

# Find the best min_samples_leaf
best_leaf = min_samples_leaf_range[np.argmax(accuracy_scores)]
best_score = max(accuracy_scores)

# Train the final model with the best min_samples_leaf
best_rf_clf = RandomForestClassifier(min_samples_leaf=best_leaf, random_state=42)
best_rf_clf.fit(X_train, y_train)
y_pred_best = best_rf_clf.predict(X_test)

# Print the classification report and display the confusion matrix
print(f"Best Min Samples Leaf: {best_leaf}")
print(f"Best Accuracy Score: {best_score}")
print("Classification Report for the Best Model:")
print(classification_report(y_test, y_pred_best))
ConfusionMatrixDisplay.from_estimator(best_rf_clf, X_test, y_test)
plt.show()
# Out:
# Best Min Samples Leaf: 1
# Best Accuracy Score: 0.5415821501014199
# Classification Report for the Best Model:
#               precision    recall  f1-score   support
#
#            0       0.55      0.46      0.50       248
#            1       0.53      0.62      0.58       245
#
#     accuracy                           0.54       493
#    macro avg       0.54      0.54      0.54       493
# weighted avg       0.54      0.54      0.54       493

# %%
# Looks like only changing max features helps at all
# Baseline Random Forest
rf_clf = RandomForestClassifier(random_state=42, max_features='log2')
rf_clf.fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(rf_clf, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.44      0.50       248
#            1       0.54      0.65      0.59       245
#
#     accuracy                           0.55       493
#    macro avg       0.55      0.55      0.54       493
# weighted avg       0.55      0.55      0.54       493

# %%
# Extract feature importances from the model
importances = rf_clf.feature_importances_
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'Feature {i}' for i in range(X_train.shape[1])]

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Sort the DataFrame by importance
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['Feature'], feature_importances_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %%
# Since dates can have multiple articles and therefore multiple predictions, we can
# pick the result with the highest probability.  This might be important for the next steps,
# but currently this is just a placeholder

# Predict probabilities and classes
y_pred_proba = rf_clf.predict_proba(X_test)
y_pred = rf_clf.predict(X_test)

# Create a DataFrame with the results
results_df = pd.DataFrame(X_test, columns=X_test.columns)
results_df['Actual'] = y_test
results_df['Predicted_Class'] = y_pred
results_df['Predicted_Probability_Class_0'] = y_pred_proba[:, 0]
results_df['Predicted_Probability_Class_1'] = y_pred_proba[:, 1]
display(results_df.head())
# Out:
#       Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 8981       False       False       False       False        False       False
# 8982       False       False       False       False        False       False
# 8983       False       False       False       False        False       False
# 8984       False        True       False       False        False       False
# 8985       False        True       False       False        False       False
#
#       Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Regulatory_Neutral  \
# 8981        True       False       False       False  ...                True
# 8982       False       False       False       False  ...               False
# 8983       False       False       False        True  ...                True
# 8984       False       False       False       False  ...               False
# 8985       False       False       False       False  ...                True
#
#       Regulatory_Positive  Green Energy_Neutral  Green Energy_Positive  \
# 8981                False                 False                   True
# 8982                False                  True                  False
# 8983                False                  True                  False
# 8984                 True                 False                   True
# 8985                False                  True                  False
#
#       OG Price_Neutral  OG Price_Positive  Actual  Predicted_Class  \
# 8981             False              False       1                0
# 8982             False              False       1                0
# 8983             False              False       1                1
# 8984              True              False       1                1
# 8985             False               True       1                0
#
#       Predicted_Probability_Class_0  Predicted_Probability_Class_1
# 8981                       0.571505                       0.428495
# 8982                       0.628690                       0.371310
# 8983                       0.228992                       0.771008
# 8984                       0.239286                       0.760714
# 8985                       0.674073                       0.325927
#
# [5 rows x 35 columns]
