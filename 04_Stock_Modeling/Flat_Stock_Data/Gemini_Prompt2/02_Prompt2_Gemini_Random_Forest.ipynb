# %%
# import libraries
import os
from google.colab import userdata
from google.colab import output
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Import github token with google secrets thingy and clone git repository
GITHUB_TOKEN = userdata.get('github')
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
# !git clone https://{GITHUB_TOKEN}@github.com/Kussil/Financial_Sentiment_LLM.git
# Out:
# Cloning into 'Financial_Sentiment_LLM'...
# remote: Enumerating objects: 2545, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2545 (delta 69), reused 75 (delta 51), pack-reused 2434
# Receiving objects: 100% (2545/2545), 467.03 MiB | 9.94 MiB/s, done.
# Resolving deltas: 100% (1701/1701), done.
# Updating files: 100% (1185/1185), done.

# %%
# Load prepped data
gemini_sentiment = pd.read_csv('/content/Financial_Sentiment_LLM/04_Stock_Modeling/Flat_Stock_Data/Gemini_Prompt2/02_Prompt2_Gemini_Prepped_Stock_Data.csv')
print(gemini_sentiment.shape)
display(gemini_sentiment.head())
print(gemini_sentiment.isna().sum())
# Out:
# (9474, 12)
#                 Source      Unique_ID Ticker        Date  \
# 0             ProQuest  PQ-2463687415     BP  2019-01-09
# 1             ProQuest  PQ-2311280728     BP  2019-02-11
# 2  Investment Research        IR-4891     BP  2019-02-20
# 3             ProQuest  PQ-2300507429     BP  2019-03-10
# 4             ProQuest  PQ-2311444292     BP  2019-03-11
#
#                                                  URL   Finance Production  \
# 0  https://www.proquest.com/newspapers/markets-co...  Positive    Neutral
# 1  https://www.proquest.com/newspapers/arabia-sau...   Neutral    Neutral
# 2                                                NaN  Positive   Positive
# 3  https://www.proquest.com/newspapers/bp-ceo-ste...  Positive    Neutral
# 4  https://www.proquest.com/newspapers/aramco-arr...  Positive    Neutral
#
#   Reserves/M&A Regulatory Green Energy  OG Price   Returns
# 0     Positive    Neutral      Neutral   Neutral  0.008244
# 1      Neutral    Neutral      Neutral   Neutral -0.006589
# 2      Neutral    Neutral      Neutral  Positive  0.002360
# 3      Neutral   Negative      Neutral   Neutral  0.001894
# 4      Neutral    Neutral     Negative   Neutral  0.001894
# Source             0
# Unique_ID          0
# Ticker             0
# Date               0
# URL             4887
# Finance            0
# Production         0
# Reserves/M&A       0
# Regulatory         0
# Green Energy       0
# OG Price           0
# Returns            0
# dtype: int64

# %%
# Drop extra columns
gemini_sentiment = gemini_sentiment.drop(['Unique_ID','URL'], axis=1)

# Convert the 'Date' column to datetime
gemini_sentiment['Date'] = pd.to_datetime(gemini_sentiment['Date'])
display(gemini_sentiment.head())
# Out:
#                 Source Ticker       Date   Finance Production Reserves/M&A  \
# 0             ProQuest     BP 2019-01-09  Positive    Neutral     Positive
# 1             ProQuest     BP 2019-02-11   Neutral    Neutral      Neutral
# 2  Investment Research     BP 2019-02-20  Positive   Positive      Neutral
# 3             ProQuest     BP 2019-03-10  Positive    Neutral      Neutral
# 4             ProQuest     BP 2019-03-11  Positive    Neutral      Neutral
#
#   Regulatory Green Energy  OG Price   Returns
# 0    Neutral      Neutral   Neutral  0.008244
# 1    Neutral      Neutral   Neutral -0.006589
# 2    Neutral      Neutral  Positive  0.002360
# 3   Negative      Neutral   Neutral  0.001894
# 4    Neutral     Negative   Neutral  0.001894

# %%
# One hot encode categorical variables
gemini_sentiment_encoded = pd.get_dummies(gemini_sentiment, columns=['Ticker',
                                                                     'Source',
                                                                     'Finance',
                                                                     'Production',
                                                                     'Reserves/M&A',
                                                                     'Regulatory',
                                                                     'Green Energy',
                                                                     'OG Price'], drop_first=True)
display(gemini_sentiment_encoded.head())
# Out:
#         Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 0 2019-01-09  0.008244       False       False       False       False
# 1 2019-02-11 -0.006589       False       False       False       False
# 2 2019-02-20  0.002360       False       False       False       False
# 3 2019-03-10  0.001894       False       False       False       False
# 4 2019-03-11  0.001894       False       False       False       False
#
#    Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  Production_Neutral  \
# 0        False       False       False       False  ...                True
# 1        False       False       False       False  ...                True
# 2        False       False       False       False  ...               False
# 3        False       False       False       False  ...                True
# 4        False       False       False       False  ...                True
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                False                 False                   True
# 1                False                  True                  False
# 2                 True                  True                  False
# 3                False                  True                  False
# 4                False                  True                  False
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0                True                False                  True
# 1                True                False                  True
# 2                True                False                  True
# 3               False                False                  True
# 4                True                False                 False
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                  False              True              False
# 1                  False              True              False
# 2                  False             False               True
# 3                  False              True              False
# 4                  False              True              False
#
# [5 rows x 33 columns]

# %%
# Split into test and train
split_date = pd.to_datetime('2024-01-01')

# Split the DataFrame
train_df = gemini_sentiment_encoded[(gemini_sentiment_encoded['Date'] < split_date)]
test_df = gemini_sentiment_encoded[gemini_sentiment_encoded['Date'] >= split_date]

display(train_df.tail())
display(test_df.head())
# Out:
#            Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 9408 2023-12-13  0.008873       False       False       False       False
# 9409 2023-12-16 -0.016701       False       False       False       False
# 9410 2023-12-20 -0.016701       False       False       False       False
# 9411 2023-12-23  0.008402       False       False       False       False
# 9412 2023-12-30  0.008402       False       False       False       False
#
#       Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  \
# 9408        False       False       False       False  ...
# 9409        False       False       False       False  ...
# 9410        False       False       False       False  ...
# 9411        False       False       False       False  ...
# 9412        False       False       False       False  ...
#
#       Production_Neutral  Production_Positive  Reserves/M&A_Neutral  \
# 9408                True                False                 False
# 9409               False                 True                 False
# 9410                True                False                  True
# 9411               False                 True                 False
# 9412                True                False                 False
#
#       Reserves/M&A_Positive  Regulatory_Neutral  Regulatory_Positive  \
# 9408                  False               False                 True
# 9409                   True                True                False
# 9410                  False                True                False
# 9411                   True                True                False
# 9412                   True                True                False
#
#       Green Energy_Neutral  Green Energy_Positive  OG Price_Neutral  \
# 9408                 False                   True              True
# 9409                 False                   True             False
# 9410                  True                  False              True
# 9411                 False                   True             False
# 9412                 False                   True              True
#
#       OG Price_Positive
# 9408              False
# 9409               True
# 9410              False
# 9411               True
# 9412              False
#
# [5 rows x 33 columns]
#           Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 742 2024-01-02  0.002825       False       False       False       False
# 743 2024-01-03  0.014085       False       False       False       False
# 744 2024-01-13 -0.016638       False       False       False       False
# 745 2024-01-16 -0.016638       False       False       False       False
# 746 2024-01-16 -0.016638       False       False       False       False
#
#      Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  Production_Neutral  \
# 742        False       False       False       False  ...               False
# 743        False       False       False       False  ...                True
# 744        False       False       False       False  ...               False
# 745        False       False       False       False  ...               False
# 746        False       False       False       False  ...                True
#
#      Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 742                False                 False                  False
# 743                False                 False                   True
# 744                False                 False                   True
# 745                 True                  True                  False
# 746                False                  True                  False
#
#      Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 742               False                False                  True
# 743               False                 True                 False
# 744                True                False                 False
# 745                True                False                  True
# 746                True                False                  True
#
#      Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 742                  False             False              False
# 743                   True              True              False
# 744                   True              True              False
# 745                  False              True              False
# 746                  False              True              False
#
# [5 rows x 33 columns]

# %%
# Define X and y
X_train = train_df.drop(columns=['Date','Returns'])
X_test = test_df.drop(columns=['Date','Returns'])

y_train = train_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)
y_test = test_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)

print(len(X_train), len(y_train), len(X_test), len(y_test))
display(X_train.head())
display(y_train.head())
# Out:
# 8981 8981 493 493
#    Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 0       False       False       False       False        False       False
# 1       False       False       False       False        False       False
# 2       False       False       False       False        False       False
# 3       False       False       False       False        False       False
# 4       False       False       False       False        False       False
#
#    Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Production_Neutral  \
# 0       False       False       False       False  ...                True
# 1       False       False       False       False  ...                True
# 2       False       False       False       False  ...               False
# 3       False       False       False       False  ...                True
# 4       False       False       False       False  ...                True
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                False                 False                   True
# 1                False                  True                  False
# 2                 True                  True                  False
# 3                False                  True                  False
# 4                False                  True                  False
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0                True                False                  True
# 1                True                False                  True
# 2                True                False                  True
# 3               False                False                  True
# 4                True                False                 False
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                  False              True              False
# 1                  False              True              False
# 2                  False             False               True
# 3                  False              True              False
# 4                  False              True              False
#
# [5 rows x 31 columns]
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Returns, dtype: int64

# %%
# Baseline Random Forest
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(rf_clf, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.43      0.47       248
#            1       0.51      0.61      0.56       245
#
#     accuracy                           0.52       493
#    macro avg       0.52      0.52      0.52       493
# weighted avg       0.52      0.52      0.52       493

# %%
# Tuned Random Forest

# Define the parameter grid
param_grid = {
   'n_estimators': [500],
   'max_depth': [None, 10, 20, 30],
   'max_features': [None, 'sqrt', 'log2']
}

# Create a Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_clf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)

# Make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# {'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.44      0.48       248
#            1       0.51      0.60      0.55       245
#
#     accuracy                           0.52       493
#    macro avg       0.52      0.52      0.52       493
# weighted avg       0.52      0.52      0.52       493

# %%
# Extract feature importances from the best model
importances = best_model.feature_importances_
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'Feature {i}' for i in range(X_train.shape[1])]

# Create a DataFrame for better visualization
feature_importances_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Sort the DataFrame by importance
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
plt.barh(feature_importances_df['Feature'], feature_importances_df['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()

# %%
# Since dates can have multiple articles and therefore multiple predictions, we can
# pick the result with the highest probability.  This might be important for the next steps,
# but currently this is just a placeholder

# Predict probabilities and classes
y_pred_proba = best_model.predict_proba(X_test)
y_pred = best_model.predict(X_test)

# Create a DataFrame with the results
results_df = pd.DataFrame(X_test, columns=X_test.columns)
results_df['Actual'] = y_test
results_df['Predicted_Class'] = y_pred
results_df['Predicted_Probability_Class_0'] = y_pred_proba[:, 0]
results_df['Predicted_Probability_Class_1'] = y_pred_proba[:, 1]
display(results_df.head())
# Out:
#      Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 742       False       False       False       False        False       False
# 743       False       False       False       False        False       False
# 744       False       False       False       False        False       False
# 745       False       False       False       False        False       False
# 746       False       False       False       False        False       False
#
#      Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Regulatory_Neutral  \
# 742       False       False       False       False  ...               False
# 743       False       False       False       False  ...               False
# 744       False       False       False       False  ...                True
# 745       False       False       False       False  ...                True
# 746       False       False       False       False  ...                True
#
#      Regulatory_Positive  Green Energy_Neutral  Green Energy_Positive  \
# 742                False                  True                  False
# 743                 True                 False                   True
# 744                False                 False                   True
# 745                False                  True                  False
# 746                False                  True                  False
#
#      OG Price_Neutral  OG Price_Positive  Actual  Predicted_Class  \
# 742             False              False       1                0
# 743              True              False       1                1
# 744              True              False       0                1
# 745              True              False       0                1
# 746              True              False       0                0
#
#      Predicted_Probability_Class_0  Predicted_Probability_Class_1
# 742                       0.573110                       0.426890
# 743                       0.454076                       0.545924
# 744                       0.470654                       0.529346
# 745                       0.344406                       0.655594
# 746                       0.548944                       0.451056
#
# [5 rows x 35 columns]
