# %%
# import libraries
import os
from google.colab import userdata
from google.colab import output
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Import github token with google secrets thingy and clone git repository
GITHUB_TOKEN = userdata.get('github')
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
# !git clone https://{GITHUB_TOKEN}@github.com/Kussil/Financial_Sentiment_LLM.git
# Out:
# Cloning into 'Financial_Sentiment_LLM'...
# remote: Enumerating objects: 2345, done.
# remote: Counting objects: 100% (750/750), done.
# remote: Compressing objects: 100% (351/351), done.
# remote: Total 2345 (delta 476), reused 648 (delta 386), pack-reused 1595
# Receiving objects: 100% (2345/2345), 475.37 MiB | 8.93 MiB/s, done.
# Resolving deltas: 100% (1559/1559), done.
# Updating files: 100% (1177/1177), done.

# %%
# Load prepped data
gemini_sentiment = pd.read_csv('/content/Financial_Sentiment_LLM/04_Stock_Modeling/Flat_Stock_Data/02_Prompt2_Gemini_Prepped_Stock_Data.csv')
print(gemini_sentiment.shape)
display(gemini_sentiment.head())
print(gemini_sentiment.isna().sum())
# Out:
# (9585, 12)
#                         Source Unique_ID Ticker        Date  URL   Finance  \
# 0  Earnings Call Presentations    EP-331     BP  2019-02-05  NaN  Positive
# 1            Earnings Call Q&A    EQ-331     BP  2019-02-05  NaN  Positive
# 2          Investment Research   IR-4891     BP  2019-02-20  NaN  Positive
# 3  Earnings Call Presentations    EP-317     BP  2019-04-30  NaN  Positive
# 4            Earnings Call Q&A    EQ-317     BP  2019-04-30  NaN  Positive
#
#   Production Reserves/M&A Regulatory Green Energy OG Price   Returns
# 0   Positive     Positive   Positive     Positive  Neutral  0.034550
# 1   Positive     Positive   Positive     Positive  Neutral  0.034550
# 2   Positive      Neutral    Neutral      Neutral  Neutral  0.002359
# 3   Positive     Positive    Neutral     Positive  Neutral  0.016503
# 4   Positive     Positive   Positive     Positive  Neutral  0.016503
# Source             0
# Unique_ID          0
# Ticker             0
# Date               0
# URL             4887
# Finance            0
# Production         0
# Reserves/M&A       0
# Regulatory         0
# Green Energy       0
# OG Price           0
# Returns            0
# dtype: int64

# %%
# Drop extra columns
gemini_sentiment = gemini_sentiment.drop(['Unique_ID','URL'], axis=1)

# Convert the 'Date' column to datetime
gemini_sentiment['Date'] = pd.to_datetime(gemini_sentiment['Date'])
display(gemini_sentiment.head())
# Out:
#                         Source Ticker       Date   Finance Production  \
# 0  Earnings Call Presentations     BP 2019-02-05  Positive   Positive
# 1            Earnings Call Q&A     BP 2019-02-05  Positive   Positive
# 2          Investment Research     BP 2019-02-20  Positive   Positive
# 3  Earnings Call Presentations     BP 2019-04-30  Positive   Positive
# 4            Earnings Call Q&A     BP 2019-04-30  Positive   Positive
#
#   Reserves/M&A Regulatory Green Energy OG Price   Returns
# 0     Positive   Positive     Positive  Neutral  0.034550
# 1     Positive   Positive     Positive  Neutral  0.034550
# 2      Neutral    Neutral      Neutral  Neutral  0.002359
# 3     Positive    Neutral     Positive  Neutral  0.016503
# 4     Positive   Positive     Positive  Neutral  0.016503

# %%
# One hot encode categorical variables
gemini_sentiment_encoded = pd.get_dummies(gemini_sentiment, columns=['Ticker',
                                                                     'Source',
                                                                     'Finance',
                                                                     'Production',
                                                                     'Reserves/M&A',
                                                                     'Regulatory',
                                                                     'Green Energy',
                                                                     'OG Price'], drop_first=True)
display(gemini_sentiment_encoded.head())
# Out:
#         Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 0 2019-02-05  0.034550       False       False       False       False
# 1 2019-02-05  0.034550       False       False       False       False
# 2 2019-02-20  0.002359       False       False       False       False
# 3 2019-04-30  0.016503       False       False       False       False
# 4 2019-04-30  0.016503       False       False       False       False
#
#    Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  Production_Neutral  \
# 0        False       False       False       False  ...               False
# 1        False       False       False       False  ...               False
# 2        False       False       False       False  ...               False
# 3        False       False       False       False  ...               False
# 4        False       False       False       False  ...               False
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                 True                 False                   True
# 1                 True                 False                   True
# 2                 True                  True                  False
# 3                 True                 False                   True
# 4                 True                 False                   True
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0               False                 True                 False
# 1               False                 True                 False
# 2                True                False                  True
# 3                True                False                 False
# 4               False                 True                 False
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                   True              True              False
# 1                   True              True              False
# 2                  False              True              False
# 3                   True              True              False
# 4                   True              True              False
#
# [5 rows x 33 columns]

# %%
# Split into test and train
split_date = pd.to_datetime('2024-01-01')

# Split the DataFrame
train_df = gemini_sentiment_encoded[(gemini_sentiment_encoded['Date'] < split_date)]
test_df = gemini_sentiment_encoded[gemini_sentiment_encoded['Date'] >= split_date]

display(train_df.tail())
display(test_df.head())
# Out:
#            Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 9509 2023-12-13  0.008873       False       False       False       False
# 9510 2023-12-16 -0.016701       False       False       False       False
# 9511 2023-12-20 -0.016701       False       False       False       False
# 9512 2023-12-23 -0.012386       False       False       False       False
# 9513 2023-12-30 -0.012386       False       False       False       False
#
#       Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  \
# 9509        False       False       False       False  ...
# 9510        False       False       False       False  ...
# 9511        False       False       False       False  ...
# 9512        False       False       False       False  ...
# 9513        False       False       False       False  ...
#
#       Production_Neutral  Production_Positive  Reserves/M&A_Neutral  \
# 9509                True                False                 False
# 9510               False                 True                 False
# 9511                True                False                  True
# 9512               False                 True                 False
# 9513               False                 True                 False
#
#       Reserves/M&A_Positive  Regulatory_Neutral  Regulatory_Positive  \
# 9509                  False               False                False
# 9510                   True                True                False
# 9511                  False                True                False
# 9512                   True                True                False
# 9513                   True                True                False
#
#       Green Energy_Neutral  Green Energy_Positive  OG Price_Neutral  \
# 9509                 False                   True              True
# 9510                 False                   True              True
# 9511                  True                  False              True
# 9512                 False                   True              True
# 9513                 False                   True              True
#
#       OG Price_Positive
# 9509              False
# 9510              False
# 9511              False
# 9512              False
# 9513              False
#
# [5 rows x 33 columns]
#           Date   Returns  Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  \
# 752 2024-01-02  0.002825       False       False       False       False
# 753 2024-01-02  0.002825       False       False       False       False
# 754 2024-01-09 -0.015241       False       False       False       False
# 755 2024-01-11 -0.002594       False       False       False       False
# 756 2024-01-13 -0.016638       False       False       False       False
#
#      Ticker_EQNR  Ticker_HES  Ticker_MPC  Ticker_MRO  ...  Production_Neutral  \
# 752        False       False       False       False  ...               False
# 753        False       False       False       False  ...                True
# 754        False       False       False       False  ...               False
# 755        False       False       False       False  ...                True
# 756        False       False       False       False  ...                True
#
#      Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 752                False                 False                  False
# 753                False                  True                  False
# 754                False                 False                  False
# 755                False                  True                  False
# 756                False                 False                   True
#
#      Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 752               False                False                  True
# 753                True                False                  True
# 754               False                False                  True
# 755                True                False                  True
# 756                True                False                 False
#
#      Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 752                  False             False              False
# 753                  False              True              False
# 754                  False              True              False
# 755                  False              True              False
# 756                   True              True              False
#
# [5 rows x 33 columns]

# %%
# Define X and y
X_train = train_df.drop(columns=['Date','Returns'])
X_test = test_df.drop(columns=['Date','Returns'])

y_train = train_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)
y_test = test_df['Returns'].apply(lambda x: 1 if x > 0.0 else 0)

print(len(X_train), len(y_train), len(X_test), len(y_test))
display(X_train.head())
display(y_train.head())
# Out:
# 9050 9050 535 535
#    Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 0       False       False       False       False        False       False
# 1       False       False       False       False        False       False
# 2       False       False       False       False        False       False
# 3       False       False       False       False        False       False
# 4       False       False       False       False        False       False
#
#    Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Production_Neutral  \
# 0       False       False       False       False  ...               False
# 1       False       False       False       False  ...               False
# 2       False       False       False       False  ...               False
# 3       False       False       False       False  ...               False
# 4       False       False       False       False  ...               False
#
#    Production_Positive  Reserves/M&A_Neutral  Reserves/M&A_Positive  \
# 0                 True                 False                   True
# 1                 True                 False                   True
# 2                 True                  True                  False
# 3                 True                 False                   True
# 4                 True                 False                   True
#
#    Regulatory_Neutral  Regulatory_Positive  Green Energy_Neutral  \
# 0               False                 True                 False
# 1               False                 True                 False
# 2                True                False                  True
# 3                True                False                 False
# 4               False                 True                 False
#
#    Green Energy_Positive  OG Price_Neutral  OG Price_Positive
# 0                   True              True              False
# 1                   True              True              False
# 2                  False              True              False
# 3                   True              True              False
# 4                   True              True              False
#
# [5 rows x 31 columns]
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Returns, dtype: int64

# %%
# Baseline Random Forest
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(X_train, y_train)
y_pred = rf_clf.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(rf_clf, X_test, y_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.46      0.45      0.46       261
#            1       0.49      0.50      0.50       274
#
#     accuracy                           0.48       535
#    macro avg       0.48      0.48      0.48       535
# weighted avg       0.48      0.48      0.48       535

# %%
# Tuned Random Forest

# Define the parameter grid
param_grid = {
   'n_estimators': [500],
   'max_depth': [None, 10, 20, 30],
   'max_features': [None, 'sqrt', 'log2']
}

# Create a Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=rf_clf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)

# Make predictions on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(best_model, X_test, y_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# {'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.34      0.43       261
#            1       0.54      0.74      0.63       274
#
#     accuracy                           0.55       535
#    macro avg       0.55      0.54      0.53       535
# weighted avg       0.55      0.55      0.53       535

# %%
# Since dates can have multiple articles and therefore multiple predictions, we can
# pick the result with the highest probability.  This might be important for the next steps,
# but currently this is just a placeholder

# Predict probabilities and classes
y_pred_proba = best_model.predict_proba(X_test)
y_pred = best_model.predict(X_test)

# Create a DataFrame with the results
results_df = pd.DataFrame(X_test, columns=X_test.columns)
results_df['Actual'] = y_test
results_df['Predicted_Class'] = y_pred
results_df['Predicted_Probability_Class_0'] = y_pred_proba[:, 0]
results_df['Predicted_Probability_Class_1'] = y_pred_proba[:, 1]
display(results_df.head())
# Out:
#      Ticker_COP  Ticker_CVX  Ticker_DVN  Ticker_EOG  Ticker_EQNR  Ticker_HES  \
# 752       False       False       False       False        False       False
# 753       False       False       False       False        False       False
# 754       False       False       False       False        False       False
# 755       False       False       False       False        False       False
# 756       False       False       False       False        False       False
#
#      Ticker_MPC  Ticker_MRO  Ticker_OXY  Ticker_PSX  ...  Regulatory_Neutral  \
# 752       False       False       False       False  ...               False
# 753       False       False       False       False  ...                True
# 754       False       False       False       False  ...               False
# 755       False       False       False       False  ...                True
# 756       False       False       False       False  ...                True
#
#      Regulatory_Positive  Green Energy_Neutral  Green Energy_Positive  \
# 752                False                  True                  False
# 753                False                  True                  False
# 754                False                  True                  False
# 755                False                  True                  False
# 756                False                 False                   True
#
#      OG Price_Neutral  OG Price_Positive  Actual  Predicted_Class  \
# 752             False              False       1                1
# 753              True              False       1                0
# 754              True              False       0                0
# 755              True              False       0                0
# 756              True              False       0                1
#
#      Predicted_Probability_Class_0  Predicted_Probability_Class_1
# 752                       0.452917                       0.547083
# 753                       0.504504                       0.495496
# 754                       0.502214                       0.497786
# 755                       0.504504                       0.495496
# 756                       0.448864                       0.551136
#
# [5 rows x 35 columns]
